# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4624  g_loss:0.3282
# epoch:2  d_loss:0.5685  g_loss:0.1025
# epoch:3  d_loss:0.6585  g_loss:0.0836
# epoch:4  d_loss:0.5768  g_loss:0.1651
# epoch:5  d_loss:0.5088  g_loss:0.4210
# epoch:6  d_loss:0.4876  g_loss:0.6974
# epoch:7  d_loss:0.5091  g_loss:0.8703
# epoch:8  d_loss:0.4965  g_loss:0.8977
# epoch:9  d_loss:0.4858  g_loss:0.8732
# epoch:10  d_loss:0.4170  g_loss:0.7877
# epoch:11  d_loss:0.4386  g_loss:0.8118
# epoch:12  d_loss:0.4802  g_loss:0.8692
# epoch:13  d_loss:0.4737  g_loss:0.9185
# epoch:14  d_loss:0.5712  g_loss:0.9720
# epoch:15  d_loss:0.4719  g_loss:1.0423
# epoch:16  d_loss:0.4016  g_loss:1.0496
# epoch:17  d_loss:0.6235  g_loss:0.7703
# epoch:18  d_loss:0.5684  g_loss:0.6393
# epoch:19  d_loss:0.4597  g_loss:0.7211
# epoch:20  d_loss:0.4232  g_loss:0.8026
# epoch:21  d_loss:0.5010  g_loss:0.8416
# epoch:22  d_loss:0.5150  g_loss:0.6772
# epoch:23  d_loss:0.4562  g_loss:0.6257
# epoch:24  d_loss:0.4514  g_loss:0.6677
# epoch:25  d_loss:0.4688  g_loss:0.7263
# epoch:26  d_loss:0.5126  g_loss:0.7368
# epoch:27  d_loss:0.4782  g_loss:0.5982
# epoch:28  d_loss:0.4953  g_loss:0.5452
# epoch:29  d_loss:0.5222  g_loss:0.5666
# epoch:30  d_loss:0.4423  g_loss:0.6301
# epoch:31  d_loss:0.4836  g_loss:0.6896
# epoch:32  d_loss:0.4419  g_loss:0.5815
# epoch:33  d_loss:0.4468  g_loss:0.6251
# epoch:34  d_loss:0.3338  g_loss:0.7062
# epoch:35  d_loss:0.3772  g_loss:0.9073
# epoch:36  d_loss:0.4501  g_loss:0.6072
# epoch:37  d_loss:0.3593  g_loss:0.7095
# epoch:38  d_loss:0.3528  g_loss:0.8784
# epoch:39  d_loss:0.2381  g_loss:1.2574
# epoch:40  d_loss:0.3412  g_loss:1.2882
# epoch:41  d_loss:0.4594  g_loss:0.9457
# epoch:42  d_loss:0.3982  g_loss:0.8213
# epoch:43  d_loss:0.2395  g_loss:1.2267
# epoch:44  d_loss:0.2039  g_loss:1.5349
# epoch:45  d_loss:0.1622  g_loss:2.1822
# epoch:46  d_loss:0.3273  g_loss:1.6893
# epoch:47  d_loss:0.2294  g_loss:1.4854
# epoch:48  d_loss:0.2725  g_loss:1.4259
# epoch:49  d_loss:0.2837  g_loss:1.4861
# epoch:50  d_loss:0.2750  g_loss:1.6432
# epoch:51  d_loss:0.3876  g_loss:2.1628
# epoch:52  d_loss:0.3063  g_loss:2.1518
# epoch:53  d_loss:0.1691  g_loss:1.8628
# epoch:54  d_loss:0.1000  g_loss:1.9161
# epoch:55  d_loss:0.1117  g_loss:2.3601
# epoch:56  d_loss:0.1618  g_loss:2.1517
# epoch:57  d_loss:0.1860  g_loss:2.9332
# epoch:58  d_loss:0.1582  g_loss:3.3478
# epoch:59  d_loss:0.3198  g_loss:2.8366
# epoch:60  d_loss:0.5640  g_loss:2.4909
# epoch:61  d_loss:0.5249  g_loss:3.3238
# epoch:62  d_loss:0.7720  g_loss:2.2332
# epoch:63  d_loss:0.6789  g_loss:2.6572
# epoch:64  d_loss:0.4120  g_loss:3.0580
# epoch:65  d_loss:0.6019  g_loss:3.0714
# epoch:66  d_loss:0.3018  g_loss:3.0136
# epoch:67  d_loss:0.2274  g_loss:3.5311
# epoch:68  d_loss:0.1575  g_loss:4.1508
# epoch:69  d_loss:0.4825  g_loss:3.2283
# epoch:70  d_loss:0.7235  g_loss:1.7375
# epoch:71  d_loss:0.4601  g_loss:2.1985
# epoch:72  d_loss:0.6293  g_loss:2.2096
# epoch:73  d_loss:0.5900  g_loss:1.8031
# epoch:74  d_loss:1.0135  g_loss:1.1075
# epoch:75  d_loss:0.9960  g_loss:1.1905
# epoch:76  d_loss:0.7390  g_loss:1.5899
# epoch:77  d_loss:0.7175  g_loss:2.0883
# epoch:78  d_loss:0.5306  g_loss:2.2203
# epoch:79  d_loss:0.2543  g_loss:2.6978
# epoch:80  d_loss:0.2771  g_loss:2.9345
# epoch:81  d_loss:0.1976  g_loss:3.6395
# epoch:82  d_loss:0.1989  g_loss:4.0926
# epoch:83  d_loss:0.1350  g_loss:5.0570
# epoch:84  d_loss:0.3063  g_loss:4.9406
# epoch:85  d_loss:0.6944  g_loss:4.1860
# epoch:86  d_loss:0.5192  g_loss:5.0409
# epoch:87  d_loss:0.7032  g_loss:5.0726
# epoch:88  d_loss:0.9008  g_loss:3.7628
# epoch:89  d_loss:1.1973  g_loss:3.0677
# epoch:90  d_loss:0.7126  g_loss:3.6959
# epoch:91  d_loss:0.8029  g_loss:4.0182
# epoch:92  d_loss:1.0728  g_loss:3.1528
# epoch:93  d_loss:1.0186  g_loss:2.1688
# epoch:94  d_loss:0.7925  g_loss:1.6461
# epoch:95  d_loss:0.6534  g_loss:1.6353
# epoch:96  d_loss:0.5662  g_loss:1.7380
# epoch:97  d_loss:0.4606  g_loss:1.9077
# epoch:98  d_loss:0.4702  g_loss:1.9481
# epoch:99  d_loss:0.5208  g_loss:1.4217
# epoch:100  d_loss:0.6062  g_loss:1.1898
# epoch:101  d_loss:0.4076  g_loss:1.4264
# epoch:102  d_loss:0.3975  g_loss:1.4079
# epoch:103  d_loss:0.5257  g_loss:1.4925
# epoch:104  d_loss:0.3631  g_loss:1.3572
# epoch:105  d_loss:0.5214  g_loss:1.2930
# epoch:106  d_loss:0.5028  g_loss:1.3855
# epoch:107  d_loss:0.4110  g_loss:1.3588
# epoch:108  d_loss:0.4961  g_loss:0.9437
# epoch:109  d_loss:0.3996  g_loss:0.9334
# epoch:110  d_loss:0.4053  g_loss:1.1454
# epoch:111  d_loss:0.4189  g_loss:1.2652
# epoch:112  d_loss:0.4218  g_loss:1.1398
# epoch:113  d_loss:0.5015  g_loss:1.1985
# epoch:114  d_loss:0.5819  g_loss:1.0317
# epoch:115  d_loss:0.5807  g_loss:0.8109
# epoch:116  d_loss:0.5541  g_loss:0.8232
# epoch:117  d_loss:0.5719  g_loss:0.9264
# epoch:118  d_loss:0.6011  g_loss:1.0769
# epoch:119  d_loss:0.4387  g_loss:1.1757
# epoch:120  d_loss:0.5880  g_loss:0.9946
# epoch:121  d_loss:0.6373  g_loss:1.0228
# epoch:122  d_loss:0.7466  g_loss:0.7861
# epoch:123  d_loss:0.6743  g_loss:0.7924
# epoch:124  d_loss:0.5726  g_loss:0.8643
# epoch:125  d_loss:0.6667  g_loss:0.9160
# epoch:126  d_loss:0.6114  g_loss:0.8470
# epoch:127  d_loss:0.5100  g_loss:1.3003
# epoch:128  d_loss:0.6122  g_loss:1.1197
# epoch:129  d_loss:0.4627  g_loss:1.3597
# epoch:130  d_loss:0.5192  g_loss:1.2220
# epoch:131  d_loss:0.5669  g_loss:1.2162
# epoch:132  d_loss:0.5325  g_loss:1.2973
# epoch:133  d_loss:0.4979  g_loss:1.3428
# epoch:134  d_loss:0.4247  g_loss:1.4831
# epoch:135  d_loss:0.4276  g_loss:1.7795
# epoch:136  d_loss:0.4311  g_loss:1.7243
# epoch:137  d_loss:0.3659  g_loss:1.8158
# epoch:138  d_loss:0.3581  g_loss:2.0402
# epoch:139  d_loss:0.3183  g_loss:2.3234
# epoch:140  d_loss:0.3210  g_loss:1.9713
# epoch:141  d_loss:0.3052  g_loss:2.9273
# epoch:142  d_loss:0.3525  g_loss:2.3195
# epoch:143  d_loss:0.3595  g_loss:2.0704
# epoch:144  d_loss:0.3413  g_loss:2.4027
# epoch:145  d_loss:0.4099  g_loss:2.6852
# epoch:146  d_loss:0.4262  g_loss:3.2120
# epoch:147  d_loss:0.8050  g_loss:2.5325
# epoch:148  d_loss:0.6790  g_loss:2.0372
# epoch:149  d_loss:0.7061  g_loss:2.1405
# epoch:150  d_loss:0.5572  g_loss:2.6733
# epoch:151  d_loss:0.8286  g_loss:2.1192
# epoch:152  d_loss:0.9103  g_loss:1.5475
# epoch:153  d_loss:0.7813  g_loss:1.3394
# epoch:154  d_loss:0.7408  g_loss:1.0390
# epoch:155  d_loss:0.8570  g_loss:1.3710
# epoch:156  d_loss:0.6838  g_loss:1.5364
# epoch:157  d_loss:0.6129  g_loss:1.4924
# epoch:158  d_loss:0.7467  g_loss:1.3197
# epoch:159  d_loss:0.6653  g_loss:1.4302
# epoch:160  d_loss:0.6361  g_loss:1.4281
# epoch:161  d_loss:0.7366  g_loss:1.3370
# epoch:162  d_loss:0.5913  g_loss:1.4431
# epoch:163  d_loss:0.5240  g_loss:1.4936
# epoch:164  d_loss:0.5365  g_loss:1.3778
# epoch:165  d_loss:0.4205  g_loss:1.5172
# epoch:166  d_loss:0.4639  g_loss:1.5213
# epoch:167  d_loss:0.4515  g_loss:1.6950
# epoch:168  d_loss:0.4505  g_loss:1.4915
# epoch:169  d_loss:0.4939  g_loss:1.5991
# epoch:170  d_loss:0.4062  g_loss:1.4394
# epoch:171  d_loss:0.3816  g_loss:1.4296
# epoch:172  d_loss:0.3768  g_loss:1.5359
# epoch:173  d_loss:0.3472  g_loss:1.6010
# epoch:174  d_loss:0.3516  g_loss:1.7899
# epoch:175  d_loss:0.3607  g_loss:1.7711
# epoch:176  d_loss:0.5008  g_loss:1.7969
# epoch:177  d_loss:0.3833  g_loss:1.9345
# epoch:178  d_loss:0.2393  g_loss:2.0827
# epoch:179  d_loss:0.2979  g_loss:1.7736
# epoch:180  d_loss:0.2751  g_loss:1.7077
# epoch:181  d_loss:0.3575  g_loss:1.5414
# epoch:182  d_loss:0.3157  g_loss:1.8653
# epoch:183  d_loss:0.3192  g_loss:1.9022
# epoch:184  d_loss:0.2623  g_loss:2.0484
# epoch:185  d_loss:0.3743  g_loss:1.6499
# epoch:186  d_loss:0.3925  g_loss:1.5985
# epoch:187  d_loss:0.3955  g_loss:1.4621
# epoch:188  d_loss:0.5367  g_loss:1.2687
# epoch:189  d_loss:0.3563  g_loss:1.6064
# epoch:190  d_loss:0.3289  g_loss:1.8595
# epoch:191  d_loss:0.5098  g_loss:1.8932
# epoch:192  d_loss:0.4615  g_loss:1.6570
# epoch:193  d_loss:0.4566  g_loss:1.3349
# epoch:194  d_loss:0.4576  g_loss:1.0736
# epoch:195  d_loss:0.5659  g_loss:1.1276
# epoch:196  d_loss:0.4683  g_loss:1.4116
# epoch:197  d_loss:0.4160  g_loss:1.4065
# epoch:198  d_loss:0.5676  g_loss:1.4525
# epoch:199  d_loss:0.6036  g_loss:1.3289
# epoch:200  d_loss:0.4847  g_loss:1.2060
# epoch:201  d_loss:0.5486  g_loss:1.1003
# epoch:202  d_loss:0.5937  g_loss:1.3341
# epoch:203  d_loss:0.4823  g_loss:1.6842
# epoch:204  d_loss:0.6179  g_loss:1.5965
# epoch:205  d_loss:0.5107  g_loss:1.3375
# epoch:206  d_loss:0.5468  g_loss:1.4723
# epoch:207  d_loss:0.5967  g_loss:1.5737
# epoch:208  d_loss:0.6171  g_loss:1.3682
# epoch:209  d_loss:0.5414  g_loss:1.4019
# epoch:210  d_loss:0.5507  g_loss:1.6782
# epoch:211  d_loss:0.4530  g_loss:1.7447
# epoch:212  d_loss:0.5394  g_loss:1.6662
# epoch:213  d_loss:0.5451  g_loss:1.6730
# epoch:214  d_loss:0.5039  g_loss:1.5610
# epoch:215  d_loss:0.4827  g_loss:1.5295
# epoch:216  d_loss:0.5619  g_loss:1.8985
# epoch:217  d_loss:0.4947  g_loss:1.6139
# epoch:218  d_loss:0.5227  g_loss:1.6415
# epoch:219  d_loss:0.5625  g_loss:1.8111
# epoch:220  d_loss:0.4873  g_loss:1.8511
# epoch:221  d_loss:0.5307  g_loss:1.8565
# epoch:222  d_loss:0.5225  g_loss:1.3014
# epoch:223  d_loss:0.5021  g_loss:1.4419
# epoch:224  d_loss:0.5071  g_loss:1.5907
# epoch:225  d_loss:0.4489  g_loss:1.5615
# epoch:226  d_loss:0.3939  g_loss:1.5813
# epoch:227  d_loss:0.5202  g_loss:1.5670
# epoch:228  d_loss:0.5045  g_loss:1.7321
# epoch:229  d_loss:0.4531  g_loss:1.6184
# epoch:230  d_loss:0.5184  g_loss:1.7592
# epoch:231  d_loss:0.4974  g_loss:1.9947
# epoch:232  d_loss:0.4486  g_loss:1.9781
# epoch:233  d_loss:0.5887  g_loss:1.5656
# epoch:234  d_loss:0.4592  g_loss:1.7196
# epoch:235  d_loss:0.4428  g_loss:1.4493
# epoch:236  d_loss:0.4135  g_loss:1.6577
# epoch:237  d_loss:0.4140  g_loss:1.9994
# epoch:238  d_loss:0.4680  g_loss:1.7104
# epoch:239  d_loss:0.3886  g_loss:1.8461
# epoch:240  d_loss:0.4256  g_loss:1.7318
# epoch:241  d_loss:0.5140  g_loss:1.7181
# epoch:242  d_loss:0.5333  g_loss:1.3669
# epoch:243  d_loss:0.5306  g_loss:1.2840
# epoch:244  d_loss:0.4597  g_loss:1.4875
# epoch:245  d_loss:0.3940  g_loss:1.9485
# epoch:246  d_loss:0.5579  g_loss:1.7910
# epoch:247  d_loss:0.4669  g_loss:2.1398
# epoch:248  d_loss:0.4552  g_loss:1.4834
# epoch:249  d_loss:0.5879  g_loss:1.5780
# epoch:250  d_loss:0.3668  g_loss:1.6026
# epoch:251  d_loss:0.5005  g_loss:1.3498
# epoch:252  d_loss:0.4423  g_loss:1.3296
# epoch:253  d_loss:0.5104  g_loss:1.7526
# epoch:254  d_loss:0.5181  g_loss:1.5890
# epoch:255  d_loss:0.6467  g_loss:1.5835
# epoch:256  d_loss:0.5849  g_loss:1.5761
# epoch:257  d_loss:0.5724  g_loss:1.3779
# epoch:258  d_loss:0.5410  g_loss:1.4269
# epoch:259  d_loss:0.5478  g_loss:1.4131
# epoch:260  d_loss:0.5146  g_loss:1.4794
# epoch:261  d_loss:0.4425  g_loss:1.7067
# epoch:262  d_loss:0.4501  g_loss:1.7566
# epoch:263  d_loss:0.5396  g_loss:1.6835
# epoch:264  d_loss:0.4131  g_loss:1.7734
# epoch:265  d_loss:0.5764  g_loss:1.5702
# epoch:266  d_loss:0.4005  g_loss:1.5459
# epoch:267  d_loss:0.4618  g_loss:1.8799
# epoch:268  d_loss:0.4151  g_loss:1.8090
# epoch:269  d_loss:0.4112  g_loss:1.7385
# epoch:270  d_loss:0.4388  g_loss:1.8573
# epoch:271  d_loss:0.3875  g_loss:2.2028
# epoch:272  d_loss:0.3382  g_loss:2.2137
# epoch:273  d_loss:0.3738  g_loss:2.1922
# epoch:274  d_loss:0.3637  g_loss:2.4692
# epoch:275  d_loss:0.3487  g_loss:1.8183
# epoch:276  d_loss:0.5567  g_loss:1.6776
# epoch:277  d_loss:0.3388  g_loss:2.0118
# epoch:278  d_loss:0.3921  g_loss:2.0359
# epoch:279  d_loss:0.3619  g_loss:2.3092
# epoch:280  d_loss:0.2630  g_loss:2.3593
# epoch:281  d_loss:0.5161  g_loss:2.2422
# epoch:282  d_loss:0.4242  g_loss:2.1976
# epoch:283  d_loss:0.4124  g_loss:2.4138
# epoch:284  d_loss:0.4019  g_loss:2.2744
# epoch:285  d_loss:0.3181  g_loss:2.4562
# epoch:286  d_loss:0.3691  g_loss:2.6318
# epoch:287  d_loss:0.5052  g_loss:1.9747
# epoch:288  d_loss:0.3103  g_loss:2.4497
# epoch:289  d_loss:0.3975  g_loss:2.8170
# epoch:290  d_loss:0.4594  g_loss:2.6124
# epoch:291  d_loss:0.5116  g_loss:2.6509
# epoch:292  d_loss:0.4066  g_loss:2.0112
# epoch:293  d_loss:0.3760  g_loss:2.0430
# epoch:294  d_loss:0.4147  g_loss:2.1372
# epoch:295  d_loss:0.4405  g_loss:1.8581
# epoch:296  d_loss:0.4798  g_loss:2.2053
# epoch:297  d_loss:0.6955  g_loss:2.3619
# epoch:298  d_loss:0.5608  g_loss:2.1334
# epoch:299  d_loss:0.5663  g_loss:1.7602
# epoch:300  d_loss:0.7335  g_loss:1.5286
# epoch:301  d_loss:0.5831  g_loss:1.2158
# epoch:302  d_loss:0.7617  g_loss:1.3336
# epoch:303  d_loss:0.7020  g_loss:1.5860
# epoch:304  d_loss:0.7572  g_loss:1.4328
# epoch:305  d_loss:0.6589  g_loss:1.5922
# epoch:306  d_loss:0.5779  g_loss:1.6777
# epoch:307  d_loss:0.6342  g_loss:1.4510
# epoch:308  d_loss:0.4356  g_loss:1.4273
# epoch:309  d_loss:0.5729  g_loss:1.4769
# epoch:310  d_loss:0.5239  g_loss:1.8475
# epoch:311  d_loss:0.3743  g_loss:1.7074
# epoch:312  d_loss:0.4715  g_loss:1.4985
# epoch:313  d_loss:0.3910  g_loss:1.7962
# epoch:314  d_loss:0.4417  g_loss:2.0036
# epoch:315  d_loss:0.3837  g_loss:1.7532
# epoch:316  d_loss:0.3774  g_loss:2.0256
# epoch:317  d_loss:0.3675  g_loss:1.9732
# epoch:318  d_loss:0.4197  g_loss:2.1013
# epoch:319  d_loss:0.3180  g_loss:2.4830
# epoch:320  d_loss:0.3895  g_loss:2.3700
# epoch:321  d_loss:0.3559  g_loss:2.2019
# epoch:322  d_loss:0.3658  g_loss:1.8169
# epoch:323  d_loss:0.3295  g_loss:2.1821
# epoch:324  d_loss:0.3711  g_loss:2.0587
# epoch:325  d_loss:0.2964  g_loss:2.2564
# epoch:326  d_loss:0.5091  g_loss:1.8603
# epoch:327  d_loss:0.3541  g_loss:1.9045
# epoch:328  d_loss:0.3072  g_loss:1.9463
# epoch:329  d_loss:0.3874  g_loss:2.2388
# epoch:330  d_loss:0.4098  g_loss:2.5273
# epoch:331  d_loss:0.3820  g_loss:2.6202
# epoch:332  d_loss:0.4767  g_loss:2.0017
# epoch:333  d_loss:0.3920  g_loss:1.9901
# epoch:334  d_loss:0.4381  g_loss:1.6475
# epoch:335  d_loss:0.5298  g_loss:1.3554
# epoch:336  d_loss:0.2979  g_loss:1.8736
# epoch:337  d_loss:0.4650  g_loss:1.7783
# epoch:338  d_loss:0.4784  g_loss:2.1387
# epoch:339  d_loss:0.4534  g_loss:2.1926
# epoch:340  d_loss:0.3741  g_loss:2.2727
# epoch:341  d_loss:0.5565  g_loss:1.6136
# epoch:342  d_loss:0.4790  g_loss:1.6869
# epoch:343  d_loss:0.6332  g_loss:1.7434
# epoch:344  d_loss:0.5224  g_loss:1.7808
# epoch:345  d_loss:0.5107  g_loss:1.9940
# epoch:346  d_loss:0.7332  g_loss:1.7869
# epoch:347  d_loss:0.4816  g_loss:1.9335
# epoch:348  d_loss:0.3662  g_loss:2.2871
# epoch:349  d_loss:0.4378  g_loss:1.7954
# epoch:350  d_loss:0.6502  g_loss:1.5663
# epoch:351  d_loss:0.4563  g_loss:1.6393
# epoch:352  d_loss:0.3377  g_loss:1.6626
# epoch:353  d_loss:0.4574  g_loss:2.1658
# epoch:354  d_loss:0.7082  g_loss:1.7476
# epoch:355  d_loss:0.5424  g_loss:1.7232
# epoch:356  d_loss:0.4890  g_loss:1.5710
# epoch:357  d_loss:0.4133  g_loss:2.0579
# epoch:358  d_loss:0.3726  g_loss:2.3437
# epoch:359  d_loss:0.2870  g_loss:2.5670
# epoch:360  d_loss:0.3923  g_loss:2.4356
# epoch:361  d_loss:0.2346  g_loss:2.5216
# epoch:362  d_loss:0.3144  g_loss:2.6573
# epoch:363  d_loss:0.4818  g_loss:1.8507
# epoch:364  d_loss:0.2614  g_loss:2.6318
# epoch:365  d_loss:0.3763  g_loss:2.6830
# epoch:366  d_loss:0.2489  g_loss:2.8760
# epoch:367  d_loss:0.3814  g_loss:2.8326
# epoch:368  d_loss:0.4008  g_loss:2.4659
# epoch:369  d_loss:0.3127  g_loss:2.2267
# epoch:370  d_loss:0.4658  g_loss:2.4836
# epoch:371  d_loss:0.2201  g_loss:2.3032
# epoch:372  d_loss:0.2904  g_loss:2.4824
# epoch:373  d_loss:0.1897  g_loss:2.5904
# epoch:374  d_loss:0.2416  g_loss:2.5779
# epoch:375  d_loss:0.3445  g_loss:3.0807
# epoch:376  d_loss:0.3907  g_loss:2.7784
# epoch:377  d_loss:0.3926  g_loss:2.5742
# epoch:378  d_loss:0.3183  g_loss:3.0678
# epoch:379  d_loss:0.2780  g_loss:3.0485
# epoch:380  d_loss:0.4457  g_loss:2.9844
# epoch:381  d_loss:0.3585  g_loss:2.6856
# epoch:382  d_loss:0.2392  g_loss:2.3842
# epoch:383  d_loss:0.3498  g_loss:2.4735
# epoch:384  d_loss:0.3317  g_loss:2.0642
# epoch:385  d_loss:0.3907  g_loss:2.0095
# epoch:386  d_loss:0.3483  g_loss:2.5221
# epoch:387  d_loss:0.2071  g_loss:2.5505
# epoch:388  d_loss:0.3592  g_loss:2.5302
# epoch:389  d_loss:0.2188  g_loss:2.6335
# epoch:390  d_loss:0.3293  g_loss:2.3597
# epoch:391  d_loss:0.2781  g_loss:1.9272
# epoch:392  d_loss:0.3505  g_loss:2.1625
# epoch:393  d_loss:0.3787  g_loss:2.4686
# epoch:394  d_loss:0.3296  g_loss:2.0695
# epoch:395  d_loss:0.3705  g_loss:2.5792
# epoch:396  d_loss:0.3637  g_loss:2.1386
# epoch:397  d_loss:0.3013  g_loss:2.4565
# epoch:398  d_loss:0.3538  g_loss:1.9608
# epoch:399  d_loss:0.5095  g_loss:1.8906
# epoch:400  d_loss:0.3778  g_loss:1.7219
# epoch:401  d_loss:0.3808  g_loss:1.9952
# epoch:402  d_loss:0.3475  g_loss:1.7134
# epoch:403  d_loss:0.5539  g_loss:1.8785
# epoch:404  d_loss:0.3886  g_loss:1.9530
# epoch:405  d_loss:0.4211  g_loss:1.9753
# epoch:406  d_loss:0.4331  g_loss:1.7839
# epoch:407  d_loss:0.3216  g_loss:1.6785
# epoch:408  d_loss:0.4217  g_loss:1.6056
# epoch:409  d_loss:0.3409  g_loss:2.0062
# epoch:410  d_loss:0.4742  g_loss:1.8336
# epoch:411  d_loss:0.4434  g_loss:2.0782
# epoch:412  d_loss:0.4309  g_loss:2.0863
# epoch:413  d_loss:0.4622  g_loss:1.9455
# epoch:414  d_loss:0.4975  g_loss:1.4396
# epoch:415  d_loss:0.4026  g_loss:1.7971
# epoch:416  d_loss:0.3654  g_loss:1.7670
# epoch:417  d_loss:0.2740  g_loss:1.8422
# epoch:418  d_loss:0.3675  g_loss:2.3597
# epoch:419  d_loss:0.3618  g_loss:2.0826
# epoch:420  d_loss:0.3441  g_loss:1.8540
# epoch:421  d_loss:0.2853  g_loss:1.8369
# epoch:422  d_loss:0.4885  g_loss:1.4561
# epoch:423  d_loss:0.3764  g_loss:1.5927
# epoch:424  d_loss:0.3138  g_loss:2.2871
# epoch:425  d_loss:0.2175  g_loss:2.7772
# epoch:426  d_loss:0.3296  g_loss:2.7447
# epoch:427  d_loss:0.4341  g_loss:2.1326
# epoch:428  d_loss:0.3782  g_loss:2.2039
# epoch:429  d_loss:0.4575  g_loss:2.1902
# epoch:430  d_loss:0.3115  g_loss:2.0322
# epoch:431  d_loss:0.3270  g_loss:2.4205
# epoch:432  d_loss:0.3396  g_loss:2.5504
# epoch:433  d_loss:0.2913  g_loss:2.9115
# epoch:434  d_loss:0.3854  g_loss:1.9763
# epoch:435  d_loss:0.3258  g_loss:1.7596
# epoch:436  d_loss:0.3162  g_loss:1.8511
# epoch:437  d_loss:0.3308  g_loss:2.3623
# epoch:438  d_loss:0.3362  g_loss:2.5940
# epoch:439  d_loss:0.2345  g_loss:3.0566
# epoch:440  d_loss:0.3095  g_loss:2.5387
# epoch:441  d_loss:0.2650  g_loss:2.2027
# epoch:442  d_loss:0.2495  g_loss:2.0117
# epoch:443  d_loss:0.2093  g_loss:2.5907
# epoch:444  d_loss:0.4311  g_loss:2.5075
# epoch:445  d_loss:0.2207  g_loss:2.5987
# epoch:446  d_loss:0.2676  g_loss:2.5052
# epoch:447  d_loss:0.3113  g_loss:2.3635
# epoch:448  d_loss:0.2804  g_loss:2.4781
# epoch:449  d_loss:0.3328  g_loss:2.9353
# epoch:450  d_loss:0.2815  g_loss:2.8969
# epoch:451  d_loss:0.2325  g_loss:3.1920
# epoch:452  d_loss:0.3781  g_loss:2.4559
# epoch:453  d_loss:0.2999  g_loss:2.4014
# epoch:454  d_loss:0.3162  g_loss:2.4605
# epoch:455  d_loss:0.4208  g_loss:2.2081
# epoch:456  d_loss:0.4249  g_loss:2.2900
# epoch:457  d_loss:0.3685  g_loss:2.3059
# epoch:458  d_loss:0.4288  g_loss:2.0925
# epoch:459  d_loss:0.3214  g_loss:2.3967
# epoch:460  d_loss:0.3547  g_loss:2.3944
# epoch:461  d_loss:0.4282  g_loss:1.9449
# epoch:462  d_loss:0.3746  g_loss:1.5138
# epoch:463  d_loss:0.4802  g_loss:1.7111
# epoch:464  d_loss:0.3809  g_loss:2.2039
# epoch:465  d_loss:0.4171  g_loss:2.2064
# epoch:466  d_loss:0.4015  g_loss:2.2996
# epoch:467  d_loss:0.4434  g_loss:2.1106
# epoch:468  d_loss:0.3642  g_loss:1.5526
# epoch:469  d_loss:0.3335  g_loss:2.4222
# epoch:470  d_loss:0.4020  g_loss:2.3418
# epoch:471  d_loss:0.5158  g_loss:1.9908
# epoch:472  d_loss:0.4288  g_loss:1.9440
# epoch:473  d_loss:0.3114  g_loss:1.8875
# epoch:474  d_loss:0.4007  g_loss:1.9121
# epoch:475  d_loss:0.3869  g_loss:1.8495
# epoch:476  d_loss:0.2968  g_loss:2.0626
# epoch:477  d_loss:0.3402  g_loss:1.8796
# epoch:478  d_loss:0.2904  g_loss:2.7621
# epoch:479  d_loss:0.2946  g_loss:2.8397
# epoch:480  d_loss:0.2593  g_loss:2.4421
# epoch:481  d_loss:0.2803  g_loss:1.9523
# epoch:482  d_loss:0.3637  g_loss:2.0128
# epoch:483  d_loss:0.2364  g_loss:2.3747
# epoch:484  d_loss:0.1455  g_loss:2.5451
# epoch:485  d_loss:0.2013  g_loss:2.8916
# epoch:486  d_loss:0.2204  g_loss:2.4036
# epoch:487  d_loss:0.2788  g_loss:2.4520
# epoch:488  d_loss:0.3089  g_loss:2.4905
# epoch:489  d_loss:0.1939  g_loss:2.7513
# epoch:490  d_loss:0.2047  g_loss:3.1869
# epoch:491  d_loss:0.2284  g_loss:2.9422
# epoch:492  d_loss:0.1542  g_loss:2.6676
# epoch:493  d_loss:0.1618  g_loss:2.7690
# epoch:494  d_loss:0.2471  g_loss:2.6390
# epoch:495  d_loss:0.2044  g_loss:2.8625
# epoch:496  d_loss:0.2157  g_loss:2.9762
# epoch:497  d_loss:0.3189  g_loss:3.0940
# epoch:498  d_loss:0.2538  g_loss:2.7627
# epoch:499  d_loss:0.1895  g_loss:2.9484
# epoch:500  d_loss:0.1427  g_loss:2.4228
# epoch:501  d_loss:0.2269  g_loss:2.7794
# epoch:502  d_loss:0.2180  g_loss:2.5905
# epoch:503  d_loss:0.1459  g_loss:3.1219
# epoch:504  d_loss:0.2513  g_loss:2.6598
# epoch:505  d_loss:0.2248  g_loss:2.6008
# epoch:506  d_loss:0.2615  g_loss:2.4884
# epoch:507  d_loss:0.3128  g_loss:2.2396
# epoch:508  d_loss:0.3312  g_loss:2.5656
# epoch:509  d_loss:0.1890  g_loss:3.0355
# epoch:510  d_loss:0.2680  g_loss:2.6661
# epoch:511  d_loss:0.3129  g_loss:2.9268
# epoch:512  d_loss:0.3139  g_loss:2.1015
# epoch:513  d_loss:0.4408  g_loss:2.5792
# epoch:514  d_loss:0.3081  g_loss:3.1770
# epoch:515  d_loss:0.3963  g_loss:3.4980
# epoch:516  d_loss:0.3387  g_loss:3.2335
# epoch:517  d_loss:0.3274  g_loss:2.0843
# epoch:518  d_loss:0.4086  g_loss:2.8337
# epoch:519  d_loss:0.4207  g_loss:3.0065
# epoch:520  d_loss:0.2696  g_loss:3.2945
# epoch:521  d_loss:0.4349  g_loss:2.2135
# epoch:522  d_loss:0.4620  g_loss:1.8181
# epoch:523  d_loss:0.3008  g_loss:2.8904
# epoch:524  d_loss:0.2717  g_loss:3.2375
# epoch:525  d_loss:0.3159  g_loss:3.0492
# epoch:526  d_loss:0.2395  g_loss:2.8824
# epoch:527  d_loss:0.2100  g_loss:2.6899
# epoch:528  d_loss:0.2651  g_loss:2.6960
# epoch:529  d_loss:0.1588  g_loss:3.3038
# epoch:530  d_loss:0.2086  g_loss:2.7754
# epoch:531  d_loss:0.1213  g_loss:3.4133
# epoch:532  d_loss:0.1480  g_loss:2.9164
# epoch:533  d_loss:0.1893  g_loss:2.9242
# epoch:534  d_loss:0.1569  g_loss:2.9843
# epoch:535  d_loss:0.0834  g_loss:3.1332
# epoch:536  d_loss:0.1477  g_loss:3.0254
# epoch:537  d_loss:0.1267  g_loss:3.4614
# epoch:538  d_loss:0.1530  g_loss:3.3707
# epoch:539  d_loss:0.2124  g_loss:3.2910
# epoch:540  d_loss:0.1563  g_loss:3.2888
# epoch:541  d_loss:0.1580  g_loss:3.5189
# epoch:542  d_loss:0.1987  g_loss:3.0513
# epoch:543  d_loss:0.2469  g_loss:2.8407
# epoch:544  d_loss:0.2577  g_loss:2.0281
# epoch:545  d_loss:0.2236  g_loss:2.6030
# epoch:546  d_loss:0.2783  g_loss:2.5676
# epoch:547  d_loss:0.1936  g_loss:2.4645
# epoch:548  d_loss:0.2212  g_loss:2.7448
# epoch:549  d_loss:0.3558  g_loss:2.5738
# epoch:550  d_loss:0.2838  g_loss:2.4827
# epoch:551  d_loss:0.2331  g_loss:2.6685
# epoch:552  d_loss:0.4518  g_loss:2.3236
# epoch:553  d_loss:0.5383  g_loss:1.9856
# epoch:554  d_loss:0.4624  g_loss:1.8993
# epoch:555  d_loss:0.3114  g_loss:2.2719
# epoch:556  d_loss:0.3498  g_loss:2.8712
# epoch:557  d_loss:0.3762  g_loss:2.2046
# epoch:558  d_loss:0.4382  g_loss:1.8473
# epoch:559  d_loss:0.1733  g_loss:2.5733
# epoch:560  d_loss:0.2257  g_loss:2.7700
# epoch:561  d_loss:0.1776  g_loss:2.7022
# epoch:562  d_loss:0.1595  g_loss:3.3526
# epoch:563  d_loss:0.1510  g_loss:3.2359
# epoch:564  d_loss:0.4008  g_loss:2.4902
# epoch:565  d_loss:0.1889  g_loss:2.7498
# epoch:566  d_loss:0.1862  g_loss:3.3210
# epoch:567  d_loss:0.1669  g_loss:3.6364
# epoch:568  d_loss:0.2880  g_loss:3.0470
# epoch:569  d_loss:0.1625  g_loss:3.2563
# epoch:570  d_loss:0.1525  g_loss:2.6482
# epoch:571  d_loss:0.2719  g_loss:1.7505
# epoch:572  d_loss:0.0749  g_loss:2.5591
# epoch:573  d_loss:0.1988  g_loss:2.6706
# epoch:574  d_loss:0.1536  g_loss:3.1855
# epoch:575  d_loss:0.1282  g_loss:3.1152
# epoch:576  d_loss:0.2031  g_loss:3.2938
# epoch:577  d_loss:0.0980  g_loss:2.9625
# epoch:578  d_loss:0.1711  g_loss:2.8477
# epoch:579  d_loss:0.2058  g_loss:3.0002
# epoch:580  d_loss:0.1406  g_loss:2.9694
# epoch:581  d_loss:0.0989  g_loss:3.3688
# epoch:582  d_loss:0.1631  g_loss:3.3149
# epoch:583  d_loss:0.1419  g_loss:2.8564
# epoch:584  d_loss:0.1894  g_loss:2.9474
# epoch:585  d_loss:0.1572  g_loss:2.7320
# epoch:586  d_loss:0.1590  g_loss:2.2988
# epoch:587  d_loss:0.2037  g_loss:2.7292
# epoch:588  d_loss:0.1657  g_loss:3.9033
# epoch:589  d_loss:0.3125  g_loss:3.6085
# epoch:590  d_loss:0.2996  g_loss:2.9347
# epoch:591  d_loss:0.2645  g_loss:2.8145
# epoch:592  d_loss:0.2572  g_loss:1.8740
# epoch:593  d_loss:0.2020  g_loss:2.4122
# epoch:594  d_loss:0.2226  g_loss:2.4796
# epoch:595  d_loss:0.2971  g_loss:2.6779
# epoch:596  d_loss:0.3498  g_loss:1.8062
# epoch:597  d_loss:0.3515  g_loss:2.1335
# epoch:598  d_loss:0.3460  g_loss:2.2480
# epoch:599  d_loss:0.2580  g_loss:2.5508
# epoch:600  d_loss:0.4074  g_loss:2.8610
# epoch:601  d_loss:0.3912  g_loss:1.8935
# epoch:602  d_loss:0.4325  g_loss:1.3667
# epoch:603  d_loss:0.5127  g_loss:1.9141
# epoch:604  d_loss:0.2887  g_loss:2.7569
# epoch:605  d_loss:0.2410  g_loss:3.1917
# epoch:606  d_loss:0.5665  g_loss:1.9910
# epoch:607  d_loss:0.4637  g_loss:1.1046
# epoch:608  d_loss:0.4598  g_loss:1.2170
# epoch:609  d_loss:0.3426  g_loss:2.1551
# epoch:610  d_loss:0.2870  g_loss:2.6542
# epoch:611  d_loss:0.3005  g_loss:3.1034
# epoch:612  d_loss:0.3274  g_loss:2.2770
# epoch:613  d_loss:0.3237  g_loss:1.8120
# epoch:614  d_loss:0.5422  g_loss:1.2358
# epoch:615  d_loss:0.7164  g_loss:1.0639
# epoch:616  d_loss:0.3410  g_loss:2.2515
# epoch:617  d_loss:0.3199  g_loss:2.4371
# epoch:618  d_loss:0.4010  g_loss:2.4136
# epoch:619  d_loss:0.2997  g_loss:2.0087
# epoch:620  d_loss:0.3350  g_loss:1.3234
# epoch:621  d_loss:0.2383  g_loss:1.3117
# epoch:622  d_loss:0.2877  g_loss:1.2598
# epoch:623  d_loss:0.2224  g_loss:1.7261
# epoch:624  d_loss:0.4430  g_loss:1.1931
# epoch:625  d_loss:0.3489  g_loss:2.0139
# epoch:626  d_loss:0.3360  g_loss:2.4297
# epoch:627  d_loss:0.3279  g_loss:3.0638
# epoch:628  d_loss:0.4832  g_loss:2.2298
# epoch:629  d_loss:0.4144  g_loss:1.7625
# epoch:630  d_loss:0.6605  g_loss:1.4244
# epoch:631  d_loss:0.6263  g_loss:0.9185
# epoch:632  d_loss:0.6138  g_loss:2.0407
# epoch:633  d_loss:0.6344  g_loss:2.1794
# epoch:634  d_loss:0.6210  g_loss:2.3777
# epoch:635  d_loss:0.5981  g_loss:1.9430
# epoch:636  d_loss:0.6265  g_loss:1.5910
# epoch:637  d_loss:0.5103  g_loss:1.7198
# epoch:638  d_loss:0.6296  g_loss:1.7656
# epoch:639  d_loss:0.6324  g_loss:1.3653
# epoch:640  d_loss:0.8214  g_loss:1.7308
# epoch:641  d_loss:0.7261  g_loss:1.4235
# epoch:642  d_loss:0.4005  g_loss:1.3792
# epoch:643  d_loss:0.5183  g_loss:1.3920
# epoch:644  d_loss:0.7132  g_loss:1.5693
# epoch:645  d_loss:0.6904  g_loss:1.3200
# epoch:646  d_loss:0.4707  g_loss:1.3661
# epoch:647  d_loss:0.6638  g_loss:1.0861
# epoch:648  d_loss:0.4774  g_loss:1.1911
# epoch:649  d_loss:0.5343  g_loss:1.4009
# epoch:650  d_loss:0.3698  g_loss:1.7073
# epoch:651  d_loss:0.4560  g_loss:1.9864
# epoch:652  d_loss:0.3298  g_loss:1.7224
# epoch:653  d_loss:0.3686  g_loss:1.5362
# epoch:654  d_loss:0.2614  g_loss:1.5196
# epoch:655  d_loss:0.2227  g_loss:2.0583
# epoch:656  d_loss:0.2462  g_loss:1.7009
# epoch:657  d_loss:0.1891  g_loss:2.0333
# epoch:658  d_loss:0.2622  g_loss:1.6585
# epoch:659  d_loss:0.3665  g_loss:1.5515
# epoch:660  d_loss:0.3947  g_loss:1.3212
# epoch:661  d_loss:0.2580  g_loss:1.9084
# epoch:662  d_loss:0.3325  g_loss:2.1427
# epoch:663  d_loss:0.4077  g_loss:1.7655
# epoch:664  d_loss:0.6355  g_loss:1.5058
# epoch:665  d_loss:0.9522  g_loss:1.1302
# epoch:666  d_loss:0.7647  g_loss:1.2474
# epoch:667  d_loss:0.6399  g_loss:1.4095
# epoch:668  d_loss:0.7995  g_loss:0.9844
# epoch:669  d_loss:0.9035  g_loss:1.1768
# epoch:670  d_loss:1.0550  g_loss:0.9490
# epoch:671  d_loss:0.8503  g_loss:1.0338
# epoch:672  d_loss:0.7861  g_loss:1.2864
# epoch:673  d_loss:0.6137  g_loss:1.4602
# epoch:674  d_loss:0.3226  g_loss:1.8994
# epoch:675  d_loss:0.2920  g_loss:2.8041
# epoch:676  d_loss:0.3772  g_loss:2.2217
# epoch:677  d_loss:0.3771  g_loss:2.3643
# epoch:678  d_loss:0.5965  g_loss:2.2035
# epoch:679  d_loss:0.5230  g_loss:2.5579
# epoch:680  d_loss:0.3685  g_loss:2.9272
# epoch:681  d_loss:0.3443  g_loss:3.7787
# epoch:682  d_loss:0.1927  g_loss:3.4870
# epoch:683  d_loss:0.1944  g_loss:4.4460
# epoch:684  d_loss:0.1448  g_loss:4.3588
# epoch:685  d_loss:0.2114  g_loss:3.4420
# epoch:686  d_loss:0.3186  g_loss:3.3607
# epoch:687  d_loss:0.3463  g_loss:2.9940
# epoch:688  d_loss:0.4756  g_loss:2.7403
# epoch:689  d_loss:0.3214  g_loss:2.8437
# epoch:690  d_loss:0.6430  g_loss:2.6499
# epoch:691  d_loss:0.7616  g_loss:1.9006
# epoch:692  d_loss:1.0002  g_loss:1.6058
# epoch:693  d_loss:1.1234  g_loss:1.3431
# epoch:694  d_loss:1.1066  g_loss:1.0515
# epoch:695  d_loss:1.1195  g_loss:1.1195
# epoch:696  d_loss:0.8569  g_loss:1.4236
# epoch:697  d_loss:0.8586  g_loss:1.2481
# epoch:698  d_loss:1.0801  g_loss:1.1579
# epoch:699  d_loss:1.1793  g_loss:0.8354
# epoch:700  d_loss:0.7821  g_loss:0.9732
# epoch:701  d_loss:0.5939  g_loss:1.5145
# epoch:702  d_loss:0.4440  g_loss:1.7348
# epoch:703  d_loss:0.5711  g_loss:1.8437
# epoch:704  d_loss:0.2411  g_loss:2.2209
# epoch:705  d_loss:0.2722  g_loss:1.9526
# epoch:706  d_loss:0.2450  g_loss:2.1592
# epoch:707  d_loss:0.2349  g_loss:2.0575
# epoch:708  d_loss:0.3830  g_loss:2.4448
# epoch:709  d_loss:0.2284  g_loss:2.4547
# epoch:710  d_loss:0.1758  g_loss:2.6859
# epoch:711  d_loss:0.1832  g_loss:2.5194
# epoch:712  d_loss:0.2519  g_loss:2.3025
# epoch:713  d_loss:0.2811  g_loss:2.2924
# epoch:714  d_loss:0.2751  g_loss:2.2028
# epoch:715  d_loss:0.2324  g_loss:2.3192
# epoch:716  d_loss:0.2115  g_loss:2.2123
# epoch:717  d_loss:0.2083  g_loss:2.6516
# epoch:718  d_loss:0.2249  g_loss:2.3296
# epoch:719  d_loss:0.3030  g_loss:2.3511
# epoch:720  d_loss:0.4160  g_loss:2.0832
# epoch:721  d_loss:0.3035  g_loss:2.5451
# epoch:722  d_loss:0.3269  g_loss:2.3266
# epoch:723  d_loss:0.3902  g_loss:1.5808
# epoch:724  d_loss:0.4564  g_loss:1.8365
# epoch:725  d_loss:0.4607  g_loss:2.0870
# epoch:726  d_loss:0.4431  g_loss:1.5195
# epoch:727  d_loss:0.5026  g_loss:1.8281
# epoch:728  d_loss:0.5536  g_loss:1.8447
# epoch:729  d_loss:0.3930  g_loss:1.5547
# epoch:730  d_loss:0.5388  g_loss:1.3884
# epoch:731  d_loss:0.5406  g_loss:1.5280
# epoch:732  d_loss:0.3558  g_loss:1.8627
# epoch:733  d_loss:0.8030  g_loss:1.4816
# epoch:734  d_loss:0.6072  g_loss:1.3741
# epoch:735  d_loss:0.5376  g_loss:1.4312
# epoch:736  d_loss:0.6053  g_loss:1.4121
# epoch:737  d_loss:0.5064  g_loss:1.2602
# epoch:738  d_loss:0.5480  g_loss:1.2741
# epoch:739  d_loss:0.4753  g_loss:1.3500
# epoch:740  d_loss:0.5739  g_loss:1.8495
# epoch:741  d_loss:0.5189  g_loss:1.7418
# epoch:742  d_loss:0.3355  g_loss:1.8921
# epoch:743  d_loss:0.4350  g_loss:1.6998
# epoch:744  d_loss:0.3313  g_loss:1.5706
# epoch:745  d_loss:0.3121  g_loss:1.5076
# epoch:746  d_loss:0.4591  g_loss:1.6638
# epoch:747  d_loss:0.2325  g_loss:2.2431
# epoch:748  d_loss:0.3747  g_loss:1.9075
# epoch:749  d_loss:0.3395  g_loss:2.6548
# epoch:750  d_loss:0.2627  g_loss:2.3962
# epoch:751  d_loss:0.4598  g_loss:2.5985
# epoch:752  d_loss:0.3766  g_loss:2.0362
# epoch:753  d_loss:0.2437  g_loss:2.0249
# epoch:754  d_loss:0.1888  g_loss:2.2378
# epoch:755  d_loss:0.2352  g_loss:2.0793
# epoch:756  d_loss:0.3407  g_loss:2.4092
# epoch:757  d_loss:0.2621  g_loss:2.6809
# epoch:758  d_loss:0.3623  g_loss:2.2153
# epoch:759  d_loss:0.3159  g_loss:1.8976
# epoch:760  d_loss:0.3048  g_loss:2.0143
# epoch:761  d_loss:0.3854  g_loss:1.6493
# epoch:762  d_loss:0.3908  g_loss:1.5770
# epoch:763  d_loss:0.4429  g_loss:1.3901
# epoch:764  d_loss:0.5114  g_loss:1.4572
# epoch:765  d_loss:0.5595  g_loss:1.9754
# epoch:766  d_loss:0.5527  g_loss:2.0831
# epoch:767  d_loss:0.5229  g_loss:1.8233
# epoch:768  d_loss:0.4311  g_loss:1.9981
# epoch:769  d_loss:0.3673  g_loss:1.9616
# epoch:770  d_loss:0.6064  g_loss:2.0809
# epoch:771  d_loss:0.4730  g_loss:1.8988
# epoch:772  d_loss:0.6488  g_loss:1.7534
# epoch:773  d_loss:0.6693  g_loss:2.0251
# epoch:774  d_loss:0.5222  g_loss:1.7548
# epoch:775  d_loss:0.5658  g_loss:1.9245
# epoch:776  d_loss:0.5386  g_loss:1.7546
# epoch:777  d_loss:0.5385  g_loss:1.5171
# epoch:778  d_loss:0.4718  g_loss:1.5138
# epoch:779  d_loss:0.5436  g_loss:1.5756
# epoch:780  d_loss:0.5001  g_loss:1.4185
# epoch:781  d_loss:0.5259  g_loss:1.4412
# epoch:782  d_loss:0.4751  g_loss:1.6695
# epoch:783  d_loss:0.4329  g_loss:2.0555
# epoch:784  d_loss:0.4050  g_loss:1.8055
# epoch:785  d_loss:0.4040  g_loss:2.2545
# epoch:786  d_loss:0.4160  g_loss:2.0387
# epoch:787  d_loss:0.5735  g_loss:1.8531
# epoch:788  d_loss:0.6167  g_loss:1.5133
# epoch:789  d_loss:0.4444  g_loss:1.4131
# epoch:790  d_loss:0.5916  g_loss:1.5153
# epoch:791  d_loss:0.4866  g_loss:1.7018
# epoch:792  d_loss:0.4726  g_loss:1.7217
# epoch:793  d_loss:0.8506  g_loss:1.5413
# epoch:794  d_loss:0.6092  g_loss:1.6135
# epoch:795  d_loss:0.5097  g_loss:1.1004
# epoch:796  d_loss:0.5992  g_loss:1.2129
# epoch:797  d_loss:0.4572  g_loss:1.5090
# epoch:798  d_loss:0.5383  g_loss:1.5061
# epoch:799  d_loss:0.5469  g_loss:1.8614
# epoch:800  d_loss:0.5494  g_loss:1.7177
# epoch:801  d_loss:0.3755  g_loss:2.0865
# epoch:802  d_loss:0.4120  g_loss:1.5491
# epoch:803  d_loss:0.3881  g_loss:1.6551
# epoch:804  d_loss:0.4074  g_loss:1.7860
# epoch:805  d_loss:0.4208  g_loss:1.8881
# epoch:806  d_loss:0.2064  g_loss:2.4788
# epoch:807  d_loss:0.2346  g_loss:2.3243
# epoch:808  d_loss:0.2859  g_loss:2.2914
# epoch:809  d_loss:0.4005  g_loss:2.6275
# epoch:810  d_loss:0.3553  g_loss:1.9212
# epoch:811  d_loss:0.3664  g_loss:2.4469
# epoch:812  d_loss:0.3882  g_loss:3.1165
# epoch:813  d_loss:0.3621  g_loss:2.3096
# epoch:814  d_loss:0.3619  g_loss:2.8860
# epoch:815  d_loss:0.3565  g_loss:2.2271
# epoch:816  d_loss:0.5774  g_loss:1.6211
# epoch:817  d_loss:0.4816  g_loss:1.8453
# epoch:818  d_loss:0.4289  g_loss:1.7983
# epoch:819  d_loss:0.3729  g_loss:2.1931
# epoch:820  d_loss:0.4260  g_loss:2.5050
# epoch:821  d_loss:0.5045  g_loss:2.7166
# epoch:822  d_loss:0.3842  g_loss:2.7853
# epoch:823  d_loss:0.3690  g_loss:2.0727
# epoch:824  d_loss:0.4663  g_loss:1.9011
# epoch:825  d_loss:0.5042  g_loss:1.4018
# epoch:826  d_loss:0.5224  g_loss:1.7468
# epoch:827  d_loss:0.5079  g_loss:1.7103
# epoch:828  d_loss:0.4822  g_loss:1.8223
# epoch:829  d_loss:0.4487  g_loss:2.3431
# epoch:830  d_loss:0.5350  g_loss:1.7104
# epoch:831  d_loss:0.6535  g_loss:1.5093
# epoch:832  d_loss:0.5354  g_loss:1.1607
# epoch:833  d_loss:0.5598  g_loss:1.4719
# epoch:834  d_loss:0.6042  g_loss:1.6673
# epoch:835  d_loss:0.5288  g_loss:1.5971
# epoch:836  d_loss:0.6055  g_loss:1.9669
# epoch:837  d_loss:0.3386  g_loss:1.9901
# epoch:838  d_loss:0.3855  g_loss:2.2516
# epoch:839  d_loss:0.3538  g_loss:2.2810
# epoch:840  d_loss:0.3314  g_loss:2.1440
# epoch:841  d_loss:0.3933  g_loss:1.9089
# epoch:842  d_loss:0.5427  g_loss:1.9124
# epoch:843  d_loss:0.2426  g_loss:1.9906
# epoch:844  d_loss:0.4077  g_loss:2.1041
# epoch:845  d_loss:0.3624  g_loss:1.9665
# epoch:846  d_loss:0.4701  g_loss:1.6818
# epoch:847  d_loss:0.5463  g_loss:2.1126
# epoch:848  d_loss:0.3595  g_loss:2.4362
# epoch:849  d_loss:0.3308  g_loss:2.2805
# epoch:850  d_loss:0.3262  g_loss:2.1895
# epoch:851  d_loss:0.2852  g_loss:2.3290
# epoch:852  d_loss:0.2644  g_loss:2.2566
# epoch:853  d_loss:0.2893  g_loss:2.4636
# epoch:854  d_loss:0.3234  g_loss:2.9989
# epoch:855  d_loss:0.2088  g_loss:2.9007
# epoch:856  d_loss:0.1837  g_loss:3.5302
# epoch:857  d_loss:0.3064  g_loss:3.6258
# epoch:858  d_loss:0.2952  g_loss:3.2647
# epoch:859  d_loss:0.3446  g_loss:3.0363
# epoch:860  d_loss:0.2607  g_loss:2.6736
# epoch:861  d_loss:0.2636  g_loss:2.7611
# epoch:862  d_loss:0.2134  g_loss:2.1566
# epoch:863  d_loss:0.3247  g_loss:2.2956
# epoch:864  d_loss:0.2946  g_loss:2.7636
# epoch:865  d_loss:0.1690  g_loss:2.9606
# epoch:866  d_loss:0.3859  g_loss:3.0893
# epoch:867  d_loss:0.2938  g_loss:3.0949
# epoch:868  d_loss:0.4627  g_loss:2.9077
# epoch:869  d_loss:0.2871  g_loss:2.1948
# epoch:870  d_loss:0.4612  g_loss:2.0458
# epoch:871  d_loss:0.5682  g_loss:2.1974
# epoch:872  d_loss:0.3850  g_loss:2.3060
# epoch:873  d_loss:0.4026  g_loss:2.4907
# epoch:874  d_loss:0.2777  g_loss:2.4557
# epoch:875  d_loss:0.4189  g_loss:2.2873
# epoch:876  d_loss:0.3802  g_loss:2.5697
# epoch:877  d_loss:0.3741  g_loss:2.1688
# epoch:878  d_loss:0.4382  g_loss:2.0065
# epoch:879  d_loss:0.6553  g_loss:1.6966
# epoch:880  d_loss:0.5007  g_loss:1.8824
# epoch:881  d_loss:0.4776  g_loss:2.4088
# epoch:882  d_loss:0.4030  g_loss:2.4399
# epoch:883  d_loss:0.5617  g_loss:2.1189
# epoch:884  d_loss:0.7128  g_loss:1.2557
# epoch:885  d_loss:0.5007  g_loss:1.8938
# epoch:886  d_loss:0.4512  g_loss:2.1019
# epoch:887  d_loss:0.4657  g_loss:2.4865
# epoch:888  d_loss:0.5628  g_loss:2.3996
# epoch:889  d_loss:0.4462  g_loss:1.9231
# epoch:890  d_loss:0.3878  g_loss:1.8004
# epoch:891  d_loss:0.4959  g_loss:1.8003
# epoch:892  d_loss:0.4408  g_loss:2.0734
# epoch:893  d_loss:0.3507  g_loss:2.4636
# epoch:894  d_loss:0.3971  g_loss:2.0389
# epoch:895  d_loss:0.4077  g_loss:2.2808
# epoch:896  d_loss:0.4523  g_loss:2.0854
# epoch:897  d_loss:0.3260  g_loss:2.4193
# epoch:898  d_loss:0.2919  g_loss:1.9315
# epoch:899  d_loss:0.3445  g_loss:2.0544
# epoch:900  d_loss:0.2873  g_loss:2.0587
# epoch:901  d_loss:0.4264  g_loss:2.1220
# epoch:902  d_loss:0.4211  g_loss:2.1825
# epoch:903  d_loss:0.3944  g_loss:2.0753
# epoch:904  d_loss:0.3659  g_loss:2.2663
# epoch:905  d_loss:0.3235  g_loss:2.1102
# epoch:906  d_loss:0.3261  g_loss:2.4919
# epoch:907  d_loss:0.3338  g_loss:2.8423
# epoch:908  d_loss:0.4460  g_loss:2.1396
# epoch:909  d_loss:0.2556  g_loss:2.1019
# epoch:910  d_loss:0.3354  g_loss:2.2660
# epoch:911  d_loss:0.4199  g_loss:1.9746
# epoch:912  d_loss:0.2291  g_loss:2.8005
# epoch:913  d_loss:0.3029  g_loss:3.1347
# epoch:914  d_loss:0.3657  g_loss:2.7037
# epoch:915  d_loss:0.3268  g_loss:2.5195
# epoch:916  d_loss:0.3318  g_loss:1.9764
# epoch:917  d_loss:0.4064  g_loss:2.1153
# epoch:918  d_loss:0.3593  g_loss:2.1671
# epoch:919  d_loss:0.3238  g_loss:2.2238
# epoch:920  d_loss:0.3610  g_loss:2.5014
# epoch:921  d_loss:0.2996  g_loss:2.5373
# epoch:922  d_loss:0.2917  g_loss:2.3574
# epoch:923  d_loss:0.3770  g_loss:1.8568
# epoch:924  d_loss:0.3207  g_loss:2.0451
# epoch:925  d_loss:0.3978  g_loss:2.4519
# epoch:926  d_loss:0.3872  g_loss:2.1715
# epoch:927  d_loss:0.3193  g_loss:2.3289
# epoch:928  d_loss:0.2362  g_loss:1.9874
# epoch:929  d_loss:0.3589  g_loss:2.1648
# epoch:930  d_loss:0.2669  g_loss:2.2388
# epoch:931  d_loss:0.4784  g_loss:1.7123
# epoch:932  d_loss:0.3396  g_loss:1.9764
# epoch:933  d_loss:0.2954  g_loss:1.8571
# epoch:934  d_loss:0.4541  g_loss:1.9223
# epoch:935  d_loss:0.4161  g_loss:2.2969
# epoch:936  d_loss:0.2863  g_loss:2.5282
# epoch:937  d_loss:0.3568  g_loss:2.1217
# epoch:938  d_loss:0.3638  g_loss:2.1537
# epoch:939  d_loss:0.4370  g_loss:1.3912
# epoch:940  d_loss:0.5173  g_loss:1.7765
# epoch:941  d_loss:0.2652  g_loss:2.2136
# epoch:942  d_loss:0.3621  g_loss:2.2741
# epoch:943  d_loss:0.4683  g_loss:2.0334
# epoch:944  d_loss:0.3205  g_loss:2.1271
# epoch:945  d_loss:0.3097  g_loss:2.2773
# epoch:946  d_loss:0.3577  g_loss:1.9021
# epoch:947  d_loss:0.4650  g_loss:1.6065
# epoch:948  d_loss:0.3777  g_loss:1.7348
# epoch:949  d_loss:0.5412  g_loss:2.0094
# epoch:950  d_loss:0.3992  g_loss:1.8896
# epoch:951  d_loss:0.3907  g_loss:2.4387
# epoch:952  d_loss:0.4760  g_loss:1.9849
# epoch:953  d_loss:0.2847  g_loss:2.0685
# epoch:954  d_loss:0.3554  g_loss:1.7011
# epoch:955  d_loss:0.4815  g_loss:1.3454
# epoch:956  d_loss:0.3944  g_loss:1.5800
# epoch:957  d_loss:0.3286  g_loss:2.1368
# epoch:958  d_loss:0.4000  g_loss:2.1069
# epoch:959  d_loss:0.4778  g_loss:1.7318
# epoch:960  d_loss:0.3985  g_loss:1.6350
# epoch:961  d_loss:0.3787  g_loss:1.7180
# epoch:962  d_loss:0.2460  g_loss:1.9879
# epoch:963  d_loss:0.3072  g_loss:1.8258
# epoch:964  d_loss:0.3509  g_loss:2.1630
# epoch:965  d_loss:0.3972  g_loss:1.9031
# epoch:966  d_loss:0.4127  g_loss:1.6917
# epoch:967  d_loss:0.4326  g_loss:2.0031
# epoch:968  d_loss:0.3860  g_loss:1.9411
# epoch:969  d_loss:0.4925  g_loss:2.3705
# epoch:970  d_loss:0.4268  g_loss:2.0673
# epoch:971  d_loss:0.5762  g_loss:1.2568
# epoch:972  d_loss:0.5766  g_loss:1.4114
# epoch:973  d_loss:0.4084  g_loss:1.8690
# epoch:974  d_loss:0.3605  g_loss:2.4683
# epoch:975  d_loss:0.3359  g_loss:2.3821
# epoch:976  d_loss:0.3813  g_loss:1.9561
# epoch:977  d_loss:0.2756  g_loss:2.0158
# epoch:978  d_loss:0.3532  g_loss:1.6808
# epoch:979  d_loss:0.3680  g_loss:1.7971
# epoch:980  d_loss:0.3954  g_loss:1.9639
# epoch:981  d_loss:0.3216  g_loss:2.4518
# epoch:982  d_loss:0.4366  g_loss:2.0660
# epoch:983  d_loss:0.4752  g_loss:2.0430
# epoch:984  d_loss:0.4010  g_loss:1.7886
# epoch:985  d_loss:0.3950  g_loss:1.5224
# epoch:986  d_loss:0.3469  g_loss:1.9205
# epoch:987  d_loss:0.3804  g_loss:1.7678
# epoch:988  d_loss:0.3411  g_loss:2.1960
# epoch:989  d_loss:0.3824  g_loss:1.9004
# epoch:990  d_loss:0.3722  g_loss:1.9463
# epoch:991  d_loss:0.3676  g_loss:2.2673
# epoch:992  d_loss:0.4200  g_loss:1.9021
# epoch:993  d_loss:0.4955  g_loss:1.8918
# epoch:994  d_loss:0.3766  g_loss:1.8116
# epoch:995  d_loss:0.5300  g_loss:2.1131
# epoch:996  d_loss:0.5057  g_loss:2.0915
# epoch:997  d_loss:0.5335  g_loss:1.5494
# epoch:998  d_loss:0.5764  g_loss:1.4973
# epoch:999  d_loss:0.3647  g_loss:1.7987
# epoch:1000  d_loss:0.3178  g_loss:2.1277
# epoch:1001  d_loss:0.4749  g_loss:2.4521
# epoch:1002  d_loss:0.3945  g_loss:2.2834
# epoch:1003  d_loss:0.4635  g_loss:1.7972
# epoch:1004  d_loss:0.5324  g_loss:1.4752
# epoch:1005  d_loss:0.4410  g_loss:1.5485
# epoch:1006  d_loss:0.3989  g_loss:2.0662
# epoch:1007  d_loss:0.4471  g_loss:2.2774
# epoch:1008  d_loss:0.3751  g_loss:1.9511
# epoch:1009  d_loss:0.3561  g_loss:1.9816
# epoch:1010  d_loss:0.5463  g_loss:1.7323
# epoch:1011  d_loss:0.4062  g_loss:1.3405
# epoch:1012  d_loss:0.3829  g_loss:1.7808
# epoch:1013  d_loss:0.4682  g_loss:1.6452
# epoch:1014  d_loss:0.2779  g_loss:1.9397
# epoch:1015  d_loss:0.4148  g_loss:2.4234
# epoch:1016  d_loss:0.4665  g_loss:2.1494
# epoch:1017  d_loss:0.3759  g_loss:1.9342
# epoch:1018  d_loss:0.4845  g_loss:1.4158
# epoch:1019  d_loss:0.4535  g_loss:1.3142
# epoch:1020  d_loss:0.3119  g_loss:2.0587
# epoch:1021  d_loss:0.2852  g_loss:2.0732
# epoch:1022  d_loss:0.3723  g_loss:2.5301
# epoch:1023  d_loss:0.3216  g_loss:2.2949
# epoch:1024  d_loss:0.4620  g_loss:1.9512
# epoch:1025  d_loss:0.4939  g_loss:1.8696
# epoch:1026  d_loss:0.3594  g_loss:1.8355
# epoch:1027  d_loss:0.3300  g_loss:1.7144
# epoch:1028  d_loss:0.4445  g_loss:1.9197
# epoch:1029  d_loss:0.3328  g_loss:2.5492
# epoch:1030  d_loss:0.2997  g_loss:2.1375
# epoch:1031  d_loss:0.3455  g_loss:2.4180
# epoch:1032  d_loss:0.3568  g_loss:1.9185
# epoch:1033  d_loss:0.3461  g_loss:1.7719
# epoch:1034  d_loss:0.2802  g_loss:1.6973
# epoch:1035  d_loss:0.4434  g_loss:1.6265
# epoch:1036  d_loss:0.4442  g_loss:1.6552
# epoch:1037  d_loss:0.2965  g_loss:1.5966
# epoch:1038  d_loss:0.3713  g_loss:1.9146
# epoch:1039  d_loss:0.3232  g_loss:1.8221
# epoch:1040  d_loss:0.4602  g_loss:2.0460
# epoch:1041  d_loss:0.4397  g_loss:2.1173
# epoch:1042  d_loss:0.6239  g_loss:1.6225
# epoch:1043  d_loss:0.5298  g_loss:1.7023
# epoch:1044  d_loss:0.3891  g_loss:1.6142
# epoch:1045  d_loss:0.4510  g_loss:1.9226
# epoch:1046  d_loss:0.3945  g_loss:1.7290
# epoch:1047  d_loss:0.4707  g_loss:1.6933
# epoch:1048  d_loss:0.4491  g_loss:1.5644
# epoch:1049  d_loss:0.5065  g_loss:1.7382
# epoch:1050  d_loss:0.5085  g_loss:1.4236
# epoch:1051  d_loss:0.5502  g_loss:1.8144
# epoch:1052  d_loss:0.4086  g_loss:1.6634
# epoch:1053  d_loss:0.3812  g_loss:1.8087
# epoch:1054  d_loss:0.3634  g_loss:1.7156
# epoch:1055  d_loss:0.4784  g_loss:1.6363
# epoch:1056  d_loss:0.4099  g_loss:1.8965
# epoch:1057  d_loss:0.3977  g_loss:1.6628
# epoch:1058  d_loss:0.4920  g_loss:1.6043
# epoch:1059  d_loss:0.4717  g_loss:1.7541
# epoch:1060  d_loss:0.2983  g_loss:2.0396
# epoch:1061  d_loss:0.3775  g_loss:1.7092
# epoch:1062  d_loss:0.3470  g_loss:2.1620
# epoch:1063  d_loss:0.5011  g_loss:1.9342
# epoch:1064  d_loss:0.4856  g_loss:1.8109
# epoch:1065  d_loss:0.4934  g_loss:1.7876
# epoch:1066  d_loss:0.4862  g_loss:1.4857
# epoch:1067  d_loss:0.3571  g_loss:2.0542
# epoch:1068  d_loss:0.4447  g_loss:1.9841
# epoch:1069  d_loss:0.3160  g_loss:2.1695
# epoch:1070  d_loss:0.4018  g_loss:2.4748
# epoch:1071  d_loss:0.3488  g_loss:2.6725
# epoch:1072  d_loss:0.5334  g_loss:2.1554
# epoch:1073  d_loss:0.2771  g_loss:1.8469
# epoch:1074  d_loss:0.3359  g_loss:2.1725
# epoch:1075  d_loss:0.3523  g_loss:2.0792
# epoch:1076  d_loss:0.3511  g_loss:2.1026
# epoch:1077  d_loss:0.3121  g_loss:2.0719
# epoch:1078  d_loss:0.3298  g_loss:2.4300
# epoch:1079  d_loss:0.3840  g_loss:2.6897
# epoch:1080  d_loss:0.4590  g_loss:2.2078
# epoch:1081  d_loss:0.2862  g_loss:1.9989
# epoch:1082  d_loss:0.3572  g_loss:1.8705
# epoch:1083  d_loss:0.4256  g_loss:2.2034
# epoch:1084  d_loss:0.4074  g_loss:2.6128
# epoch:1085  d_loss:0.3988  g_loss:2.1602
# epoch:1086  d_loss:0.4271  g_loss:1.7423
# epoch:1087  d_loss:0.4310  g_loss:2.1230
# epoch:1088  d_loss:0.4021  g_loss:1.8477
# epoch:1089  d_loss:0.4528  g_loss:1.9473
# epoch:1090  d_loss:0.4436  g_loss:1.8002
# epoch:1091  d_loss:0.5490  g_loss:1.9925
# epoch:1092  d_loss:0.4195  g_loss:2.1166
# epoch:1093  d_loss:0.4859  g_loss:2.4108
# epoch:1094  d_loss:0.5355  g_loss:2.1265
# epoch:1095  d_loss:0.3805  g_loss:2.1085
# epoch:1096  d_loss:0.4992  g_loss:1.6426
# epoch:1097  d_loss:0.4081  g_loss:1.8950
# epoch:1098  d_loss:0.4398  g_loss:2.1227
# epoch:1099  d_loss:0.3892  g_loss:2.5375
# epoch:1100  d_loss:0.5066  g_loss:1.7465
# epoch:1101  d_loss:0.4493  g_loss:1.9279
# epoch:1102  d_loss:0.4388  g_loss:2.0688
# epoch:1103  d_loss:0.5396  g_loss:2.0076
# epoch:1104  d_loss:0.4368  g_loss:1.9213
# epoch:1105  d_loss:0.3795  g_loss:2.1003
# epoch:1106  d_loss:0.5111  g_loss:1.9547
# epoch:1107  d_loss:0.5148  g_loss:1.8904
# epoch:1108  d_loss:0.4081  g_loss:1.7812
# epoch:1109  d_loss:0.4668  g_loss:1.5809
# epoch:1110  d_loss:0.5311  g_loss:1.7463
# epoch:1111  d_loss:0.6731  g_loss:1.9010
# epoch:1112  d_loss:0.4136  g_loss:1.9794
# epoch:1113  d_loss:0.4028  g_loss:2.1790
# epoch:1114  d_loss:0.2343  g_loss:2.7782
# epoch:1115  d_loss:0.4217  g_loss:2.2338
# epoch:1116  d_loss:0.5176  g_loss:1.9124
# epoch:1117  d_loss:0.2960  g_loss:1.8112
# epoch:1118  d_loss:0.4836  g_loss:1.8820
# epoch:1119  d_loss:0.3465  g_loss:2.5958
# epoch:1120  d_loss:0.3939  g_loss:2.3818
# epoch:1121  d_loss:0.3517  g_loss:2.2334
# epoch:1122  d_loss:0.3593  g_loss:2.1679
# epoch:1123  d_loss:0.3863  g_loss:1.9215
# epoch:1124  d_loss:0.3521  g_loss:2.1752
# epoch:1125  d_loss:0.4825  g_loss:2.1753
# epoch:1126  d_loss:0.4644  g_loss:1.8903
# epoch:1127  d_loss:0.4178  g_loss:2.1537
# epoch:1128  d_loss:0.4482  g_loss:1.9838
# epoch:1129  d_loss:0.4190  g_loss:2.0586
# epoch:1130  d_loss:0.3202  g_loss:2.6670
# epoch:1131  d_loss:0.3463  g_loss:2.7799
# epoch:1132  d_loss:0.6008  g_loss:1.9772
# epoch:1133  d_loss:0.4705  g_loss:2.0399
# epoch:1134  d_loss:0.3161  g_loss:1.7742
# epoch:1135  d_loss:0.4273  g_loss:1.7217
# epoch:1136  d_loss:0.4266  g_loss:1.9823
# epoch:1137  d_loss:0.3364  g_loss:2.1086
# epoch:1138  d_loss:0.3888  g_loss:2.4487
# epoch:1139  d_loss:0.3203  g_loss:2.6228
# epoch:1140  d_loss:0.4356  g_loss:1.9526
# epoch:1141  d_loss:0.4682  g_loss:2.0336
# epoch:1142  d_loss:0.2024  g_loss:2.0904
# epoch:1143  d_loss:0.1924  g_loss:2.5644
# epoch:1144  d_loss:0.3176  g_loss:2.4804
# epoch:1145  d_loss:0.3595  g_loss:2.2796
# epoch:1146  d_loss:0.3002  g_loss:2.2314
# epoch:1147  d_loss:0.3201  g_loss:2.2033
# epoch:1148  d_loss:0.2988  g_loss:2.3701
# epoch:1149  d_loss:0.3023  g_loss:2.4693
# epoch:1150  d_loss:0.2785  g_loss:2.5450
# epoch:1151  d_loss:0.2031  g_loss:2.4886
# epoch:1152  d_loss:0.3935  g_loss:3.0485
# epoch:1153  d_loss:0.3535  g_loss:2.4625
# epoch:1154  d_loss:0.3881  g_loss:2.1328
# epoch:1155  d_loss:0.4899  g_loss:2.3084
# epoch:1156  d_loss:0.5382  g_loss:2.6729
# epoch:1157  d_loss:0.4336  g_loss:2.1546
# epoch:1158  d_loss:0.5546  g_loss:1.9328
# epoch:1159  d_loss:0.7200  g_loss:1.4771
# epoch:1160  d_loss:0.5998  g_loss:1.3951
# epoch:1161  d_loss:0.4725  g_loss:1.9549
# epoch:1162  d_loss:0.6271  g_loss:2.1151
# epoch:1163  d_loss:0.5233  g_loss:2.7198
# epoch:1164  d_loss:0.7676  g_loss:1.4558
# epoch:1165  d_loss:0.5763  g_loss:1.2442
# epoch:1166  d_loss:0.5420  g_loss:1.6764
# epoch:1167  d_loss:0.6212  g_loss:1.7701
# epoch:1168  d_loss:0.4495  g_loss:2.0207
# epoch:1169  d_loss:0.5381  g_loss:2.1712
# epoch:1170  d_loss:0.6351  g_loss:1.4820
# epoch:1171  d_loss:0.5816  g_loss:1.1676
# epoch:1172  d_loss:0.3976  g_loss:1.2013
# epoch:1173  d_loss:0.5166  g_loss:1.7037
# epoch:1174  d_loss:0.4243  g_loss:2.3666
# ...
# epoch:3619  d_loss:0.4252  g_loss:1.7578
# epoch:3620  d_loss:0.4975  g_loss:2.0504
# epoch:3621  d_loss:0.6304  g_loss:1.9183
# epoch:3622  d_loss:0.4260  g_loss:1.6025
# epoch:3623  d_loss:0.4874  g_loss:1.5094
# epoch:3624  d_loss:0.4994  g_loss:1.6753
# epoch:3625  d_loss:0.6359  g_loss:1.7439
# epoch:3626  d_loss:0.5897  g_loss:1.5040
# epoch:3627  d_loss:0.5057  g_loss:1.5717
# epoch:3628  d_loss:0.5819  g_loss:1.8179
# epoch:3629  d_loss:0.5367  g_loss:1.5352
# epoch:3630  d_loss:0.5368  g_loss:1.3240
# epoch:3631  d_loss:0.4230  g_loss:1.3866
# epoch:3632  d_loss:0.4987  g_loss:1.4333
# epoch:3633  d_loss:0.5257  g_loss:1.6526
# epoch:3634  d_loss:0.4733  g_loss:2.1069
# epoch:3635  d_loss:0.6046  g_loss:1.5478
# epoch:3636  d_loss:0.5454  g_loss:1.6897
# epoch:3637  d_loss:0.4248  g_loss:1.8997
# epoch:3638  d_loss:0.4764  g_loss:1.5105
# epoch:3639  d_loss:0.4312  g_loss:1.3091
# epoch:3640  d_loss:0.5668  g_loss:1.2610
# epoch:3641  d_loss:0.4081  g_loss:1.2920
# epoch:3642  d_loss:0.3896  g_loss:1.8442
# epoch:3643  d_loss:0.3305  g_loss:2.0028
# epoch:3644  d_loss:0.4932  g_loss:2.1627
# epoch:3645  d_loss:0.4557  g_loss:2.0241
# epoch:3646  d_loss:0.3489  g_loss:1.9510
# epoch:3647  d_loss:0.3293  g_loss:1.5064
# epoch:3648  d_loss:0.4493  g_loss:2.0758
# epoch:3649  d_loss:0.4048  g_loss:2.1985
# epoch:3650  d_loss:0.3708  g_loss:1.9134
# epoch:3651  d_loss:0.3960  g_loss:2.0153
# epoch:3652  d_loss:0.4104  g_loss:2.1447
# epoch:3653  d_loss:0.2827  g_loss:2.1580
# epoch:3654  d_loss:0.4497  g_loss:2.2878
# epoch:3655  d_loss:0.4671  g_loss:2.2891
# epoch:3656  d_loss:0.3921  g_loss:2.0703
# epoch:3657  d_loss:0.5723  g_loss:1.7203
# epoch:3658  d_loss:0.5382  g_loss:1.7271
# epoch:3659  d_loss:0.4527  g_loss:1.6207
# epoch:3660  d_loss:0.3809  g_loss:1.6687
# epoch:3661  d_loss:0.4078  g_loss:1.9103
# epoch:3662  d_loss:0.6015  g_loss:1.6540
# epoch:3663  d_loss:0.4854  g_loss:1.6993
# epoch:3664  d_loss:0.5935  g_loss:1.7398
# epoch:3665  d_loss:0.6246  g_loss:1.6524
# epoch:3666  d_loss:0.5053  g_loss:1.5286
# epoch:3667  d_loss:0.5657  g_loss:1.3506
# epoch:3668  d_loss:0.6136  g_loss:1.5614
# epoch:3669  d_loss:0.7040  g_loss:1.5396
# epoch:3670  d_loss:0.4421  g_loss:1.7105
# epoch:3671  d_loss:0.5301  g_loss:1.6986
# epoch:3672  d_loss:0.5348  g_loss:1.4291
# epoch:3673  d_loss:0.3716  g_loss:1.4964
# epoch:3674  d_loss:0.4057  g_loss:1.6966
# epoch:3675  d_loss:0.3347  g_loss:1.6560
# epoch:3676  d_loss:0.5440  g_loss:1.3206
# epoch:3677  d_loss:0.3094  g_loss:1.8410
# epoch:3678  d_loss:0.3762  g_loss:1.9217
# epoch:3679  d_loss:0.4809  g_loss:1.6301
# epoch:3680  d_loss:0.4898  g_loss:1.8035
# epoch:3681  d_loss:0.4722  g_loss:1.8549
# epoch:3682  d_loss:0.4320  g_loss:1.5315
# epoch:3683  d_loss:0.4877  g_loss:1.8096
# epoch:3684  d_loss:0.4053  g_loss:1.8375
# epoch:3685  d_loss:0.3181  g_loss:1.6226
# epoch:3686  d_loss:0.3752  g_loss:1.7104
# epoch:3687  d_loss:0.6277  g_loss:1.9618
# epoch:3688  d_loss:0.4022  g_loss:1.9754
# epoch:3689  d_loss:0.6728  g_loss:1.5322
# epoch:3690  d_loss:0.5377  g_loss:1.7814
# epoch:3691  d_loss:0.4986  g_loss:1.6346
# epoch:3692  d_loss:0.6562  g_loss:1.8625
# epoch:3693  d_loss:0.5984  g_loss:2.0494
# epoch:3694  d_loss:0.4527  g_loss:2.1768
# epoch:3695  d_loss:0.6163  g_loss:1.8749
# epoch:3696  d_loss:0.6802  g_loss:2.4839
# epoch:3697  d_loss:0.5847  g_loss:1.7850
# epoch:3698  d_loss:0.5109  g_loss:1.6091
# epoch:3699  d_loss:0.4790  g_loss:1.7504
# epoch:3700  d_loss:0.5562  g_loss:1.7612
# epoch:3701  d_loss:0.4485  g_loss:2.0813
# epoch:3702  d_loss:0.4804  g_loss:1.9463
# epoch:3703  d_loss:0.4619  g_loss:1.7358
# epoch:3704  d_loss:0.4467  g_loss:1.6005
# epoch:3705  d_loss:0.4208  g_loss:1.5707
# epoch:3706  d_loss:0.3828  g_loss:2.0167
# epoch:3707  d_loss:0.3542  g_loss:2.6134
# epoch:3708  d_loss:0.3783  g_loss:1.9636
# epoch:3709  d_loss:0.4264  g_loss:1.9512
# epoch:3710  d_loss:0.4644  g_loss:1.9586
# epoch:3711  d_loss:0.5787  g_loss:1.5602
# epoch:3712  d_loss:0.4639  g_loss:1.4420
# epoch:3713  d_loss:0.3256  g_loss:2.4060
# epoch:3714  d_loss:0.4192  g_loss:2.2290
# epoch:3715  d_loss:0.3925  g_loss:2.1788
# epoch:3716  d_loss:0.4883  g_loss:2.1413
# epoch:3717  d_loss:0.5464  g_loss:2.4970
# epoch:3718  d_loss:0.2862  g_loss:2.1547
# epoch:3719  d_loss:0.3326  g_loss:2.3818
# epoch:3720  d_loss:0.3946  g_loss:2.0033
# epoch:3721  d_loss:0.3064  g_loss:2.3082
# epoch:3722  d_loss:0.3216  g_loss:2.0395
# epoch:3723  d_loss:0.3696  g_loss:1.9478
# epoch:3724  d_loss:0.6194  g_loss:2.1938
# epoch:3725  d_loss:0.4955  g_loss:1.8966
# epoch:3726  d_loss:0.4986  g_loss:1.9989
# epoch:3727  d_loss:0.4879  g_loss:1.8250
# epoch:3728  d_loss:0.4953  g_loss:1.5430
# epoch:3729  d_loss:0.3456  g_loss:1.7822
# epoch:3730  d_loss:0.5930  g_loss:1.5480
# epoch:3731  d_loss:0.4888  g_loss:1.6292
# epoch:3732  d_loss:0.5938  g_loss:1.4747
# epoch:3733  d_loss:0.5607  g_loss:1.5172
# epoch:3734  d_loss:0.6232  g_loss:1.2826
# epoch:3735  d_loss:0.5918  g_loss:1.3477
# epoch:3736  d_loss:0.5117  g_loss:1.3760
# epoch:3737  d_loss:0.4847  g_loss:1.4712
# epoch:3738  d_loss:0.5191  g_loss:1.7319
# epoch:3739  d_loss:0.4059  g_loss:1.9044
# epoch:3740  d_loss:0.5794  g_loss:1.5809
# epoch:3741  d_loss:0.5166  g_loss:1.6967
# epoch:3742  d_loss:0.4086  g_loss:1.9936
# epoch:3743  d_loss:0.4430  g_loss:1.8944
# epoch:3744  d_loss:0.3325  g_loss:1.9686
# epoch:3745  d_loss:0.5312  g_loss:2.0950
# epoch:3746  d_loss:0.3449  g_loss:1.8095
# epoch:3747  d_loss:0.2750  g_loss:1.7692
# epoch:3748  d_loss:0.3198  g_loss:1.9099
# epoch:3749  d_loss:0.4446  g_loss:1.7858
# epoch:3750  d_loss:0.4025  g_loss:2.1930
# epoch:3751  d_loss:0.5181  g_loss:1.6544
# epoch:3752  d_loss:0.3610  g_loss:1.8095
# epoch:3753  d_loss:0.6246  g_loss:1.4000
# epoch:3754  d_loss:0.5432  g_loss:1.5114
# epoch:3755  d_loss:0.6404  g_loss:1.5081
# epoch:3756  d_loss:0.5776  g_loss:1.5096
# epoch:3757  d_loss:0.4157  g_loss:1.7001
# epoch:3758  d_loss:0.4461  g_loss:1.6412
# epoch:3759  d_loss:0.3917  g_loss:2.1248
# epoch:3760  d_loss:0.6099  g_loss:2.0116
# epoch:3761  d_loss:0.5905  g_loss:1.4255
# epoch:3762  d_loss:0.5102  g_loss:1.7296
# epoch:3763  d_loss:0.5358  g_loss:1.8438
# epoch:3764  d_loss:0.6546  g_loss:2.1152
# epoch:3765  d_loss:0.5094  g_loss:1.5337
# epoch:3766  d_loss:0.3557  g_loss:1.6106
# epoch:3767  d_loss:0.6038  g_loss:1.4623
# epoch:3768  d_loss:0.4557  g_loss:1.8703
# epoch:3769  d_loss:0.4554  g_loss:1.7135
# epoch:3770  d_loss:0.4274  g_loss:1.8411
# epoch:3771  d_loss:0.3642  g_loss:1.7227
# epoch:3772  d_loss:0.5083  g_loss:1.3058
# epoch:3773  d_loss:0.3768  g_loss:1.7769
# epoch:3774  d_loss:0.5184  g_loss:2.0437
# epoch:3775  d_loss:0.5297  g_loss:1.7797
# epoch:3776  d_loss:0.3700  g_loss:2.1478
# epoch:3777  d_loss:0.4717  g_loss:1.9368
# epoch:3778  d_loss:0.3928  g_loss:2.0252
# epoch:3779  d_loss:0.5215  g_loss:1.7304
# epoch:3780  d_loss:0.3066  g_loss:2.0033
# epoch:3781  d_loss:0.3503  g_loss:2.2787
# epoch:3782  d_loss:0.4750  g_loss:1.7086
# epoch:3783  d_loss:0.5543  g_loss:1.4497
# epoch:3784  d_loss:0.5867  g_loss:1.2247
# epoch:3785  d_loss:0.3587  g_loss:1.9621
# epoch:3786  d_loss:0.4208  g_loss:1.6375
# epoch:3787  d_loss:0.4465  g_loss:2.1695
# epoch:3788  d_loss:0.4993  g_loss:1.6860
# epoch:3789  d_loss:0.5272  g_loss:1.9699
# epoch:3790  d_loss:0.4631  g_loss:2.1927
# epoch:3791  d_loss:0.6413  g_loss:1.9584
# epoch:3792  d_loss:0.5240  g_loss:1.6418
# epoch:3793  d_loss:0.4642  g_loss:1.9576
# epoch:3794  d_loss:0.4251  g_loss:2.0635
# epoch:3795  d_loss:0.4358  g_loss:1.8183
# epoch:3796  d_loss:0.5320  g_loss:1.5704
# epoch:3797  d_loss:0.6905  g_loss:1.3256
# epoch:3798  d_loss:0.4522  g_loss:1.2842
# epoch:3799  d_loss:0.4876  g_loss:1.4397
# epoch:3800  d_loss:0.6327  g_loss:1.7991
# epoch:3801  d_loss:0.4286  g_loss:1.6377
# epoch:3802  d_loss:0.6295  g_loss:1.6164
# epoch:3803  d_loss:0.4057  g_loss:1.5880
# epoch:3804  d_loss:0.4751  g_loss:1.2965
# epoch:3805  d_loss:0.6707  g_loss:1.6592
# epoch:3806  d_loss:0.4873  g_loss:1.4648
# epoch:3807  d_loss:0.4272  g_loss:1.5810
# epoch:3808  d_loss:0.5412  g_loss:1.8139
# epoch:3809  d_loss:0.5040  g_loss:2.0762
# epoch:3810  d_loss:0.4102  g_loss:1.4795
# epoch:3811  d_loss:0.4654  g_loss:1.3795
# epoch:3812  d_loss:0.6563  g_loss:1.4733
# epoch:3813  d_loss:0.5058  g_loss:1.4931
# epoch:3814  d_loss:0.5153  g_loss:1.5365
# epoch:3815  d_loss:0.4439  g_loss:1.6598
# epoch:3816  d_loss:0.5079  g_loss:1.5454
# epoch:3817  d_loss:0.5239  g_loss:1.7669
# epoch:3818  d_loss:0.4533  g_loss:1.4153
# epoch:3819  d_loss:0.4803  g_loss:1.4745
# epoch:3820  d_loss:0.5769  g_loss:1.3218
# epoch:3821  d_loss:0.4562  g_loss:1.3949
# epoch:3822  d_loss:0.4937  g_loss:1.4089
# epoch:3823  d_loss:0.4080  g_loss:1.7440
# epoch:3824  d_loss:0.4954  g_loss:1.7533
# epoch:3825  d_loss:0.5929  g_loss:1.8230
# epoch:3826  d_loss:0.6066  g_loss:1.4832
# epoch:3827  d_loss:0.6060  g_loss:1.3004
# epoch:3828  d_loss:0.5424  g_loss:1.6083
# epoch:3829  d_loss:0.4661  g_loss:1.5037
# epoch:3830  d_loss:0.4410  g_loss:1.6449
# epoch:3831  d_loss:0.4031  g_loss:1.6853
# epoch:3832  d_loss:0.5369  g_loss:1.9266
# epoch:3833  d_loss:0.3188  g_loss:2.2947
# epoch:3834  d_loss:0.4422  g_loss:2.1131
# epoch:3835  d_loss:0.5295  g_loss:1.8016
# epoch:3836  d_loss:0.5073  g_loss:1.1845
# epoch:3837  d_loss:0.4455  g_loss:1.6271
# epoch:3838  d_loss:0.3644  g_loss:2.0317
# epoch:3839  d_loss:0.5294  g_loss:1.5024
# epoch:3840  d_loss:0.3514  g_loss:1.7611
# epoch:3841  d_loss:0.5077  g_loss:1.8267
# epoch:3842  d_loss:0.5128  g_loss:1.6314
# epoch:3843  d_loss:0.4537  g_loss:1.8521
# epoch:3844  d_loss:0.3781  g_loss:2.1633
# epoch:3845  d_loss:0.5697  g_loss:1.7547
# epoch:3846  d_loss:0.3513  g_loss:2.2521
# epoch:3847  d_loss:0.5200  g_loss:2.0987
# epoch:3848  d_loss:0.3509  g_loss:1.7046
# epoch:3849  d_loss:0.5074  g_loss:1.5271
# epoch:3850  d_loss:0.5902  g_loss:1.4553
# epoch:3851  d_loss:0.4849  g_loss:1.7574
# epoch:3852  d_loss:0.4504  g_loss:1.8399
# epoch:3853  d_loss:0.4900  g_loss:1.8623
# epoch:3854  d_loss:0.6882  g_loss:1.6636
# epoch:3855  d_loss:0.5664  g_loss:1.4519
# epoch:3856  d_loss:0.5401  g_loss:1.7294
# epoch:3857  d_loss:0.3914  g_loss:1.4605
# epoch:3858  d_loss:0.4965  g_loss:1.4853
# epoch:3859  d_loss:0.5248  g_loss:1.5927
# epoch:3860  d_loss:0.4961  g_loss:1.5098
# epoch:3861  d_loss:0.4473  g_loss:1.7015
# epoch:3862  d_loss:0.5827  g_loss:1.5360
# epoch:3863  d_loss:0.5818  g_loss:1.6349
# epoch:3864  d_loss:0.4824  g_loss:1.3603
# epoch:3865  d_loss:0.6754  g_loss:1.1068
# epoch:3866  d_loss:0.4337  g_loss:1.2190
# epoch:3867  d_loss:0.5662  g_loss:1.3565
# epoch:3868  d_loss:0.4739  g_loss:1.9360
# epoch:3869  d_loss:0.4654  g_loss:1.6242
# epoch:3870  d_loss:0.3545  g_loss:1.7029
# epoch:3871  d_loss:0.5485  g_loss:1.7718
# epoch:3872  d_loss:0.5257  g_loss:1.5753
# epoch:3873  d_loss:0.5051  g_loss:1.5675
# epoch:3874  d_loss:0.4996  g_loss:1.1310
# epoch:3875  d_loss:0.5141  g_loss:1.5391
# epoch:3876  d_loss:0.5261  g_loss:1.4495
# epoch:3877  d_loss:0.5007  g_loss:1.6507
# epoch:3878  d_loss:0.5241  g_loss:1.8264
# epoch:3879  d_loss:0.4940  g_loss:1.7642
# epoch:3880  d_loss:0.4362  g_loss:1.9987
# epoch:3881  d_loss:0.5589  g_loss:2.0310
# epoch:3882  d_loss:0.4764  g_loss:1.9165
# epoch:3883  d_loss:0.3927  g_loss:1.8508
# epoch:3884  d_loss:0.4828  g_loss:1.3836
# epoch:3885  d_loss:0.5123  g_loss:1.5995
# epoch:3886  d_loss:0.3986  g_loss:1.2496
# epoch:3887  d_loss:0.6019  g_loss:1.4164
# epoch:3888  d_loss:0.3788  g_loss:1.7116
# epoch:3889  d_loss:0.4585  g_loss:1.7902
# epoch:3890  d_loss:0.5067  g_loss:1.9653
# epoch:3891  d_loss:0.4080  g_loss:2.3167
# epoch:3892  d_loss:0.4631  g_loss:1.8405
# epoch:3893  d_loss:0.5926  g_loss:1.9833
# epoch:3894  d_loss:0.6715  g_loss:1.7810
# epoch:3895  d_loss:0.3731  g_loss:1.8594
# epoch:3896  d_loss:0.5336  g_loss:1.8187
# epoch:3897  d_loss:0.4491  g_loss:1.7926
# epoch:3898  d_loss:0.4923  g_loss:1.9357
# epoch:3899  d_loss:0.4966  g_loss:1.5199
# epoch:3900  d_loss:0.5124  g_loss:1.8925
# epoch:3901  d_loss:0.5589  g_loss:1.8345
# epoch:3902  d_loss:0.5152  g_loss:1.8081
# epoch:3903  d_loss:0.4525  g_loss:1.6601
# epoch:3904  d_loss:0.4720  g_loss:2.1002
# epoch:3905  d_loss:0.5005  g_loss:1.7467
# epoch:3906  d_loss:0.4239  g_loss:1.7521
# epoch:3907  d_loss:0.4065  g_loss:1.5334
# epoch:3908  d_loss:0.4421  g_loss:1.4456
# epoch:3909  d_loss:0.4662  g_loss:1.3322
# epoch:3910  d_loss:0.4400  g_loss:1.6775
# epoch:3911  d_loss:0.4167  g_loss:1.6569
# epoch:3912  d_loss:0.4128  g_loss:2.1177
# epoch:3913  d_loss:0.4705  g_loss:1.9245
# epoch:3914  d_loss:0.5720  g_loss:1.5097
# epoch:3915  d_loss:0.4763  g_loss:1.8371
# epoch:3916  d_loss:0.5223  g_loss:1.4574
# epoch:3917  d_loss:0.4746  g_loss:1.8962
# epoch:3918  d_loss:0.4427  g_loss:2.0525
# epoch:3919  d_loss:0.5174  g_loss:2.0977
# epoch:3920  d_loss:0.4594  g_loss:1.7324
# epoch:3921  d_loss:0.4533  g_loss:1.5040
# epoch:3922  d_loss:0.5178  g_loss:1.5482
# epoch:3923  d_loss:0.5022  g_loss:1.6094
# epoch:3924  d_loss:0.4444  g_loss:1.9916
# epoch:3925  d_loss:0.5436  g_loss:1.7984
# epoch:3926  d_loss:0.5528  g_loss:1.3971
# epoch:3927  d_loss:0.5731  g_loss:1.6845
# epoch:3928  d_loss:0.5291  g_loss:1.4964
# epoch:3929  d_loss:0.4410  g_loss:1.8396
# epoch:3930  d_loss:0.5066  g_loss:1.6463
# epoch:3931  d_loss:0.5435  g_loss:1.4888
# epoch:3932  d_loss:0.4789  g_loss:1.5247
# epoch:3933  d_loss:0.4435  g_loss:1.5181
# epoch:3934  d_loss:0.4379  g_loss:1.3574
# epoch:3935  d_loss:0.6162  g_loss:1.3966
# epoch:3936  d_loss:0.5521  g_loss:1.2359
# epoch:3937  d_loss:0.3890  g_loss:1.9961
# epoch:3938  d_loss:0.5618  g_loss:1.5046
# epoch:3939  d_loss:0.5690  g_loss:2.0426
# epoch:3940  d_loss:0.6331  g_loss:1.5535
# epoch:3941  d_loss:0.4837  g_loss:1.7590
# epoch:3942  d_loss:0.5157  g_loss:1.4971
# epoch:3943  d_loss:0.4458  g_loss:1.3972
# epoch:3944  d_loss:0.4546  g_loss:1.3201
# epoch:3945  d_loss:0.5354  g_loss:1.3391
# epoch:3946  d_loss:0.4534  g_loss:1.7464
# epoch:3947  d_loss:0.4053  g_loss:1.8474
# epoch:3948  d_loss:0.4648  g_loss:1.6259
# epoch:3949  d_loss:0.4241  g_loss:1.6384
# epoch:3950  d_loss:0.5062  g_loss:1.4265
# epoch:3951  d_loss:0.5410  g_loss:1.6283
# epoch:3952  d_loss:0.3549  g_loss:1.5371
# epoch:3953  d_loss:0.4110  g_loss:1.5179
# epoch:3954  d_loss:0.4419  g_loss:1.8024
# epoch:3955  d_loss:0.3802  g_loss:1.9685
# epoch:3956  d_loss:0.4726  g_loss:1.5329
# epoch:3957  d_loss:0.3882  g_loss:1.8562
# epoch:3958  d_loss:0.4321  g_loss:1.7023
# epoch:3959  d_loss:0.4416  g_loss:1.9878
# epoch:3960  d_loss:0.4263  g_loss:1.2880
# epoch:3961  d_loss:0.5289  g_loss:1.5900
# epoch:3962  d_loss:0.4412  g_loss:1.4733
# epoch:3963  d_loss:0.4640  g_loss:1.8011
# epoch:3964  d_loss:0.5036  g_loss:1.8988
# epoch:3965  d_loss:0.5314  g_loss:1.7168
# epoch:3966  d_loss:0.4666  g_loss:1.9577
# epoch:3967  d_loss:0.5051  g_loss:1.5758
# epoch:3968  d_loss:0.5183  g_loss:1.6587
# epoch:3969  d_loss:0.5261  g_loss:1.5126
# epoch:3970  d_loss:0.4743  g_loss:1.5118
# epoch:3971  d_loss:0.4205  g_loss:1.2493
# epoch:3972  d_loss:0.6121  g_loss:1.3084
# epoch:3973  d_loss:0.4608  g_loss:1.8501
# epoch:3974  d_loss:0.4454  g_loss:1.6146
# epoch:3975  d_loss:0.5439  g_loss:1.7024
# epoch:3976  d_loss:0.6307  g_loss:1.5969
# epoch:3977  d_loss:0.4792  g_loss:1.4714
# epoch:3978  d_loss:0.5699  g_loss:1.2217
# epoch:3979  d_loss:0.6382  g_loss:1.0940
# epoch:3980  d_loss:0.3883  g_loss:1.7249
# epoch:3981  d_loss:0.5599  g_loss:1.5956
# epoch:3982  d_loss:0.4417  g_loss:1.6599
# epoch:3983  d_loss:0.5009  g_loss:1.9585
# epoch:3984  d_loss:0.7237  g_loss:1.2941
# epoch:3985  d_loss:0.5768  g_loss:1.1795
# epoch:3986  d_loss:0.6287  g_loss:1.3470
# epoch:3987  d_loss:0.6198  g_loss:1.3139
# epoch:3988  d_loss:0.4130  g_loss:1.6584
# epoch:3989  d_loss:0.4224  g_loss:1.6382
# epoch:3990  d_loss:0.5337  g_loss:1.6163
# epoch:3991  d_loss:0.4464  g_loss:1.8009
# epoch:3992  d_loss:0.3931  g_loss:1.6490
# epoch:3993  d_loss:0.4283  g_loss:1.3953
# epoch:3994  d_loss:0.5089  g_loss:1.4157
# epoch:3995  d_loss:0.5820  g_loss:1.4620
# epoch:3996  d_loss:0.5096  g_loss:1.4783
# epoch:3997  d_loss:0.3866  g_loss:1.7246
# epoch:3998  d_loss:0.4203  g_loss:1.6301
# epoch:3999  d_loss:0.4832  g_loss:1.8334
# epoch:4000  d_loss:0.4038  g_loss:1.7657
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:91: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
