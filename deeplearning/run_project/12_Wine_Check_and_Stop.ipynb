# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
numpy.random.seed(3)
tf.random.set_seed(3)

df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Using TensorFlow backend.
# Epoch 00001: val_loss improved from inf to 0.77907, saving model to ./model/01-0.7791.hdf5
#
# Epoch 00002: val_loss improved from 0.77907 to 0.65665, saving model to ./model/02-0.6566.hdf5
#
# Epoch 00003: val_loss improved from 0.65665 to 0.55570, saving model to ./model/03-0.5557.hdf5
#
# Epoch 00004: val_loss improved from 0.55570 to 0.47428, saving model to ./model/04-0.4743.hdf5
#
# Epoch 00005: val_loss improved from 0.47428 to 0.40921, saving model to ./model/05-0.4092.hdf5
#
# Epoch 00006: val_loss improved from 0.40921 to 0.36598, saving model to ./model/06-0.3660.hdf5
#
# Epoch 00007: val_loss improved from 0.36598 to 0.35366, saving model to ./model/07-0.3537.hdf5
#
# Epoch 00008: val_loss did not improve from 0.35366
#
# Epoch 00009: val_loss did not improve from 0.35366
#
# Epoch 00010: val_loss did not improve from 0.35366
#
# Epoch 00011: val_loss did not improve from 0.35366
#
# Epoch 00012: val_loss did not improve from 0.35366
#
# Epoch 00013: val_loss improved from 0.35366 to 0.33791, saving model to ./model/13-0.3379.hdf5
#
# Epoch 00014: val_loss improved from 0.33791 to 0.31578, saving model to ./model/14-0.3158.hdf5
#
# Epoch 00015: val_loss improved from 0.31578 to 0.30334, saving model to ./model/15-0.3033.hdf5
#
# Epoch 00016: val_loss improved from 0.30334 to 0.29845, saving model to ./model/16-0.2984.hdf5
#
# Epoch 00017: val_loss improved from 0.29845 to 0.29607, saving model to ./model/17-0.2961.hdf5
#
# Epoch 00018: val_loss improved from 0.29607 to 0.29397, saving model to ./model/18-0.2940.hdf5
#
# Epoch 00019: val_loss improved from 0.29397 to 0.29146, saving model to ./model/19-0.2915.hdf5
#
# Epoch 00020: val_loss improved from 0.29146 to 0.28898, saving model to ./model/20-0.2890.hdf5
#
# Epoch 00021: val_loss improved from 0.28898 to 0.28745, saving model to ./model/21-0.2875.hdf5
#
# Epoch 00022: val_loss did not improve from 0.28745
#
# Epoch 00023: val_loss did not improve from 0.28745
#
# Epoch 00024: val_loss did not improve from 0.28745
#
# Epoch 00025: val_loss did not improve from 0.28745
#
# Epoch 00026: val_loss did not improve from 0.28745
#
# Epoch 00027: val_loss did not improve from 0.28745
#
# Epoch 00028: val_loss improved from 0.28745 to 0.28466, saving model to ./model/28-0.2847.hdf5
#
# Epoch 00029: val_loss improved from 0.28466 to 0.28046, saving model to ./model/29-0.2805.hdf5
#
# Epoch 00030: val_loss improved from 0.28046 to 0.27682, saving model to ./model/30-0.2768.hdf5
#
# Epoch 00031: val_loss improved from 0.27682 to 0.27385, saving model to ./model/31-0.2738.hdf5
#
# Epoch 00032: val_loss improved from 0.27385 to 0.27149, saving model to ./model/32-0.2715.hdf5
#
# Epoch 00033: val_loss improved from 0.27149 to 0.26999, saving model to ./model/33-0.2700.hdf5
#
# Epoch 00034: val_loss improved from 0.26999 to 0.26944, saving model to ./model/34-0.2694.hdf5
#
# Epoch 00035: val_loss did not improve from 0.26944
#
# Epoch 00036: val_loss improved from 0.26944 to 0.26937, saving model to ./model/36-0.2694.hdf5
#
# Epoch 00037: val_loss improved from 0.26937 to 0.26893, saving model to ./model/37-0.2689.hdf5
#
# Epoch 00038: val_loss improved from 0.26893 to 0.26787, saving model to ./model/38-0.2679.hdf5
#
# Epoch 00039: val_loss improved from 0.26787 to 0.26618, saving model to ./model/39-0.2662.hdf5
#
# Epoch 00040: val_loss improved from 0.26618 to 0.26353, saving model to ./model/40-0.2635.hdf5
#
# Epoch 00041: val_loss improved from 0.26353 to 0.26107, saving model to ./model/41-0.2611.hdf5
#
# Epoch 00042: val_loss improved from 0.26107 to 0.25874, saving model to ./model/42-0.2587.hdf5
#
# Epoch 00043: val_loss improved from 0.25874 to 0.25693, saving model to ./model/43-0.2569.hdf5
#
# Epoch 00044: val_loss improved from 0.25693 to 0.25559, saving model to ./model/44-0.2556.hdf5
#
# Epoch 00045: val_loss improved from 0.25559 to 0.25443, saving model to ./model/45-0.2544.hdf5
#
# Epoch 00046: val_loss improved from 0.25443 to 0.25383, saving model to ./model/46-0.2538.hdf5
#
# Epoch 00047: val_loss improved from 0.25383 to 0.25275, saving model to ./model/47-0.2528.hdf5
#
# Epoch 00048: val_loss improved from 0.25275 to 0.25085, saving model to ./model/48-0.2509.hdf5
#
# Epoch 00049: val_loss improved from 0.25085 to 0.24940, saving model to ./model/49-0.2494.hdf5
#
# Epoch 00050: val_loss improved from 0.24940 to 0.24739, saving model to ./model/50-0.2474.hdf5
#
# Epoch 00051: val_loss improved from 0.24739 to 0.24553, saving model to ./model/51-0.2455.hdf5
#
# Epoch 00052: val_loss improved from 0.24553 to 0.24389, saving model to ./model/52-0.2439.hdf5
#
# Epoch 00053: val_loss improved from 0.24389 to 0.24200, saving model to ./model/53-0.2420.hdf5
#
# Epoch 00054: val_loss improved from 0.24200 to 0.24037, saving model to ./model/54-0.2404.hdf5
#
# Epoch 00055: val_loss improved from 0.24037 to 0.23966, saving model to ./model/55-0.2397.hdf5
#
# Epoch 00056: val_loss improved from 0.23966 to 0.23887, saving model to ./model/56-0.2389.hdf5
#
# Epoch 00057: val_loss improved from 0.23887 to 0.23793, saving model to ./model/57-0.2379.hdf5
#
# Epoch 00058: val_loss improved from 0.23793 to 0.23693, saving model to ./model/58-0.2369.hdf5
#
# Epoch 00059: val_loss improved from 0.23693 to 0.23631, saving model to ./model/59-0.2363.hdf5
#
# Epoch 00060: val_loss improved from 0.23631 to 0.23540, saving model to ./model/60-0.2354.hdf5
#
# Epoch 00061: val_loss improved from 0.23540 to 0.23332, saving model to ./model/61-0.2333.hdf5
#
# Epoch 00062: val_loss improved from 0.23332 to 0.23041, saving model to ./model/62-0.2304.hdf5
#
# Epoch 00063: val_loss improved from 0.23041 to 0.22780, saving model to ./model/63-0.2278.hdf5
#
# Epoch 00064: val_loss improved from 0.22780 to 0.22577, saving model to ./model/64-0.2258.hdf5
#
# Epoch 00065: val_loss improved from 0.22577 to 0.22355, saving model to ./model/65-0.2236.hdf5
#
# Epoch 00066: val_loss improved from 0.22355 to 0.22269, saving model to ./model/66-0.2227.hdf5
#
# Epoch 00067: val_loss improved from 0.22269 to 0.22254, saving model to ./model/67-0.2225.hdf5
#
# Epoch 00068: val_loss did not improve from 0.22254
#
# Epoch 00069: val_loss did not improve from 0.22254
#
# Epoch 00070: val_loss improved from 0.22254 to 0.22136, saving model to ./model/70-0.2214.hdf5
#
# Epoch 00071: val_loss improved from 0.22136 to 0.21919, saving model to ./model/71-0.2192.hdf5
#
# Epoch 00072: val_loss improved from 0.21919 to 0.21681, saving model to ./model/72-0.2168.hdf5
#
# Epoch 00073: val_loss improved from 0.21681 to 0.21467, saving model to ./model/73-0.2147.hdf5
#
# Epoch 00074: val_loss improved from 0.21467 to 0.21383, saving model to ./model/74-0.2138.hdf5
#
# Epoch 00075: val_loss improved from 0.21383 to 0.21272, saving model to ./model/75-0.2127.hdf5
#
# Epoch 00076: val_loss improved from 0.21272 to 0.21093, saving model to ./model/76-0.2109.hdf5
#
# Epoch 00077: val_loss improved from 0.21093 to 0.20901, saving model to ./model/77-0.2090.hdf5
#
# Epoch 00078: val_loss improved from 0.20901 to 0.20731, saving model to ./model/78-0.2073.hdf5
#
# Epoch 00079: val_loss improved from 0.20731 to 0.20679, saving model to ./model/79-0.2068.hdf5
#
# Epoch 00080: val_loss improved from 0.20679 to 0.20642, saving model to ./model/80-0.2064.hdf5
#
# Epoch 00081: val_loss improved from 0.20642 to 0.20531, saving model to ./model/81-0.2053.hdf5
#
# Epoch 00082: val_loss improved from 0.20531 to 0.20400, saving model to ./model/82-0.2040.hdf5
#
# Epoch 00083: val_loss improved from 0.20400 to 0.20172, saving model to ./model/83-0.2017.hdf5
#
# Epoch 00084: val_loss improved from 0.20172 to 0.19932, saving model to ./model/84-0.1993.hdf5
#
# Epoch 00085: val_loss did not improve from 0.19932
#
# Epoch 00086: val_loss improved from 0.19932 to 0.19899, saving model to ./model/86-0.1990.hdf5
#
# Epoch 00087: val_loss improved from 0.19899 to 0.19826, saving model to ./model/87-0.1983.hdf5
#
# Epoch 00088: val_loss improved from 0.19826 to 0.19742, saving model to ./model/88-0.1974.hdf5
#
# Epoch 00089: val_loss improved from 0.19742 to 0.19567, saving model to ./model/89-0.1957.hdf5
#
# Epoch 00090: val_loss improved from 0.19567 to 0.19338, saving model to ./model/90-0.1934.hdf5
#
# Epoch 00091: val_loss improved from 0.19338 to 0.19180, saving model to ./model/91-0.1918.hdf5
#
# Epoch 00092: val_loss improved from 0.19180 to 0.19083, saving model to ./model/92-0.1908.hdf5
#
# Epoch 00093: val_loss improved from 0.19083 to 0.19052, saving model to ./model/93-0.1905.hdf5
#
# Epoch 00094: val_loss improved from 0.19052 to 0.18973, saving model to ./model/94-0.1897.hdf5
#
# Epoch 00095: val_loss improved from 0.18973 to 0.18890, saving model to ./model/95-0.1889.hdf5
#
# Epoch 00096: val_loss improved from 0.18890 to 0.18774, saving model to ./model/96-0.1877.hdf5
#
# Epoch 00097: val_loss improved from 0.18774 to 0.18681, saving model to ./model/97-0.1868.hdf5
#
# Epoch 00098: val_loss improved from 0.18681 to 0.18597, saving model to ./model/98-0.1860.hdf5
#
# Epoch 00099: val_loss did not improve from 0.18597
#
# Epoch 00100: val_loss did not improve from 0.18597
#
# Epoch 00101: val_loss improved from 0.18597 to 0.18401, saving model to ./model/101-0.1840.hdf5
#
# Epoch 00102: val_loss improved from 0.18401 to 0.18340, saving model to ./model/102-0.1834.hdf5
#
# Epoch 00103: val_loss improved from 0.18340 to 0.18230, saving model to ./model/103-0.1823.hdf5
#
# Epoch 00104: val_loss improved from 0.18230 to 0.17959, saving model to ./model/104-0.1796.hdf5
#
# Epoch 00105: val_loss improved from 0.17959 to 0.17688, saving model to ./model/105-0.1769.hdf5
#
# Epoch 00106: val_loss improved from 0.17688 to 0.17529, saving model to ./model/106-0.1753.hdf5
#
# Epoch 00107: val_loss improved from 0.17529 to 0.17463, saving model to ./model/107-0.1746.hdf5
#
# Epoch 00108: val_loss did not improve from 0.17463
#
# Epoch 00109: val_loss did not improve from 0.17463
#
# Epoch 00110: val_loss did not improve from 0.17463
#
# Epoch 00111: val_loss did not improve from 0.17463
#
# Epoch 00112: val_loss improved from 0.17463 to 0.17219, saving model to ./model/112-0.1722.hdf5
#
# Epoch 00113: val_loss improved from 0.17219 to 0.17132, saving model to ./model/113-0.1713.hdf5
#
# Epoch 00114: val_loss did not improve from 0.17132
#
# Epoch 00115: val_loss did not improve from 0.17132
#
# Epoch 00116: val_loss did not improve from 0.17132
#
# Epoch 00117: val_loss improved from 0.17132 to 0.17107, saving model to ./model/117-0.1711.hdf5
#
# Epoch 00118: val_loss improved from 0.17107 to 0.16869, saving model to ./model/118-0.1687.hdf5
#
# Epoch 00119: val_loss improved from 0.16869 to 0.16827, saving model to ./model/119-0.1683.hdf5
#
# Epoch 00120: val_loss did not improve from 0.16827
#
# Epoch 00121: val_loss improved from 0.16827 to 0.16719, saving model to ./model/121-0.1672.hdf5
#
# Epoch 00122: val_loss improved from 0.16719 to 0.16652, saving model to ./model/122-0.1665.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16652
#
# Epoch 00124: val_loss improved from 0.16652 to 0.16611, saving model to ./model/124-0.1661.hdf5
#
# Epoch 00125: val_loss did not improve from 0.16611
#
# Epoch 00126: val_loss did not improve from 0.16611
#
# Epoch 00127: val_loss improved from 0.16611 to 0.16600, saving model to ./model/127-0.1660.hdf5
#
# Epoch 00128: val_loss did not improve from 0.16600
#
# Epoch 00129: val_loss did not improve from 0.16600
#
# Epoch 00130: val_loss did not improve from 0.16600
#
# Epoch 00131: val_loss improved from 0.16600 to 0.16565, saving model to ./model/131-0.1657.hdf5
#
# Epoch 00132: val_loss improved from 0.16565 to 0.16330, saving model to ./model/132-0.1633.hdf5
#
# Epoch 00133: val_loss improved from 0.16330 to 0.16138, saving model to ./model/133-0.1614.hdf5
#
# Epoch 00134: val_loss improved from 0.16138 to 0.16029, saving model to ./model/134-0.1603.hdf5
#
# Epoch 00135: val_loss improved from 0.16029 to 0.15849, saving model to ./model/135-0.1585.hdf5
#
# Epoch 00136: val_loss did not improve from 0.15849
#
# Epoch 00137: val_loss did not improve from 0.15849
#
# Epoch 00138: val_loss did not improve from 0.15849
#
# Epoch 00139: val_loss did not improve from 0.15849
#
# Epoch 00140: val_loss did not improve from 0.15849
#
# Epoch 00141: val_loss improved from 0.15849 to 0.15827, saving model to ./model/141-0.1583.hdf5
#
# Epoch 00142: val_loss improved from 0.15827 to 0.15684, saving model to ./model/142-0.1568.hdf5
#
# Epoch 00143: val_loss did not improve from 0.15684
#
# Epoch 00144: val_loss did not improve from 0.15684
#
# Epoch 00145: val_loss did not improve from 0.15684
#
# Epoch 00146: val_loss did not improve from 0.15684
#
# Epoch 00147: val_loss did not improve from 0.15684
#
# Epoch 00148: val_loss improved from 0.15684 to 0.15466, saving model to ./model/148-0.1547.hdf5
#
# Epoch 00149: val_loss improved from 0.15466 to 0.15415, saving model to ./model/149-0.1542.hdf5
#
# Epoch 00150: val_loss did not improve from 0.15415
#
# Epoch 00151: val_loss did not improve from 0.15415
#
# Epoch 00152: val_loss did not improve from 0.15415
#
# Epoch 00153: val_loss did not improve from 0.15415
#
# Epoch 00154: val_loss improved from 0.15415 to 0.15234, saving model to ./model/154-0.1523.hdf5
#
# Epoch 00155: val_loss improved from 0.15234 to 0.15224, saving model to ./model/155-0.1522.hdf5
#
# Epoch 00156: val_loss did not improve from 0.15224
#
# Epoch 00157: val_loss did not improve from 0.15224
#
# Epoch 00158: val_loss did not improve from 0.15224
#
# Epoch 00159: val_loss did not improve from 0.15224
#
# Epoch 00160: val_loss did not improve from 0.15224
#
# Epoch 00161: val_loss did not improve from 0.15224
#
# Epoch 00162: val_loss did not improve from 0.15224
#
# Epoch 00163: val_loss did not improve from 0.15224
#
# Epoch 00164: val_loss did not improve from 0.15224
#
# Epoch 00165: val_loss improved from 0.15224 to 0.15009, saving model to ./model/165-0.1501.hdf5
#
# Epoch 00166: val_loss improved from 0.15009 to 0.14924, saving model to ./model/166-0.1492.hdf5
#
# Epoch 00167: val_loss did not improve from 0.14924
#
# Epoch 00168: val_loss did not improve from 0.14924
#
# Epoch 00169: val_loss did not improve from 0.14924
#
# Epoch 00170: val_loss did not improve from 0.14924
#
# Epoch 00171: val_loss improved from 0.14924 to 0.14781, saving model to ./model/171-0.1478.hdf5
#
# Epoch 00172: val_loss improved from 0.14781 to 0.14538, saving model to ./model/172-0.1454.hdf5
#
# Epoch 00173: val_loss did not improve from 0.14538
#
# Epoch 00174: val_loss did not improve from 0.14538
#
# Epoch 00175: val_loss did not improve from 0.14538
#
# Epoch 00176: val_loss did not improve from 0.14538
#
# Epoch 00177: val_loss improved from 0.14538 to 0.14305, saving model to ./model/177-0.1431.hdf5
#
# Epoch 00178: val_loss improved from 0.14305 to 0.14127, saving model to ./model/178-0.1413.hdf5
#
# Epoch 00179: val_loss did not improve from 0.14127
#
# Epoch 00180: val_loss did not improve from 0.14127
#
# Epoch 00181: val_loss did not improve from 0.14127
#
# Epoch 00182: val_loss did not improve from 0.14127
#
# Epoch 00183: val_loss did not improve from 0.14127
#
# Epoch 00184: val_loss improved from 0.14127 to 0.14112, saving model to ./model/184-0.1411.hdf5
#
# Epoch 00185: val_loss did not improve from 0.14112
#
# Epoch 00186: val_loss did not improve from 0.14112
#
# Epoch 00187: val_loss did not improve from 0.14112
#
# Epoch 00188: val_loss did not improve from 0.14112
#
# Epoch 00189: val_loss did not improve from 0.14112
#
# Epoch 00190: val_loss did not improve from 0.14112
#
# Epoch 00191: val_loss did not improve from 0.14112
#
# Epoch 00192: val_loss did not improve from 0.14112
#
# Epoch 00193: val_loss improved from 0.14112 to 0.14098, saving model to ./model/193-0.1410.hdf5
#
# Epoch 00194: val_loss did not improve from 0.14098
#
# Epoch 00195: val_loss did not improve from 0.14098
#
# Epoch 00196: val_loss did not improve from 0.14098
#
# Epoch 00197: val_loss did not improve from 0.14098
#
# Epoch 00198: val_loss did not improve from 0.14098
#
# Epoch 00199: val_loss improved from 0.14098 to 0.13916, saving model to ./model/199-0.1392.hdf5
#
# Epoch 00200: val_loss did not improve from 0.13916
#
# Epoch 00201: val_loss did not improve from 0.13916
#
# Epoch 00202: val_loss did not improve from 0.13916
#
# Epoch 00203: val_loss did not improve from 0.13916
#
# Epoch 00204: val_loss did not improve from 0.13916
#
# Epoch 00205: val_loss improved from 0.13916 to 0.13884, saving model to ./model/205-0.1388.hdf5
#
# Epoch 00206: val_loss did not improve from 0.13884
#
# Epoch 00207: val_loss improved from 0.13884 to 0.13884, saving model to ./model/207-0.1388.hdf5
#
# Epoch 00208: val_loss improved from 0.13884 to 0.13808, saving model to ./model/208-0.1381.hdf5
#
# Epoch 00209: val_loss did not improve from 0.13808
#
# Epoch 00210: val_loss did not improve from 0.13808
#
# Epoch 00211: val_loss did not improve from 0.13808
#
# Epoch 00212: val_loss did not improve from 0.13808
#
# Epoch 00213: val_loss improved from 0.13808 to 0.13690, saving model to ./model/213-0.1369.hdf5
#
# Epoch 00214: val_loss improved from 0.13690 to 0.13499, saving model to ./model/214-0.1350.hdf5
#
# Epoch 00215: val_loss improved from 0.13499 to 0.13330, saving model to ./model/215-0.1333.hdf5
#
# Epoch 00216: val_loss did not improve from 0.13330
#
# Epoch 00217: val_loss did not improve from 0.13330
#
# Epoch 00218: val_loss did not improve from 0.13330
#
# Epoch 00219: val_loss did not improve from 0.13330
#
# Epoch 00220: val_loss did not improve from 0.13330
#
# Epoch 00221: val_loss did not improve from 0.13330
#
# Epoch 00222: val_loss did not improve from 0.13330
#
# Epoch 00223: val_loss did not improve from 0.13330
#
# Epoch 00224: val_loss did not improve from 0.13330
#
# Epoch 00225: val_loss did not improve from 0.13330
#
# Epoch 00226: val_loss improved from 0.13330 to 0.13134, saving model to ./model/226-0.1313.hdf5
#
# Epoch 00227: val_loss improved from 0.13134 to 0.13035, saving model to ./model/227-0.1303.hdf5
#
# Epoch 00228: val_loss did not improve from 0.13035
#
# Epoch 00229: val_loss did not improve from 0.13035
#
# Epoch 00230: val_loss did not improve from 0.13035
#
# Epoch 00231: val_loss did not improve from 0.13035
#
# Epoch 00232: val_loss improved from 0.13035 to 0.12938, saving model to ./model/232-0.1294.hdf5
#
# Epoch 00233: val_loss improved from 0.12938 to 0.12911, saving model to ./model/233-0.1291.hdf5
#
# Epoch 00234: val_loss did not improve from 0.12911
#
# Epoch 00235: val_loss did not improve from 0.12911
#
# Epoch 00236: val_loss did not improve from 0.12911
#
# Epoch 00237: val_loss did not improve from 0.12911
#
# Epoch 00238: val_loss improved from 0.12911 to 0.12864, saving model to ./model/238-0.1286.hdf5
#
# Epoch 00239: val_loss did not improve from 0.12864
#
# Epoch 00240: val_loss did not improve from 0.12864
#
# Epoch 00241: val_loss did not improve from 0.12864
#
# Epoch 00242: val_loss did not improve from 0.12864
#
# Epoch 00243: val_loss improved from 0.12864 to 0.12848, saving model to ./model/243-0.1285.hdf5
#
# Epoch 00244: val_loss improved from 0.12848 to 0.12773, saving model to ./model/244-0.1277.hdf5
#
# Epoch 00245: val_loss improved from 0.12773 to 0.12615, saving model to ./model/245-0.1262.hdf5
#
# Epoch 00246: val_loss improved from 0.12615 to 0.12560, saving model to ./model/246-0.1256.hdf5
#
# Epoch 00247: val_loss did not improve from 0.12560
#
# Epoch 00248: val_loss did not improve from 0.12560
#
# Epoch 00249: val_loss did not improve from 0.12560
#
# Epoch 00250: val_loss did not improve from 0.12560
#
# Epoch 00251: val_loss did not improve from 0.12560
#
# Epoch 00252: val_loss improved from 0.12560 to 0.12536, saving model to ./model/252-0.1254.hdf5
#
# Epoch 00253: val_loss did not improve from 0.12536
#
# Epoch 00254: val_loss did not improve from 0.12536
#
# Epoch 00255: val_loss did not improve from 0.12536
#
# Epoch 00256: val_loss did not improve from 0.12536
#
# Epoch 00257: val_loss improved from 0.12536 to 0.12372, saving model to ./model/257-0.1237.hdf5
#
# Epoch 00258: val_loss improved from 0.12372 to 0.12303, saving model to ./model/258-0.1230.hdf5
#
# Epoch 00259: val_loss did not improve from 0.12303
#
# Epoch 00260: val_loss did not improve from 0.12303
#
# Epoch 00261: val_loss did not improve from 0.12303
#
# Epoch 00262: val_loss did not improve from 0.12303
#
# Epoch 00263: val_loss improved from 0.12303 to 0.12050, saving model to ./model/263-0.1205.hdf5
#
# Epoch 00264: val_loss did not improve from 0.12050
#
# Epoch 00265: val_loss did not improve from 0.12050
#
# Epoch 00266: val_loss did not improve from 0.12050
#
# Epoch 00267: val_loss did not improve from 0.12050
#
# Epoch 00268: val_loss improved from 0.12050 to 0.12026, saving model to ./model/268-0.1203.hdf5
#
# Epoch 00269: val_loss improved from 0.12026 to 0.11892, saving model to ./model/269-0.1189.hdf5
#
# Epoch 00270: val_loss did not improve from 0.11892
#
# Epoch 00271: val_loss did not improve from 0.11892
#
# Epoch 00272: val_loss did not improve from 0.11892
#
# Epoch 00273: val_loss did not improve from 0.11892
#
# Epoch 00274: val_loss did not improve from 0.11892
#
# Epoch 00275: val_loss did not improve from 0.11892
#
# Epoch 00276: val_loss did not improve from 0.11892
#
# Epoch 00277: val_loss did not improve from 0.11892
#
# Epoch 00278: val_loss improved from 0.11892 to 0.11855, saving model to ./model/278-0.1186.hdf5
#
# Epoch 00279: val_loss improved from 0.11855 to 0.11835, saving model to ./model/279-0.1184.hdf5
#
# Epoch 00280: val_loss did not improve from 0.11835
#
# Epoch 00281: val_loss did not improve from 0.11835
#
# Epoch 00282: val_loss did not improve from 0.11835
#
# Epoch 00283: val_loss improved from 0.11835 to 0.11668, saving model to ./model/283-0.1167.hdf5
#
# Epoch 00284: val_loss did not improve from 0.11668
#
# Epoch 00285: val_loss did not improve from 0.11668
#
# Epoch 00286: val_loss did not improve from 0.11668
#
# Epoch 00287: val_loss improved from 0.11668 to 0.11561, saving model to ./model/287-0.1156.hdf5
#
# Epoch 00288: val_loss did not improve from 0.11561
#
# Epoch 00289: val_loss did not improve from 0.11561
#
# Epoch 00290: val_loss did not improve from 0.11561
#
# Epoch 00291: val_loss did not improve from 0.11561
#
# Epoch 00292: val_loss did not improve from 0.11561
#
# Epoch 00293: val_loss did not improve from 0.11561
#
# Epoch 00294: val_loss did not improve from 0.11561
#
# Epoch 00295: val_loss did not improve from 0.11561
#
# Epoch 00296: val_loss did not improve from 0.11561
#
# Epoch 00297: val_loss did not improve from 0.11561
#
# Epoch 00298: val_loss did not improve from 0.11561
#
# Epoch 00299: val_loss did not improve from 0.11561
#
# Epoch 00300: val_loss improved from 0.11561 to 0.11484, saving model to ./model/300-0.1148.hdf5
#
# Epoch 00301: val_loss did not improve from 0.11484
#
# Epoch 00302: val_loss did not improve from 0.11484
#
# Epoch 00303: val_loss improved from 0.11484 to 0.11361, saving model to ./model/303-0.1136.hdf5
#
# Epoch 00304: val_loss improved from 0.11361 to 0.11321, saving model to ./model/304-0.1132.hdf5
#
# Epoch 00305: val_loss did not improve from 0.11321
#
# Epoch 00306: val_loss did not improve from 0.11321
#
# Epoch 00307: val_loss did not improve from 0.11321
#
# Epoch 00308: val_loss did not improve from 0.11321
#
# Epoch 00309: val_loss did not improve from 0.11321
#
# Epoch 00310: val_loss improved from 0.11321 to 0.11319, saving model to ./model/310-0.1132.hdf5
#
# Epoch 00311: val_loss did not improve from 0.11319
#
# Epoch 00312: val_loss did not improve from 0.11319
#
# Epoch 00313: val_loss did not improve from 0.11319
#
# Epoch 00314: val_loss improved from 0.11319 to 0.11184, saving model to ./model/314-0.1118.hdf5
#
# Epoch 00315: val_loss did not improve from 0.11184
#
# Epoch 00316: val_loss did not improve from 0.11184
#
# Epoch 00317: val_loss improved from 0.11184 to 0.11130, saving model to ./model/317-0.1113.hdf5
#
# Epoch 00318: val_loss improved from 0.11130 to 0.10912, saving model to ./model/318-0.1091.hdf5
#
# Epoch 00319: val_loss did not improve from 0.10912
#
# Epoch 00320: val_loss did not improve from 0.10912
#
# Epoch 00321: val_loss did not improve from 0.10912
#
# Epoch 00322: val_loss did not improve from 0.10912
#
# Epoch 00323: val_loss did not improve from 0.10912
#
# Epoch 00324: val_loss did not improve from 0.10912
#
# Epoch 00325: val_loss did not improve from 0.10912
#
# Epoch 00326: val_loss did not improve from 0.10912
#
# Epoch 00327: val_loss did not improve from 0.10912
#
# Epoch 00328: val_loss did not improve from 0.10912
#
# Epoch 00329: val_loss improved from 0.10912 to 0.10893, saving model to ./model/329-0.1089.hdf5
#
# Epoch 00330: val_loss did not improve from 0.10893
#
# Epoch 00331: val_loss did not improve from 0.10893
#
# Epoch 00332: val_loss did not improve from 0.10893
#
# Epoch 00333: val_loss improved from 0.10893 to 0.10836, saving model to ./model/333-0.1084.hdf5
#
# Epoch 00334: val_loss improved from 0.10836 to 0.10749, saving model to ./model/334-0.1075.hdf5
#
# Epoch 00335: val_loss did not improve from 0.10749
#
# Epoch 00336: val_loss did not improve from 0.10749
#
# Epoch 00337: val_loss did not improve from 0.10749
#
# Epoch 00338: val_loss did not improve from 0.10749
#
# Epoch 00339: val_loss improved from 0.10749 to 0.10685, saving model to ./model/339-0.1069.hdf5
#
# Epoch 00340: val_loss did not improve from 0.10685
#
# Epoch 00341: val_loss did not improve from 0.10685
#
# Epoch 00342: val_loss did not improve from 0.10685
#
# Epoch 00343: val_loss improved from 0.10685 to 0.10449, saving model to ./model/343-0.1045.hdf5
#
# Epoch 00344: val_loss did not improve from 0.10449
#
# Epoch 00345: val_loss did not improve from 0.10449
#
# Epoch 00346: val_loss did not improve from 0.10449
#
# Epoch 00347: val_loss improved from 0.10449 to 0.10326, saving model to ./model/347-0.1033.hdf5
#
# Epoch 00348: val_loss did not improve from 0.10326
#
# Epoch 00349: val_loss did not improve from 0.10326
#
# Epoch 00350: val_loss did not improve from 0.10326
#
# Epoch 00351: val_loss did not improve from 0.10326
#
# Epoch 00352: val_loss improved from 0.10326 to 0.10262, saving model to ./model/352-0.1026.hdf5
#
# Epoch 00353: val_loss did not improve from 0.10262
#
# Epoch 00354: val_loss did not improve from 0.10262
#
# Epoch 00355: val_loss did not improve from 0.10262
#
# Epoch 00356: val_loss improved from 0.10262 to 0.10178, saving model to ./model/356-0.1018.hdf5
#
# Epoch 00357: val_loss did not improve from 0.10178
#
# Epoch 00358: val_loss did not improve from 0.10178
#
# Epoch 00359: val_loss did not improve from 0.10178
#
# Epoch 00360: val_loss improved from 0.10178 to 0.10165, saving model to ./model/360-0.1016.hdf5
#
# Epoch 00361: val_loss did not improve from 0.10165
#
# Epoch 00362: val_loss did not improve from 0.10165
#
# Epoch 00363: val_loss did not improve from 0.10165
#
# Epoch 00364: val_loss did not improve from 0.10165
#
# Epoch 00365: val_loss improved from 0.10165 to 0.10064, saving model to ./model/365-0.1006.hdf5
#
# Epoch 00366: val_loss did not improve from 0.10064
#
# Epoch 00367: val_loss did not improve from 0.10064
#
# Epoch 00368: val_loss did not improve from 0.10064
#
# Epoch 00369: val_loss improved from 0.10064 to 0.10005, saving model to ./model/369-0.1000.hdf5
#
# Epoch 00370: val_loss did not improve from 0.10005
#
# Epoch 00371: val_loss did not improve from 0.10005
#
# Epoch 00372: val_loss did not improve from 0.10005
#
# Epoch 00373: val_loss did not improve from 0.10005
#
# Epoch 00374: val_loss did not improve from 0.10005
#
# Epoch 00375: val_loss did not improve from 0.10005
#
# Epoch 00376: val_loss did not improve from 0.10005
#
# Epoch 00377: val_loss did not improve from 0.10005
#
# Epoch 00378: val_loss did not improve from 0.10005
#
# Epoch 00379: val_loss did not improve from 0.10005
#
# Epoch 00380: val_loss did not improve from 0.10005
#
# Epoch 00381: val_loss did not improve from 0.10005
#
# Epoch 00382: val_loss did not improve from 0.10005
#
# Epoch 00383: val_loss did not improve from 0.10005
#
# Epoch 00384: val_loss did not improve from 0.10005
#
# Epoch 00385: val_loss did not improve from 0.10005
#
# Epoch 00386: val_loss did not improve from 0.10005
#
# Epoch 00387: val_loss did not improve from 0.10005
#
# Epoch 00388: val_loss did not improve from 0.10005
#
# Epoch 00389: val_loss did not improve from 0.10005
#
# Epoch 00390: val_loss did not improve from 0.10005
#
# Epoch 00391: val_loss did not improve from 0.10005
#
# Epoch 00392: val_loss did not improve from 0.10005
#
# Epoch 00393: val_loss improved from 0.10005 to 0.09868, saving model to ./model/393-0.0987.hdf5
#
# Epoch 00394: val_loss did not improve from 0.09868
#
# Epoch 00395: val_loss did not improve from 0.09868
#
# Epoch 00396: val_loss did not improve from 0.09868
#
# Epoch 00397: val_loss improved from 0.09868 to 0.09786, saving model to ./model/397-0.0979.hdf5
#
# Epoch 00398: val_loss improved from 0.09786 to 0.09738, saving model to ./model/398-0.0974.hdf5
#
# Epoch 00399: val_loss did not improve from 0.09738
#
# Epoch 00400: val_loss did not improve from 0.09738
#
# Epoch 00401: val_loss did not improve from 0.09738
#
# Epoch 00402: val_loss improved from 0.09738 to 0.09652, saving model to ./model/402-0.0965.hdf5
#
# Epoch 00403: val_loss did not improve from 0.09652
#
# Epoch 00404: val_loss did not improve from 0.09652
#
# Epoch 00405: val_loss did not improve from 0.09652
#
# Epoch 00406: val_loss did not improve from 0.09652
#
# Epoch 00407: val_loss did not improve from 0.09652
#
# Epoch 00408: val_loss did not improve from 0.09652
#
# Epoch 00409: val_loss did not improve from 0.09652
#
# Epoch 00410: val_loss did not improve from 0.09652
#
# Epoch 00411: val_loss improved from 0.09652 to 0.09612, saving model to ./model/411-0.0961.hdf5
#
# Epoch 00412: val_loss did not improve from 0.09612
#
# Epoch 00413: val_loss did not improve from 0.09612
#
# Epoch 00414: val_loss did not improve from 0.09612
#
# Epoch 00415: val_loss did not improve from 0.09612
#
# Epoch 00416: val_loss did not improve from 0.09612
#
# Epoch 00417: val_loss did not improve from 0.09612
#
# Epoch 00418: val_loss did not improve from 0.09612
#
# Epoch 00419: val_loss improved from 0.09612 to 0.09505, saving model to ./model/419-0.0951.hdf5
#
# Epoch 00420: val_loss did not improve from 0.09505
#
# Epoch 00421: val_loss did not improve from 0.09505
#
# Epoch 00422: val_loss did not improve from 0.09505
#
# Epoch 00423: val_loss did not improve from 0.09505
#
# Epoch 00424: val_loss did not improve from 0.09505
#
# Epoch 00425: val_loss did not improve from 0.09505
#
# Epoch 00426: val_loss did not improve from 0.09505
#
# Epoch 00427: val_loss did not improve from 0.09505
#
# Epoch 00428: val_loss did not improve from 0.09505
#
# Epoch 00429: val_loss did not improve from 0.09505
#
# Epoch 00430: val_loss did not improve from 0.09505
#
# Epoch 00431: val_loss did not improve from 0.09505
#
# Epoch 00432: val_loss did not improve from 0.09505
#
# Epoch 00433: val_loss did not improve from 0.09505
#
# Epoch 00434: val_loss improved from 0.09505 to 0.09499, saving model to ./model/434-0.0950.hdf5
#
# Epoch 00435: val_loss improved from 0.09499 to 0.09460, saving model to ./model/435-0.0946.hdf5
#
# Epoch 00436: val_loss did not improve from 0.09460
#
# Epoch 00437: val_loss did not improve from 0.09460
#
# Epoch 00438: val_loss did not improve from 0.09460
#
# Epoch 00439: val_loss improved from 0.09460 to 0.09372, saving model to ./model/439-0.0937.hdf5
#
# Epoch 00440: val_loss did not improve from 0.09372
#
# Epoch 00441: val_loss did not improve from 0.09372
#
# Epoch 00442: val_loss improved from 0.09372 to 0.09347, saving model to ./model/442-0.0935.hdf5
#
# Epoch 00443: val_loss did not improve from 0.09347
#
# Epoch 00444: val_loss did not improve from 0.09347
#
# Epoch 00445: val_loss did not improve from 0.09347
#
# Epoch 00446: val_loss did not improve from 0.09347
#
# Epoch 00447: val_loss did not improve from 0.09347
#
# Epoch 00448: val_loss did not improve from 0.09347
#
# Epoch 00449: val_loss did not improve from 0.09347
#
# Epoch 00450: val_loss did not improve from 0.09347
#
# Epoch 00451: val_loss did not improve from 0.09347
#
# Epoch 00452: val_loss did not improve from 0.09347
#
# Epoch 00453: val_loss did not improve from 0.09347
#
# Epoch 00454: val_loss improved from 0.09347 to 0.09304, saving model to ./model/454-0.0930.hdf5
#
# Epoch 00455: val_loss did not improve from 0.09304
#
# Epoch 00456: val_loss did not improve from 0.09304
#
# Epoch 00457: val_loss did not improve from 0.09304
#
# Epoch 00458: val_loss did not improve from 0.09304
#
# Epoch 00459: val_loss did not improve from 0.09304
#
# Epoch 00460: val_loss did not improve from 0.09304
#
# Epoch 00461: val_loss did not improve from 0.09304
#
# Epoch 00462: val_loss did not improve from 0.09304
#
# Epoch 00463: val_loss did not improve from 0.09304
#
# Epoch 00464: val_loss did not improve from 0.09304
#
# Epoch 00465: val_loss improved from 0.09304 to 0.09150, saving model to ./model/465-0.0915.hdf5
#
# Epoch 00466: val_loss did not improve from 0.09150
#
# Epoch 00467: val_loss did not improve from 0.09150
#
# Epoch 00468: val_loss did not improve from 0.09150
#
# Epoch 00469: val_loss improved from 0.09150 to 0.09079, saving model to ./model/469-0.0908.hdf5
#
# Epoch 00470: val_loss did not improve from 0.09079
#
# Epoch 00471: val_loss did not improve from 0.09079
#
# Epoch 00472: val_loss improved from 0.09079 to 0.09040, saving model to ./model/472-0.0904.hdf5
#
# Epoch 00473: val_loss improved from 0.09040 to 0.08940, saving model to ./model/473-0.0894.hdf5
#
# Epoch 00474: val_loss did not improve from 0.08940
#
# Epoch 00475: val_loss did not improve from 0.08940
#
# Epoch 00476: val_loss did not improve from 0.08940
#
# Epoch 00477: val_loss did not improve from 0.08940
#
# Epoch 00478: val_loss did not improve from 0.08940
#
# Epoch 00479: val_loss did not improve from 0.08940
#
# Epoch 00480: val_loss did not improve from 0.08940
#
# Epoch 00481: val_loss did not improve from 0.08940
#
# Epoch 00482: val_loss did not improve from 0.08940
#
# Epoch 00483: val_loss did not improve from 0.08940
#
# Epoch 00484: val_loss did not improve from 0.08940
#
# Epoch 00485: val_loss did not improve from 0.08940
#
# Epoch 00486: val_loss did not improve from 0.08940
#
# Epoch 00487: val_loss did not improve from 0.08940
#
# Epoch 00488: val_loss did not improve from 0.08940
#
# Epoch 00489: val_loss did not improve from 0.08940
#
# Epoch 00490: val_loss improved from 0.08940 to 0.08893, saving model to ./model/490-0.0889.hdf5
#
# Epoch 00491: val_loss did not improve from 0.08893
#
# Epoch 00492: val_loss did not improve from 0.08893
#
# Epoch 00493: val_loss did not improve from 0.08893
#
# Epoch 00494: val_loss did not improve from 0.08893
#
# Epoch 00495: val_loss did not improve from 0.08893
#
# Epoch 00496: val_loss improved from 0.08893 to 0.08884, saving model to ./model/496-0.0888.hdf5
#
# Epoch 00497: val_loss improved from 0.08884 to 0.08801, saving model to ./model/497-0.0880.hdf5
#
# Epoch 00498: val_loss did not improve from 0.08801
#
# Epoch 00499: val_loss did not improve from 0.08801
#
# Epoch 00500: val_loss did not improve from 0.08801
#
# Epoch 00501: val_loss improved from 0.08801 to 0.08685, saving model to ./model/501-0.0869.hdf5
#
# Epoch 00502: val_loss did not improve from 0.08685
#
# Epoch 00503: val_loss did not improve from 0.08685
#
# Epoch 00504: val_loss did not improve from 0.08685
#
# Epoch 00505: val_loss improved from 0.08685 to 0.08644, saving model to ./model/505-0.0864.hdf5
#
# Epoch 00506: val_loss did not improve from 0.08644
#
# Epoch 00507: val_loss did not improve from 0.08644
#
# Epoch 00508: val_loss did not improve from 0.08644
#
# Epoch 00509: val_loss did not improve from 0.08644
#
# Epoch 00510: val_loss did not improve from 0.08644
#
# Epoch 00511: val_loss did not improve from 0.08644
#
# Epoch 00512: val_loss did not improve from 0.08644
#
# Epoch 00513: val_loss did not improve from 0.08644
#
# Epoch 00514: val_loss did not improve from 0.08644
#
# Epoch 00515: val_loss did not improve from 0.08644
#
# Epoch 00516: val_loss did not improve from 0.08644
#
# Epoch 00517: val_loss did not improve from 0.08644
#
# Epoch 00518: val_loss did not improve from 0.08644
#
# Epoch 00519: val_loss did not improve from 0.08644
#
# Epoch 00520: val_loss did not improve from 0.08644
#
# Epoch 00521: val_loss did not improve from 0.08644
#
# Epoch 00522: val_loss did not improve from 0.08644
#
# Epoch 00523: val_loss did not improve from 0.08644
#
# Epoch 00524: val_loss did not improve from 0.08644
#
# Epoch 00525: val_loss did not improve from 0.08644
#
# Epoch 00526: val_loss improved from 0.08644 to 0.08638, saving model to ./model/526-0.0864.hdf5
#
# Epoch 00527: val_loss did not improve from 0.08638
#
# Epoch 00528: val_loss did not improve from 0.08638
#
# Epoch 00529: val_loss improved from 0.08638 to 0.08601, saving model to ./model/529-0.0860.hdf5
#
# Epoch 00530: val_loss did not improve from 0.08601
#
# Epoch 00531: val_loss did not improve from 0.08601
#
# Epoch 00532: val_loss did not improve from 0.08601
#
# Epoch 00533: val_loss did not improve from 0.08601
#
# Epoch 00534: val_loss did not improve from 0.08601
#
# Epoch 00535: val_loss did not improve from 0.08601
#
# Epoch 00536: val_loss improved from 0.08601 to 0.08592, saving model to ./model/536-0.0859.hdf5
#
# Epoch 00537: val_loss did not improve from 0.08592
#
# Epoch 00538: val_loss did not improve from 0.08592
#
# Epoch 00539: val_loss did not improve from 0.08592
#
# Epoch 00540: val_loss did not improve from 0.08592
#
# Epoch 00541: val_loss improved from 0.08592 to 0.08559, saving model to ./model/541-0.0856.hdf5
#
# Epoch 00542: val_loss did not improve from 0.08559
#
# Epoch 00543: val_loss did not improve from 0.08559
#
# Epoch 00544: val_loss did not improve from 0.08559
#
# Epoch 00545: val_loss improved from 0.08559 to 0.08558, saving model to ./model/545-0.0856.hdf5
#
# Epoch 00546: val_loss did not improve from 0.08558
#
# Epoch 00547: val_loss did not improve from 0.08558
#
# Epoch 00548: val_loss did not improve from 0.08558
#
# Epoch 00549: val_loss did not improve from 0.08558
#
# Epoch 00550: val_loss did not improve from 0.08558
#
# Epoch 00551: val_loss did not improve from 0.08558
#
# Epoch 00552: val_loss did not improve from 0.08558
#
# Epoch 00553: val_loss improved from 0.08558 to 0.08502, saving model to ./model/553-0.0850.hdf5
#
# Epoch 00554: val_loss improved from 0.08502 to 0.08478, saving model to ./model/554-0.0848.hdf5
#
# Epoch 00555: val_loss did not improve from 0.08478
#
# Epoch 00556: val_loss did not improve from 0.08478
#
# Epoch 00557: val_loss did not improve from 0.08478
#
# Epoch 00558: val_loss did not improve from 0.08478
#
# Epoch 00559: val_loss did not improve from 0.08478
#
# Epoch 00560: val_loss improved from 0.08478 to 0.08290, saving model to ./model/560-0.0829.hdf5
#
# Epoch 00561: val_loss did not improve from 0.08290
#
# Epoch 00562: val_loss did not improve from 0.08290
#
# Epoch 00563: val_loss did not improve from 0.08290
#
# Epoch 00564: val_loss improved from 0.08290 to 0.08251, saving model to ./model/564-0.0825.hdf5
#
# Epoch 00565: val_loss improved from 0.08251 to 0.08242, saving model to ./model/565-0.0824.hdf5
#
# Epoch 00566: val_loss did not improve from 0.08242
#
# Epoch 00567: val_loss did not improve from 0.08242
#
# Epoch 00568: val_loss did not improve from 0.08242
#
# Epoch 00569: val_loss did not improve from 0.08242
#
# Epoch 00570: val_loss did not improve from 0.08242
#
# Epoch 00571: val_loss did not improve from 0.08242
#
# Epoch 00572: val_loss did not improve from 0.08242
#
# Epoch 00573: val_loss did not improve from 0.08242
#
# Epoch 00574: val_loss did not improve from 0.08242
#
# Epoch 00575: val_loss did not improve from 0.08242
#
# Epoch 00576: val_loss did not improve from 0.08242
#
# Epoch 00577: val_loss did not improve from 0.08242
#
# Epoch 00578: val_loss did not improve from 0.08242
#
# Epoch 00579: val_loss did not improve from 0.08242
#
# Epoch 00580: val_loss did not improve from 0.08242
#
# Epoch 00581: val_loss did not improve from 0.08242
#
# Epoch 00582: val_loss did not improve from 0.08242
#
# Epoch 00583: val_loss did not improve from 0.08242
#
# Epoch 00584: val_loss did not improve from 0.08242
#
# Epoch 00585: val_loss did not improve from 0.08242
#
# Epoch 00586: val_loss did not improve from 0.08242
#
# Epoch 00587: val_loss did not improve from 0.08242
#
# Epoch 00588: val_loss did not improve from 0.08242
#
# Epoch 00589: val_loss did not improve from 0.08242
#
# Epoch 00590: val_loss improved from 0.08242 to 0.08238, saving model to ./model/590-0.0824.hdf5
#
# Epoch 00591: val_loss did not improve from 0.08238
#
# Epoch 00592: val_loss did not improve from 0.08238
#
# Epoch 00593: val_loss did not improve from 0.08238
#
# Epoch 00594: val_loss improved from 0.08238 to 0.08163, saving model to ./model/594-0.0816.hdf5
#
# Epoch 00595: val_loss did not improve from 0.08163
#
# Epoch 00596: val_loss did not improve from 0.08163
#
# Epoch 00597: val_loss did not improve from 0.08163
#
# Epoch 00598: val_loss improved from 0.08163 to 0.08100, saving model to ./model/598-0.0810.hdf5
#
# Epoch 00599: val_loss did not improve from 0.08100
#
# Epoch 00600: val_loss did not improve from 0.08100
#
# Epoch 00601: val_loss did not improve from 0.08100
#
# Epoch 00602: val_loss did not improve from 0.08100
#
# Epoch 00603: val_loss did not improve from 0.08100
#
# Epoch 00604: val_loss did not improve from 0.08100
#
# Epoch 00605: val_loss did not improve from 0.08100
#
# Epoch 00606: val_loss did not improve from 0.08100
#
# Epoch 00607: val_loss improved from 0.08100 to 0.08071, saving model to ./model/607-0.0807.hdf5
#
# Epoch 00608: val_loss did not improve from 0.08071
#
# Epoch 00609: val_loss did not improve from 0.08071
#
# Epoch 00610: val_loss did not improve from 0.08071
#
# Epoch 00611: val_loss did not improve from 0.08071
#
# Epoch 00612: val_loss did not improve from 0.08071
#
# Epoch 00613: val_loss did not improve from 0.08071
#
# Epoch 00614: val_loss did not improve from 0.08071
#
# Epoch 00615: val_loss did not improve from 0.08071
#
# Epoch 00616: val_loss improved from 0.08071 to 0.07952, saving model to ./model/616-0.0795.hdf5
#
# Epoch 00617: val_loss did not improve from 0.07952
#
# Epoch 00618: val_loss did not improve from 0.07952
#
# Epoch 00619: val_loss did not improve from 0.07952
#
# Epoch 00620: val_loss did not improve from 0.07952
#
# Epoch 00621: val_loss did not improve from 0.07952
#
# Epoch 00622: val_loss did not improve from 0.07952
#
# Epoch 00623: val_loss did not improve from 0.07952
#
# Epoch 00624: val_loss did not improve from 0.07952
#
# Epoch 00625: val_loss did not improve from 0.07952
#
# Epoch 00626: val_loss did not improve from 0.07952
#
# Epoch 00627: val_loss did not improve from 0.07952
#
# Epoch 00628: val_loss did not improve from 0.07952
#
# Epoch 00629: val_loss improved from 0.07952 to 0.07946, saving model to ./model/629-0.0795.hdf5
#
# Epoch 00630: val_loss did not improve from 0.07946
#
# Epoch 00631: val_loss did not improve from 0.07946
#
# Epoch 00632: val_loss did not improve from 0.07946
#
# Epoch 00633: val_loss improved from 0.07946 to 0.07936, saving model to ./model/633-0.0794.hdf5
#
# Epoch 00634: val_loss did not improve from 0.07936
#
# Epoch 00635: val_loss did not improve from 0.07936
#
# Epoch 00636: val_loss did not improve from 0.07936
#
# Epoch 00637: val_loss improved from 0.07936 to 0.07848, saving model to ./model/637-0.0785.hdf5
#
# Epoch 00638: val_loss did not improve from 0.07848
#
# Epoch 00639: val_loss did not improve from 0.07848
#
# Epoch 00640: val_loss did not improve from 0.07848
#
# Epoch 00641: val_loss did not improve from 0.07848
#
# Epoch 00642: val_loss did not improve from 0.07848
#
# Epoch 00643: val_loss did not improve from 0.07848
#
# Epoch 00644: val_loss did not improve from 0.07848
#
# Epoch 00645: val_loss did not improve from 0.07848
#
# Epoch 00646: val_loss did not improve from 0.07848
#
# Epoch 00647: val_loss did not improve from 0.07848
#
# Epoch 00648: val_loss did not improve from 0.07848
#
# Epoch 00649: val_loss did not improve from 0.07848
#
# Epoch 00650: val_loss did not improve from 0.07848
#
# Epoch 00651: val_loss did not improve from 0.07848
#
# Epoch 00652: val_loss did not improve from 0.07848
#
# Epoch 00653: val_loss did not improve from 0.07848
#
# Epoch 00654: val_loss did not improve from 0.07848
#
# Epoch 00655: val_loss did not improve from 0.07848
#
# Epoch 00656: val_loss did not improve from 0.07848
#
# Epoch 00657: val_loss did not improve from 0.07848
#
# Epoch 00658: val_loss did not improve from 0.07848
#
# Epoch 00659: val_loss did not improve from 0.07848
#
# Epoch 00660: val_loss did not improve from 0.07848
#
# Epoch 00661: val_loss did not improve from 0.07848
#
# Epoch 00662: val_loss did not improve from 0.07848
#
# Epoch 00663: val_loss did not improve from 0.07848
#
# Epoch 00664: val_loss did not improve from 0.07848
#
# Epoch 00665: val_loss did not improve from 0.07848
#
# Epoch 00666: val_loss did not improve from 0.07848
#
# Epoch 00667: val_loss did not improve from 0.07848
#
# Epoch 00668: val_loss did not improve from 0.07848
#
# Epoch 00669: val_loss did not improve from 0.07848
#
# Epoch 00670: val_loss did not improve from 0.07848
#
# Epoch 00671: val_loss did not improve from 0.07848
#
# Epoch 00672: val_loss did not improve from 0.07848
#
# Epoch 00673: val_loss did not improve from 0.07848
#
# Epoch 00674: val_loss did not improve from 0.07848
#
# Epoch 00675: val_loss did not improve from 0.07848
#
# Epoch 00676: val_loss did not improve from 0.07848
#
# Epoch 00677: val_loss did not improve from 0.07848
#
# Epoch 00678: val_loss did not improve from 0.07848
#
# Epoch 00679: val_loss improved from 0.07848 to 0.07762, saving model to ./model/679-0.0776.hdf5
#
# Epoch 00680: val_loss did not improve from 0.07762
#
# Epoch 00681: val_loss did not improve from 0.07762
#
# Epoch 00682: val_loss did not improve from 0.07762
#
# Epoch 00683: val_loss improved from 0.07762 to 0.07727, saving model to ./model/683-0.0773.hdf5
#
# Epoch 00684: val_loss did not improve from 0.07727
#
# Epoch 00685: val_loss did not improve from 0.07727
#
# Epoch 00686: val_loss did not improve from 0.07727
#
# Epoch 00687: val_loss improved from 0.07727 to 0.07707, saving model to ./model/687-0.0771.hdf5
#
# Epoch 00688: val_loss did not improve from 0.07707
#
# Epoch 00689: val_loss did not improve from 0.07707
#
# Epoch 00690: val_loss did not improve from 0.07707
#
# Epoch 00691: val_loss did not improve from 0.07707
#
# Epoch 00692: val_loss did not improve from 0.07707
#
# Epoch 00693: val_loss did not improve from 0.07707
#
# Epoch 00694: val_loss did not improve from 0.07707
#
# Epoch 00695: val_loss did not improve from 0.07707
#
# Epoch 00696: val_loss did not improve from 0.07707
#
# Epoch 00697: val_loss did not improve from 0.07707
#
# Epoch 00698: val_loss did not improve from 0.07707
#
# Epoch 00699: val_loss improved from 0.07707 to 0.07623, saving model to ./model/699-0.0762.hdf5
#
# Epoch 00700: val_loss improved from 0.07623 to 0.07598, saving model to ./model/700-0.0760.hdf5
#
# Epoch 00701: val_loss did not improve from 0.07598
#
# Epoch 00702: val_loss did not improve from 0.07598
#
# Epoch 00703: val_loss did not improve from 0.07598
#
# Epoch 00704: val_loss did not improve from 0.07598
#
# Epoch 00705: val_loss did not improve from 0.07598
#
# Epoch 00706: val_loss did not improve from 0.07598
#
# Epoch 00707: val_loss improved from 0.07598 to 0.07510, saving model to ./model/707-0.0751.hdf5
#
# Epoch 00708: val_loss did not improve from 0.07510
#
# Epoch 00709: val_loss did not improve from 0.07510
#
# Epoch 00710: val_loss did not improve from 0.07510
#
# Epoch 00711: val_loss improved from 0.07510 to 0.07357, saving model to ./model/711-0.0736.hdf5
#
# Epoch 00712: val_loss did not improve from 0.07357
#
# Epoch 00713: val_loss did not improve from 0.07357
#
# Epoch 00714: val_loss did not improve from 0.07357
#
# Epoch 00715: val_loss did not improve from 0.07357
#
# Epoch 00716: val_loss did not improve from 0.07357
#
# Epoch 00717: val_loss did not improve from 0.07357
#
# Epoch 00718: val_loss did not improve from 0.07357
#
# Epoch 00719: val_loss did not improve from 0.07357
#
# Epoch 00720: val_loss did not improve from 0.07357
#
# Epoch 00721: val_loss did not improve from 0.07357
#
# Epoch 00722: val_loss did not improve from 0.07357
#
# Epoch 00723: val_loss did not improve from 0.07357
#
# Epoch 00724: val_loss did not improve from 0.07357
#
# Epoch 00725: val_loss did not improve from 0.07357
#
# Epoch 00726: val_loss did not improve from 0.07357
#
# Epoch 00727: val_loss improved from 0.07357 to 0.07341, saving model to ./model/727-0.0734.hdf5
#
# Epoch 00728: val_loss did not improve from 0.07341
#
# Epoch 00729: val_loss did not improve from 0.07341
#
# Epoch 00730: val_loss did not improve from 0.07341
#
# Epoch 00731: val_loss improved from 0.07341 to 0.07280, saving model to ./model/731-0.0728.hdf5
#
# Epoch 00732: val_loss did not improve from 0.07280
#
# Epoch 00733: val_loss did not improve from 0.07280
#
# Epoch 00734: val_loss did not improve from 0.07280
#
# Epoch 00735: val_loss did not improve from 0.07280
#
# Epoch 00736: val_loss did not improve from 0.07280
#
# Epoch 00737: val_loss did not improve from 0.07280
#
# Epoch 00738: val_loss did not improve from 0.07280
#
# Epoch 00739: val_loss did not improve from 0.07280
#
# Epoch 00740: val_loss did not improve from 0.07280
#
# Epoch 00741: val_loss did not improve from 0.07280
#
# Epoch 00742: val_loss improved from 0.07280 to 0.07226, saving model to ./model/742-0.0723.hdf5
#
# ...
#
# Epoch 01196: val_loss did not improve from 0.05831
#
# Epoch 01197: val_loss did not improve from 0.05831
#
# Epoch 01198: val_loss did not improve from 0.05831
#
# Epoch 01199: val_loss did not improve from 0.05831
#
# Epoch 01200: val_loss did not improve from 0.05831
#
# Epoch 01201: val_loss did not improve from 0.05831
#
# Epoch 01202: val_loss did not improve from 0.05831
#
# Epoch 01203: val_loss did not improve from 0.05831
#
# Epoch 01204: val_loss did not improve from 0.05831
#
# Epoch 01205: val_loss did not improve from 0.05831
#
# Epoch 01206: val_loss did not improve from 0.05831
#
# Epoch 01207: val_loss did not improve from 0.05831
#
# Epoch 01208: val_loss did not improve from 0.05831
#
# Epoch 01209: val_loss did not improve from 0.05831
#
# Epoch 01210: val_loss did not improve from 0.05831
#
# Epoch 01211: val_loss did not improve from 0.05831
#
# Epoch 01212: val_loss did not improve from 0.05831
#
# Epoch 01213: val_loss did not improve from 0.05831
#
# Epoch 01214: val_loss did not improve from 0.05831
#
# Epoch 01215: val_loss did not improve from 0.05831
#
# Epoch 01216: val_loss did not improve from 0.05831
#
# Epoch 01217: val_loss did not improve from 0.05831
#
# Epoch 01218: val_loss did not improve from 0.05831
#
# Epoch 01219: val_loss did not improve from 0.05831
#
# Epoch 01220: val_loss did not improve from 0.05831
#
# Epoch 01221: val_loss did not improve from 0.05831
#
# Epoch 01222: val_loss did not improve from 0.05831
#
# Epoch 01223: val_loss did not improve from 0.05831
#
# Epoch 01224: val_loss did not improve from 0.05831
#
# Epoch 01225: val_loss did not improve from 0.05831
#
# Epoch 01226: val_loss did not improve from 0.05831
#
# Epoch 01227: val_loss did not improve from 0.05831
#
# Epoch 01228: val_loss did not improve from 0.05831
#
# Epoch 01229: val_loss did not improve from 0.05831
#
# Epoch 01230: val_loss did not improve from 0.05831
#
# Epoch 01231: val_loss did not improve from 0.05831
#
# Epoch 01232: val_loss did not improve from 0.05831
#
# Epoch 01233: val_loss did not improve from 0.05831
#
# Epoch 01234: val_loss did not improve from 0.05831
#
# Epoch 01235: val_loss did not improve from 0.05831
#
# Epoch 01236: val_loss did not improve from 0.05831
#
# Epoch 01237: val_loss did not improve from 0.05831
#
# Epoch 01238: val_loss did not improve from 0.05831
#
# Epoch 01239: val_loss did not improve from 0.05831
#
# Epoch 01240: val_loss did not improve from 0.05831
#
# Epoch 01241: val_loss did not improve from 0.05831
#
# Epoch 01242: val_loss did not improve from 0.05831
#
# Epoch 01243: val_loss did not improve from 0.05831
#
# Epoch 01244: val_loss did not improve from 0.05831
#
# Epoch 01245: val_loss did not improve from 0.05831
#
# Epoch 01246: val_loss did not improve from 0.05831
#
# Epoch 01247: val_loss did not improve from 0.05831
#
# Epoch 01248: val_loss did not improve from 0.05831
#
# Epoch 01249: val_loss did not improve from 0.05831
#
# Epoch 01250: val_loss did not improve from 0.05831
#
# Epoch 01251: val_loss did not improve from 0.05831
#
# Epoch 01252: val_loss did not improve from 0.05831
#
# Epoch 01253: val_loss did not improve from 0.05831
#
# Epoch 01254: val_loss did not improve from 0.05831
#
# Epoch 01255: val_loss did not improve from 0.05831
#
# Epoch 01256: val_loss did not improve from 0.05831
#
# Epoch 01257: val_loss did not improve from 0.05831
#
# Epoch 01258: val_loss improved from 0.05831 to 0.05769, saving model to ./model/1258-0.0577.hdf5
#
# Epoch 01259: val_loss improved from 0.05769 to 0.05656, saving model to ./model/1259-0.0566.hdf5
#
# Epoch 01260: val_loss did not improve from 0.05656
#
# Epoch 01261: val_loss did not improve from 0.05656
#
# Epoch 01262: val_loss did not improve from 0.05656
#
# Epoch 01263: val_loss did not improve from 0.05656
#
# Epoch 01264: val_loss did not improve from 0.05656
#
# Epoch 01265: val_loss did not improve from 0.05656
#
# Epoch 01266: val_loss did not improve from 0.05656
#
# Epoch 01267: val_loss did not improve from 0.05656
#
# Epoch 01268: val_loss did not improve from 0.05656
#
# Epoch 01269: val_loss did not improve from 0.05656
#
# Epoch 01270: val_loss did not improve from 0.05656
#
# Epoch 01271: val_loss improved from 0.05656 to 0.05648, saving model to ./model/1271-0.0565.hdf5
#
# Epoch 01272: val_loss did not improve from 0.05648
#
# Epoch 01273: val_loss did not improve from 0.05648
#
# Epoch 01274: val_loss did not improve from 0.05648
#
# Epoch 01275: val_loss did not improve from 0.05648
#
# Epoch 01276: val_loss did not improve from 0.05648
#
# Epoch 01277: val_loss did not improve from 0.05648
#
# Epoch 01278: val_loss did not improve from 0.05648
#
# Epoch 01279: val_loss did not improve from 0.05648
#
# Epoch 01280: val_loss did not improve from 0.05648
#
# Epoch 01281: val_loss did not improve from 0.05648
#
# Epoch 01282: val_loss did not improve from 0.05648
#
# Epoch 01283: val_loss did not improve from 0.05648
#
# Epoch 01284: val_loss did not improve from 0.05648
#
# Epoch 01285: val_loss did not improve from 0.05648
#
# Epoch 01286: val_loss did not improve from 0.05648
#
# Epoch 01287: val_loss did not improve from 0.05648
#
# Epoch 01288: val_loss did not improve from 0.05648
#
# Epoch 01289: val_loss did not improve from 0.05648
#
# Epoch 01290: val_loss did not improve from 0.05648
#
# Epoch 01291: val_loss did not improve from 0.05648
#
# Epoch 01292: val_loss did not improve from 0.05648
#
# Epoch 01293: val_loss did not improve from 0.05648
#
# Epoch 01294: val_loss did not improve from 0.05648
#
# Epoch 01295: val_loss did not improve from 0.05648
#
# Epoch 01296: val_loss did not improve from 0.05648
#
# Epoch 01297: val_loss did not improve from 0.05648
#
# Epoch 01298: val_loss did not improve from 0.05648
#
# Epoch 01299: val_loss did not improve from 0.05648
#
# Epoch 01300: val_loss did not improve from 0.05648
#
# Epoch 01301: val_loss did not improve from 0.05648
#
# Epoch 01302: val_loss did not improve from 0.05648
#
# Epoch 01303: val_loss did not improve from 0.05648
#
# Epoch 01304: val_loss did not improve from 0.05648
#
# Epoch 01305: val_loss did not improve from 0.05648
#
# Epoch 01306: val_loss did not improve from 0.05648
#
# Epoch 01307: val_loss did not improve from 0.05648
#
# Epoch 01308: val_loss did not improve from 0.05648
#
# Epoch 01309: val_loss did not improve from 0.05648
#
# Epoch 01310: val_loss did not improve from 0.05648
#
# Epoch 01311: val_loss did not improve from 0.05648
#
# Epoch 01312: val_loss did not improve from 0.05648
#
# Epoch 01313: val_loss did not improve from 0.05648
#
# Epoch 01314: val_loss did not improve from 0.05648
#
# Epoch 01315: val_loss did not improve from 0.05648
#
# Epoch 01316: val_loss did not improve from 0.05648
#
# Epoch 01317: val_loss did not improve from 0.05648
#
# Epoch 01318: val_loss did not improve from 0.05648
#
# Epoch 01319: val_loss did not improve from 0.05648
#
# Epoch 01320: val_loss did not improve from 0.05648
#
# Epoch 01321: val_loss did not improve from 0.05648
#
# Epoch 01322: val_loss did not improve from 0.05648
#
# Epoch 01323: val_loss did not improve from 0.05648
#
# Epoch 01324: val_loss did not improve from 0.05648
#
# Epoch 01325: val_loss did not improve from 0.05648
#
# Epoch 01326: val_loss did not improve from 0.05648
#
# Epoch 01327: val_loss did not improve from 0.05648
#
# Epoch 01328: val_loss did not improve from 0.05648
#
# Epoch 01329: val_loss did not improve from 0.05648
#
# Epoch 01330: val_loss did not improve from 0.05648
#
# Epoch 01331: val_loss did not improve from 0.05648
#
# Epoch 01332: val_loss did not improve from 0.05648
#
# Epoch 01333: val_loss did not improve from 0.05648
#
# Epoch 01334: val_loss did not improve from 0.05648
#
# Epoch 01335: val_loss did not improve from 0.05648
#
# Epoch 01336: val_loss did not improve from 0.05648
#
# Epoch 01337: val_loss did not improve from 0.05648
#
# Epoch 01338: val_loss did not improve from 0.05648
#
# Epoch 01339: val_loss did not improve from 0.05648
#
# Epoch 01340: val_loss did not improve from 0.05648
#
# Epoch 01341: val_loss did not improve from 0.05648
#
# Epoch 01342: val_loss did not improve from 0.05648
#
# Epoch 01343: val_loss did not improve from 0.05648
#
# Epoch 01344: val_loss did not improve from 0.05648
#
# Epoch 01345: val_loss did not improve from 0.05648
#
# Epoch 01346: val_loss improved from 0.05648 to 0.05631, saving model to ./model/1346-0.0563.hdf5
#
# Epoch 01347: val_loss did not improve from 0.05631
#
# Epoch 01348: val_loss did not improve from 0.05631
#
# Epoch 01349: val_loss did not improve from 0.05631
#
# Epoch 01350: val_loss did not improve from 0.05631
#
# Epoch 01351: val_loss did not improve from 0.05631
#
# Epoch 01352: val_loss did not improve from 0.05631
#
# Epoch 01353: val_loss did not improve from 0.05631
#
# Epoch 01354: val_loss did not improve from 0.05631
#
# Epoch 01355: val_loss did not improve from 0.05631
#
# Epoch 01356: val_loss did not improve from 0.05631
#
# Epoch 01357: val_loss did not improve from 0.05631
#
# Epoch 01358: val_loss did not improve from 0.05631
#
# Epoch 01359: val_loss did not improve from 0.05631
#
# Epoch 01360: val_loss did not improve from 0.05631
#
# Epoch 01361: val_loss did not improve from 0.05631
#
# Epoch 01362: val_loss did not improve from 0.05631
#
# Epoch 01363: val_loss did not improve from 0.05631
#
# Epoch 01364: val_loss did not improve from 0.05631
#
# Epoch 01365: val_loss did not improve from 0.05631
#
# Epoch 01366: val_loss did not improve from 0.05631
#
# Epoch 01367: val_loss did not improve from 0.05631
#
# Epoch 01368: val_loss did not improve from 0.05631
#
# Epoch 01369: val_loss did not improve from 0.05631
#
# Epoch 01370: val_loss did not improve from 0.05631
#
# Epoch 01371: val_loss did not improve from 0.05631
#
# Epoch 01372: val_loss did not improve from 0.05631
#
# Epoch 01373: val_loss did not improve from 0.05631
#
# Epoch 01374: val_loss did not improve from 0.05631
#
# Epoch 01375: val_loss did not improve from 0.05631
#
# Epoch 01376: val_loss did not improve from 0.05631
#
# Epoch 01377: val_loss did not improve from 0.05631
#
# Epoch 01378: val_loss did not improve from 0.05631
#
# Epoch 01379: val_loss did not improve from 0.05631
#
# Epoch 01380: val_loss did not improve from 0.05631
#
# Epoch 01381: val_loss did not improve from 0.05631
#
# Epoch 01382: val_loss did not improve from 0.05631
#
# Epoch 01383: val_loss did not improve from 0.05631
#
# Epoch 01384: val_loss did not improve from 0.05631
#
# Epoch 01385: val_loss did not improve from 0.05631
#
# Epoch 01386: val_loss did not improve from 0.05631
#
# Epoch 01387: val_loss did not improve from 0.05631
#
# Epoch 01388: val_loss did not improve from 0.05631
#
# Epoch 01389: val_loss did not improve from 0.05631
#
# Epoch 01390: val_loss did not improve from 0.05631
#
# Epoch 01391: val_loss did not improve from 0.05631
#
# Epoch 01392: val_loss did not improve from 0.05631
#
# Epoch 01393: val_loss did not improve from 0.05631
#
# Epoch 01394: val_loss did not improve from 0.05631
#
# Epoch 01395: val_loss did not improve from 0.05631
#
# Epoch 01396: val_loss did not improve from 0.05631
#
# Epoch 01397: val_loss did not improve from 0.05631
#
# Epoch 01398: val_loss improved from 0.05631 to 0.05524, saving model to ./model/1398-0.0552.hdf5
#
# Epoch 01399: val_loss did not improve from 0.05524
#
# Epoch 01400: val_loss did not improve from 0.05524
#
# Epoch 01401: val_loss did not improve from 0.05524
#
# Epoch 01402: val_loss did not improve from 0.05524
#
# Epoch 01403: val_loss did not improve from 0.05524
#
# Epoch 01404: val_loss did not improve from 0.05524
#
# Epoch 01405: val_loss did not improve from 0.05524
#
# Epoch 01406: val_loss did not improve from 0.05524
#
# Epoch 01407: val_loss did not improve from 0.05524
#
# Epoch 01408: val_loss did not improve from 0.05524
#
# Epoch 01409: val_loss did not improve from 0.05524
#
# Epoch 01410: val_loss did not improve from 0.05524
#
# Epoch 01411: val_loss did not improve from 0.05524
#
# Epoch 01412: val_loss did not improve from 0.05524
#
# Epoch 01413: val_loss did not improve from 0.05524
#
# Epoch 01414: val_loss did not improve from 0.05524
#
# Epoch 01415: val_loss did not improve from 0.05524
#
# Epoch 01416: val_loss did not improve from 0.05524
#
# Epoch 01417: val_loss did not improve from 0.05524
#
# Epoch 01418: val_loss did not improve from 0.05524
#
# Epoch 01419: val_loss did not improve from 0.05524
#
# Epoch 01420: val_loss did not improve from 0.05524
#
# Epoch 01421: val_loss did not improve from 0.05524
#
# Epoch 01422: val_loss did not improve from 0.05524
#
# Epoch 01423: val_loss did not improve from 0.05524
#
# Epoch 01424: val_loss did not improve from 0.05524
#
# Epoch 01425: val_loss did not improve from 0.05524
#
# Epoch 01426: val_loss did not improve from 0.05524
#
# Epoch 01427: val_loss did not improve from 0.05524
#
# Epoch 01428: val_loss did not improve from 0.05524
#
# Epoch 01429: val_loss did not improve from 0.05524
#
# Epoch 01430: val_loss did not improve from 0.05524
#
# Epoch 01431: val_loss did not improve from 0.05524
#
# Epoch 01432: val_loss did not improve from 0.05524
#
# Epoch 01433: val_loss did not improve from 0.05524
#
# Epoch 01434: val_loss did not improve from 0.05524
#
# Epoch 01435: val_loss did not improve from 0.05524
#
# Epoch 01436: val_loss did not improve from 0.05524
#
# Epoch 01437: val_loss did not improve from 0.05524
#
# Epoch 01438: val_loss did not improve from 0.05524
#
# Epoch 01439: val_loss did not improve from 0.05524
#
# Epoch 01440: val_loss did not improve from 0.05524
#
# Epoch 01441: val_loss did not improve from 0.05524
#
# Epoch 01442: val_loss did not improve from 0.05524
#
# Epoch 01443: val_loss did not improve from 0.05524
#
# Epoch 01444: val_loss did not improve from 0.05524
#
# Epoch 01445: val_loss did not improve from 0.05524
#
# Epoch 01446: val_loss did not improve from 0.05524
#
# Epoch 01447: val_loss did not improve from 0.05524
#
# Epoch 01448: val_loss did not improve from 0.05524
#
# Epoch 01449: val_loss did not improve from 0.05524
#
# Epoch 01450: val_loss did not improve from 0.05524
#
# Epoch 01451: val_loss did not improve from 0.05524
#
# Epoch 01452: val_loss did not improve from 0.05524
#
# Epoch 01453: val_loss did not improve from 0.05524
#
# Epoch 01454: val_loss did not improve from 0.05524
#
# Epoch 01455: val_loss did not improve from 0.05524
#
# Epoch 01456: val_loss did not improve from 0.05524
#
# Epoch 01457: val_loss did not improve from 0.05524
#
# Epoch 01458: val_loss did not improve from 0.05524
#
# Epoch 01459: val_loss did not improve from 0.05524
#
# Epoch 01460: val_loss did not improve from 0.05524
#
# Epoch 01461: val_loss did not improve from 0.05524
#
# Epoch 01462: val_loss did not improve from 0.05524
#
# Epoch 01463: val_loss did not improve from 0.05524
#
# Epoch 01464: val_loss did not improve from 0.05524
#
# Epoch 01465: val_loss did not improve from 0.05524
#
# Epoch 01466: val_loss did not improve from 0.05524
#
# Epoch 01467: val_loss did not improve from 0.05524
#
# Epoch 01468: val_loss did not improve from 0.05524
#
# Epoch 01469: val_loss did not improve from 0.05524
#
# Epoch 01470: val_loss did not improve from 0.05524
#
# Epoch 01471: val_loss did not improve from 0.05524
#
# Epoch 01472: val_loss did not improve from 0.05524
#
# Epoch 01473: val_loss did not improve from 0.05524
#
# Epoch 01474: val_loss did not improve from 0.05524
#
# Epoch 01475: val_loss did not improve from 0.05524
#
# Epoch 01476: val_loss did not improve from 0.05524
#
# Epoch 01477: val_loss did not improve from 0.05524
#
# Epoch 01478: val_loss did not improve from 0.05524
#
# Epoch 01479: val_loss did not improve from 0.05524
#
# Epoch 01480: val_loss did not improve from 0.05524
#
# Epoch 01481: val_loss did not improve from 0.05524
#
# Epoch 01482: val_loss did not improve from 0.05524
#
# Epoch 01483: val_loss did not improve from 0.05524
#
# Epoch 01484: val_loss did not improve from 0.05524
#
# Epoch 01485: val_loss did not improve from 0.05524
#
# Epoch 01486: val_loss did not improve from 0.05524
#
# Epoch 01487: val_loss did not improve from 0.05524
#
# Epoch 01488: val_loss did not improve from 0.05524
#
# Epoch 01489: val_loss did not improve from 0.05524
#
# Epoch 01490: val_loss did not improve from 0.05524
#
# Epoch 01491: val_loss did not improve from 0.05524
#
# Epoch 01492: val_loss did not improve from 0.05524
#
# Epoch 01493: val_loss did not improve from 0.05524
#
# Epoch 01494: val_loss did not improve from 0.05524
#
# Epoch 01495: val_loss did not improve from 0.05524
#
# Epoch 01496: val_loss did not improve from 0.05524
#
# Epoch 01497: val_loss did not improve from 0.05524
#
# Epoch 01498: val_loss did not improve from 0.05524
