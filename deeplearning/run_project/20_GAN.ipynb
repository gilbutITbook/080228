# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7088  g_loss:0.6902
# epoch:1  d_loss:0.4522  g_loss:0.3372
# epoch:2  d_loss:0.4974  g_loss:0.0869
# epoch:3  d_loss:0.5613  g_loss:0.0402
# epoch:4  d_loss:0.5677  g_loss:0.0702
# epoch:5  d_loss:0.5295  g_loss:0.2231
# epoch:6  d_loss:0.4931  g_loss:0.4970
# epoch:7  d_loss:0.5091  g_loss:0.7294
# epoch:8  d_loss:0.5189  g_loss:0.7715
# epoch:9  d_loss:0.4831  g_loss:0.7910
# epoch:10  d_loss:0.4100  g_loss:0.8486
# epoch:11  d_loss:0.3848  g_loss:1.0181
# epoch:12  d_loss:0.3379  g_loss:1.2347
# epoch:13  d_loss:0.3442  g_loss:1.6277
# epoch:14  d_loss:0.4528  g_loss:1.6801
# epoch:15  d_loss:0.5774  g_loss:1.6810
# epoch:16  d_loss:0.6369  g_loss:1.6721
# epoch:17  d_loss:0.8093  g_loss:1.1350
# epoch:18  d_loss:0.6904  g_loss:0.9426
# epoch:19  d_loss:0.4779  g_loss:0.8701
# epoch:20  d_loss:0.4141  g_loss:0.8623
# epoch:21  d_loss:0.4661  g_loss:0.8384
# epoch:22  d_loss:0.4086  g_loss:0.7095
# epoch:23  d_loss:0.3367  g_loss:0.6585
# epoch:24  d_loss:0.3227  g_loss:0.9212
# epoch:25  d_loss:0.3438  g_loss:1.0008
# epoch:26  d_loss:0.3947  g_loss:0.9902
# epoch:27  d_loss:0.3396  g_loss:1.0100
# epoch:28  d_loss:0.2868  g_loss:1.1054
# epoch:29  d_loss:0.2896  g_loss:1.1437
# epoch:30  d_loss:0.2167  g_loss:1.4213
# epoch:31  d_loss:0.2587  g_loss:1.5991
# epoch:32  d_loss:0.2207  g_loss:1.9538
# epoch:33  d_loss:0.1548  g_loss:1.9702
# epoch:34  d_loss:0.1536  g_loss:1.9362
# epoch:35  d_loss:0.3813  g_loss:1.4901
# epoch:36  d_loss:0.2495  g_loss:1.6554
# epoch:37  d_loss:0.4268  g_loss:1.4301
# epoch:38  d_loss:0.8851  g_loss:1.4639
# epoch:39  d_loss:0.8286  g_loss:1.5413
# epoch:40  d_loss:1.0821  g_loss:0.9568
# epoch:41  d_loss:0.6730  g_loss:0.9255
# epoch:42  d_loss:0.2197  g_loss:1.8272
# epoch:43  d_loss:0.0651  g_loss:2.5778
# epoch:44  d_loss:0.0420  g_loss:3.5155
# epoch:45  d_loss:0.0239  g_loss:3.9876
# epoch:46  d_loss:0.0162  g_loss:4.1454
# epoch:47  d_loss:0.0292  g_loss:4.0338
# epoch:48  d_loss:0.0141  g_loss:2.3754
# epoch:49  d_loss:0.0312  g_loss:1.9012
# epoch:50  d_loss:0.0547  g_loss:1.4889
# epoch:51  d_loss:0.2585  g_loss:2.2801
# epoch:52  d_loss:0.1360  g_loss:2.7150
# epoch:53  d_loss:0.1045  g_loss:2.5287
# epoch:54  d_loss:0.5100  g_loss:2.2389
# epoch:55  d_loss:0.5417  g_loss:1.9288
# epoch:56  d_loss:0.6015  g_loss:1.4781
# epoch:57  d_loss:0.6002  g_loss:2.0978
# epoch:58  d_loss:0.7343  g_loss:2.4812
# epoch:59  d_loss:0.8023  g_loss:1.8590
# epoch:60  d_loss:1.1651  g_loss:1.5858
# epoch:61  d_loss:0.8139  g_loss:1.7618
# epoch:62  d_loss:0.8682  g_loss:2.1906
# epoch:63  d_loss:0.7081  g_loss:2.4279
# epoch:64  d_loss:0.6741  g_loss:2.1425
# epoch:65  d_loss:0.6615  g_loss:2.5020
# epoch:66  d_loss:0.5265  g_loss:2.2837
# epoch:67  d_loss:0.3906  g_loss:2.4131
# epoch:68  d_loss:0.3882  g_loss:2.5810
# epoch:69  d_loss:0.3470  g_loss:2.8464
# epoch:70  d_loss:0.4227  g_loss:2.4881
# epoch:71  d_loss:0.2360  g_loss:2.5068
# epoch:72  d_loss:0.3648  g_loss:2.4555
# epoch:73  d_loss:0.2774  g_loss:2.2120
# epoch:74  d_loss:0.3991  g_loss:2.2598
# epoch:75  d_loss:0.4061  g_loss:2.0202
# epoch:76  d_loss:0.3372  g_loss:1.9465
# epoch:77  d_loss:0.3884  g_loss:1.7421
# epoch:78  d_loss:0.3531  g_loss:1.5440
# epoch:79  d_loss:0.4179  g_loss:1.1276
# epoch:80  d_loss:0.5139  g_loss:0.9603
# epoch:81  d_loss:0.4271  g_loss:1.1423
# epoch:82  d_loss:0.4854  g_loss:0.8921
# epoch:83  d_loss:0.5417  g_loss:0.9442
# epoch:84  d_loss:0.6130  g_loss:0.9255
# epoch:85  d_loss:0.5167  g_loss:0.9225
# epoch:86  d_loss:0.7620  g_loss:0.8860
# epoch:87  d_loss:0.7072  g_loss:0.7403
# epoch:88  d_loss:0.6170  g_loss:0.8260
# epoch:89  d_loss:0.7947  g_loss:0.9485
# epoch:90  d_loss:0.5430  g_loss:1.2640
# epoch:91  d_loss:0.5451  g_loss:1.6002
# epoch:92  d_loss:0.4127  g_loss:2.0294
# epoch:93  d_loss:0.3076  g_loss:2.4110
# epoch:94  d_loss:0.2806  g_loss:2.6996
# epoch:95  d_loss:0.1937  g_loss:2.6263
# epoch:96  d_loss:0.2701  g_loss:2.8075
# epoch:97  d_loss:0.3058  g_loss:2.4633
# epoch:98  d_loss:0.2985  g_loss:3.0273
# epoch:99  d_loss:0.2895  g_loss:2.7989
# epoch:100  d_loss:0.2015  g_loss:3.2853
# epoch:101  d_loss:0.4848  g_loss:2.4145
# epoch:102  d_loss:0.6992  g_loss:2.3163
# epoch:103  d_loss:0.4114  g_loss:3.0477
# epoch:104  d_loss:0.7645  g_loss:2.4038
# epoch:105  d_loss:0.7892  g_loss:1.7591
# epoch:106  d_loss:0.8228  g_loss:1.2902
# epoch:107  d_loss:0.8111  g_loss:1.6054
# epoch:108  d_loss:0.6417  g_loss:1.6298
# epoch:109  d_loss:0.8169  g_loss:1.7085
# epoch:110  d_loss:0.7038  g_loss:1.7082
# epoch:111  d_loss:0.8201  g_loss:1.1893
# epoch:112  d_loss:0.7560  g_loss:1.0422
# epoch:113  d_loss:0.6439  g_loss:1.0159
# epoch:114  d_loss:0.5179  g_loss:1.2720
# epoch:115  d_loss:0.5287  g_loss:1.4810
# epoch:116  d_loss:0.4777  g_loss:1.4435
# epoch:117  d_loss:0.4432  g_loss:1.4716
# epoch:118  d_loss:0.4537  g_loss:1.3779
# epoch:119  d_loss:0.3773  g_loss:1.4141
# epoch:120  d_loss:0.4209  g_loss:1.2660
# epoch:121  d_loss:0.4031  g_loss:1.3074
# epoch:122  d_loss:0.4477  g_loss:1.2459
# epoch:123  d_loss:0.4159  g_loss:1.3979
# epoch:124  d_loss:0.2689  g_loss:1.4307
# epoch:125  d_loss:0.3437  g_loss:1.5112
# epoch:126  d_loss:0.4127  g_loss:1.3869
# epoch:127  d_loss:0.3521  g_loss:1.2425
# epoch:128  d_loss:0.3955  g_loss:1.2728
# epoch:129  d_loss:0.3802  g_loss:1.5183
# epoch:130  d_loss:0.3043  g_loss:1.4466
# epoch:131  d_loss:0.3033  g_loss:1.5831
# epoch:132  d_loss:0.3199  g_loss:1.4662
# epoch:133  d_loss:0.3518  g_loss:1.6728
# epoch:134  d_loss:0.4735  g_loss:1.5746
# epoch:135  d_loss:0.3957  g_loss:1.0893
# epoch:136  d_loss:0.3974  g_loss:1.2114
# epoch:137  d_loss:0.3822  g_loss:1.1106
# epoch:138  d_loss:0.4731  g_loss:1.2518
# epoch:139  d_loss:0.6516  g_loss:1.1450
# epoch:140  d_loss:0.5691  g_loss:1.0912
# epoch:141  d_loss:0.4287  g_loss:1.3579
# epoch:142  d_loss:0.3666  g_loss:1.4283
# epoch:143  d_loss:0.4602  g_loss:1.3824
# epoch:144  d_loss:0.4890  g_loss:1.4581
# epoch:145  d_loss:0.5487  g_loss:1.1453
# epoch:146  d_loss:0.4485  g_loss:1.3639
# epoch:147  d_loss:0.4836  g_loss:1.4843
# epoch:148  d_loss:0.4884  g_loss:1.4465
# epoch:149  d_loss:0.5043  g_loss:1.5259
# epoch:150  d_loss:0.4686  g_loss:1.8682
# epoch:151  d_loss:0.4936  g_loss:1.6292
# epoch:152  d_loss:0.4197  g_loss:1.8459
# epoch:153  d_loss:0.4677  g_loss:1.7217
# epoch:154  d_loss:0.4266  g_loss:1.7390
# epoch:155  d_loss:0.4558  g_loss:1.8497
# epoch:156  d_loss:0.5164  g_loss:1.7455
# epoch:157  d_loss:0.5091  g_loss:2.0101
# epoch:158  d_loss:0.3658  g_loss:2.3141
# epoch:159  d_loss:0.3602  g_loss:2.4963
# epoch:160  d_loss:0.3742  g_loss:2.5077
# epoch:161  d_loss:0.3256  g_loss:2.8342
# epoch:162  d_loss:0.3022  g_loss:2.4551
# epoch:163  d_loss:0.3730  g_loss:2.1660
# epoch:164  d_loss:0.3263  g_loss:2.2925
# epoch:165  d_loss:0.2961  g_loss:2.3450
# epoch:166  d_loss:0.2716  g_loss:2.5642
# epoch:167  d_loss:0.3618  g_loss:2.7799
# epoch:168  d_loss:0.3622  g_loss:2.7557
# epoch:169  d_loss:0.4462  g_loss:2.4117
# epoch:170  d_loss:0.4425  g_loss:2.2409
# epoch:171  d_loss:0.6592  g_loss:1.4873
# epoch:172  d_loss:0.3611  g_loss:2.1587
# epoch:173  d_loss:0.5840  g_loss:2.0736
# epoch:174  d_loss:0.5443  g_loss:2.4081
# epoch:175  d_loss:0.5775  g_loss:2.1291
# epoch:176  d_loss:0.5787  g_loss:1.5196
# epoch:177  d_loss:0.5758  g_loss:1.4617
# epoch:178  d_loss:0.6190  g_loss:1.5305
# epoch:179  d_loss:0.4734  g_loss:1.7590
# epoch:180  d_loss:0.6260  g_loss:1.9077
# epoch:181  d_loss:0.5086  g_loss:1.6949
# epoch:182  d_loss:0.5725  g_loss:1.6966
# epoch:183  d_loss:0.5968  g_loss:1.4928
# epoch:184  d_loss:0.5162  g_loss:1.4541
# epoch:185  d_loss:0.5212  g_loss:1.5948
# epoch:186  d_loss:0.5491  g_loss:1.3400
# epoch:187  d_loss:0.4838  g_loss:1.2929
# epoch:188  d_loss:0.5658  g_loss:1.4493
# epoch:189  d_loss:0.3814  g_loss:1.7832
# epoch:190  d_loss:0.3845  g_loss:1.6509
# epoch:191  d_loss:0.5694  g_loss:1.9156
# epoch:192  d_loss:0.5202  g_loss:1.5329
# epoch:193  d_loss:0.3668  g_loss:1.5085
# epoch:194  d_loss:0.5102  g_loss:1.3487
# epoch:195  d_loss:0.4096  g_loss:1.5639
# epoch:196  d_loss:0.4580  g_loss:1.7091
# epoch:197  d_loss:0.4201  g_loss:1.8017
# epoch:198  d_loss:0.3331  g_loss:1.8044
# epoch:199  d_loss:0.4552  g_loss:1.5659
# epoch:200  d_loss:0.3568  g_loss:1.3377
# epoch:201  d_loss:0.4283  g_loss:1.8074
# epoch:202  d_loss:0.3762  g_loss:1.6813
# epoch:203  d_loss:0.4774  g_loss:2.0340
# epoch:204  d_loss:0.4511  g_loss:2.0650
# epoch:205  d_loss:0.3907  g_loss:2.0397
# epoch:206  d_loss:0.4249  g_loss:2.0229
# epoch:207  d_loss:0.4844  g_loss:1.5143
# epoch:208  d_loss:0.4347  g_loss:1.3394
# epoch:209  d_loss:0.4244  g_loss:1.5355
# epoch:210  d_loss:0.3825  g_loss:1.5039
# epoch:211  d_loss:0.3453  g_loss:2.0123
# epoch:212  d_loss:0.4312  g_loss:2.0264
# epoch:213  d_loss:0.5618  g_loss:2.0146
# epoch:214  d_loss:0.5002  g_loss:1.5675
# epoch:215  d_loss:0.4397  g_loss:1.9235
# epoch:216  d_loss:0.4996  g_loss:1.6195
# epoch:217  d_loss:0.3887  g_loss:1.7039
# epoch:218  d_loss:0.4505  g_loss:1.9361
# epoch:219  d_loss:0.4740  g_loss:2.3026
# epoch:220  d_loss:0.5180  g_loss:2.0820
# epoch:221  d_loss:0.4917  g_loss:1.8968
# epoch:222  d_loss:0.4865  g_loss:1.9960
# epoch:223  d_loss:0.5761  g_loss:1.7593
# epoch:224  d_loss:0.4422  g_loss:1.9587
# epoch:225  d_loss:0.5635  g_loss:1.8451
# epoch:226  d_loss:0.4363  g_loss:1.9491
# epoch:227  d_loss:0.4462  g_loss:2.3067
# epoch:228  d_loss:0.5876  g_loss:2.0056
# epoch:229  d_loss:0.4005  g_loss:2.3185
# epoch:230  d_loss:0.4850  g_loss:2.3083
# epoch:231  d_loss:0.5422  g_loss:2.1182
# epoch:232  d_loss:0.6895  g_loss:2.0782
# epoch:233  d_loss:0.4875  g_loss:2.0054
# epoch:234  d_loss:0.6848  g_loss:1.9152
# epoch:235  d_loss:0.4759  g_loss:2.2474
# epoch:236  d_loss:0.4294  g_loss:1.9969
# epoch:237  d_loss:0.4407  g_loss:2.3627
# epoch:238  d_loss:0.3904  g_loss:2.2385
# epoch:239  d_loss:0.4045  g_loss:1.9522
# epoch:240  d_loss:0.4062  g_loss:2.0219
# epoch:241  d_loss:0.5087  g_loss:1.7060
# epoch:242  d_loss:0.4687  g_loss:1.7093
# epoch:243  d_loss:0.4122  g_loss:1.8036
# epoch:244  d_loss:0.4752  g_loss:1.6728
# epoch:245  d_loss:0.5700  g_loss:1.9495
# epoch:246  d_loss:0.6106  g_loss:2.1869
# epoch:247  d_loss:0.5457  g_loss:2.2210
# epoch:248  d_loss:0.4132  g_loss:2.4551
# epoch:249  d_loss:0.3637  g_loss:1.8441
# epoch:250  d_loss:0.4941  g_loss:1.9546
# epoch:251  d_loss:0.5311  g_loss:1.8116
# epoch:252  d_loss:0.4889  g_loss:1.7183
# epoch:253  d_loss:0.4492  g_loss:2.2061
# epoch:254  d_loss:0.5848  g_loss:2.0543
# epoch:255  d_loss:0.5665  g_loss:2.1914
# epoch:256  d_loss:0.4854  g_loss:1.7237
# epoch:257  d_loss:0.4554  g_loss:1.9844
# epoch:258  d_loss:0.5402  g_loss:2.0054
# epoch:259  d_loss:0.4932  g_loss:1.8564
# epoch:260  d_loss:0.4186  g_loss:1.9762
# epoch:261  d_loss:0.3432  g_loss:2.3665
# epoch:262  d_loss:0.4828  g_loss:2.4840
# epoch:263  d_loss:0.4694  g_loss:2.5467
# epoch:264  d_loss:0.4634  g_loss:2.0344
# epoch:265  d_loss:0.4815  g_loss:1.4232
# epoch:266  d_loss:0.4936  g_loss:1.6843
# epoch:267  d_loss:0.4383  g_loss:1.5451
# epoch:268  d_loss:0.3874  g_loss:1.8470
# epoch:269  d_loss:0.3180  g_loss:2.1003
# epoch:270  d_loss:0.2417  g_loss:2.6394
# epoch:271  d_loss:0.3086  g_loss:2.4859
# epoch:272  d_loss:0.3028  g_loss:2.5576
# epoch:273  d_loss:0.3845  g_loss:2.0146
# epoch:274  d_loss:0.4278  g_loss:2.4918
# epoch:275  d_loss:0.3232  g_loss:2.3622
# epoch:276  d_loss:0.4218  g_loss:2.2711
# epoch:277  d_loss:0.4855  g_loss:2.8581
# epoch:278  d_loss:0.4876  g_loss:2.4108
# epoch:279  d_loss:0.4787  g_loss:2.7568
# epoch:280  d_loss:0.3708  g_loss:2.6970
# epoch:281  d_loss:0.6845  g_loss:2.0712
# epoch:282  d_loss:0.5967  g_loss:1.7996
# epoch:283  d_loss:0.5454  g_loss:2.3684
# epoch:284  d_loss:0.7551  g_loss:1.7851
# epoch:285  d_loss:0.7765  g_loss:1.8825
# epoch:286  d_loss:0.5209  g_loss:1.9443
# epoch:287  d_loss:0.6947  g_loss:2.1198
# epoch:288  d_loss:0.4247  g_loss:2.4633
# epoch:289  d_loss:0.5855  g_loss:2.1372
# epoch:290  d_loss:0.5232  g_loss:1.7900
# epoch:291  d_loss:0.4636  g_loss:1.9444
# epoch:292  d_loss:0.3448  g_loss:2.1520
# epoch:293  d_loss:0.4066  g_loss:1.8975
# epoch:294  d_loss:0.3586  g_loss:2.2614
# epoch:295  d_loss:0.2984  g_loss:2.4011
# epoch:296  d_loss:0.3595  g_loss:2.1603
# epoch:297  d_loss:0.3207  g_loss:2.3869
# epoch:298  d_loss:0.3337  g_loss:2.5752
# epoch:299  d_loss:0.3818  g_loss:2.2861
# epoch:300  d_loss:0.3051  g_loss:2.1666
# epoch:301  d_loss:0.4205  g_loss:2.2300
# epoch:302  d_loss:0.3216  g_loss:2.3999
# epoch:303  d_loss:0.3615  g_loss:2.6676
# epoch:304  d_loss:0.3966  g_loss:2.8876
# epoch:305  d_loss:0.3337  g_loss:3.2551
# epoch:306  d_loss:0.3758  g_loss:2.7604
# epoch:307  d_loss:0.3352  g_loss:2.4149
# epoch:308  d_loss:0.3365  g_loss:2.0413
# epoch:309  d_loss:0.4493  g_loss:1.9334
# epoch:310  d_loss:0.4376  g_loss:1.9158
# epoch:311  d_loss:0.2910  g_loss:2.0507
# epoch:312  d_loss:0.4270  g_loss:2.3626
# epoch:313  d_loss:0.4075  g_loss:1.9109
# epoch:314  d_loss:0.4823  g_loss:2.2431
# epoch:315  d_loss:0.4647  g_loss:1.9697
# epoch:316  d_loss:0.3961  g_loss:2.0376
# epoch:317  d_loss:0.3605  g_loss:2.1064
# epoch:318  d_loss:0.6684  g_loss:1.8574
# epoch:319  d_loss:0.4121  g_loss:1.9232
# epoch:320  d_loss:0.5964  g_loss:1.9932
# epoch:321  d_loss:0.4651  g_loss:2.1990
# epoch:322  d_loss:0.5213  g_loss:1.5956
# epoch:323  d_loss:0.5065  g_loss:1.7517
# epoch:324  d_loss:0.6266  g_loss:1.7443
# epoch:325  d_loss:0.5281  g_loss:1.3749
# epoch:326  d_loss:0.5853  g_loss:1.7968
# epoch:327  d_loss:0.6488  g_loss:2.3680
# epoch:328  d_loss:0.6481  g_loss:2.1229
# epoch:329  d_loss:0.5029  g_loss:1.9296
# epoch:330  d_loss:0.6561  g_loss:1.7280
# epoch:331  d_loss:0.4067  g_loss:1.9353
# epoch:332  d_loss:0.5450  g_loss:1.8031
# epoch:333  d_loss:0.5117  g_loss:1.4094
# epoch:334  d_loss:0.4429  g_loss:1.4561
# epoch:335  d_loss:0.4092  g_loss:1.5405
# epoch:336  d_loss:0.4659  g_loss:1.8035
# epoch:337  d_loss:0.4049  g_loss:1.9980
# epoch:338  d_loss:0.4240  g_loss:2.0906
# epoch:339  d_loss:0.4178  g_loss:2.3338
# epoch:340  d_loss:0.2887  g_loss:1.9004
# epoch:341  d_loss:0.3693  g_loss:1.6578
# epoch:342  d_loss:0.4421  g_loss:1.4060
# epoch:343  d_loss:0.2369  g_loss:2.1593
# epoch:344  d_loss:0.3019  g_loss:2.1702
# epoch:345  d_loss:0.2226  g_loss:3.2802
# epoch:346  d_loss:0.2906  g_loss:3.1800
# epoch:347  d_loss:0.2385  g_loss:2.3089
# epoch:348  d_loss:0.3371  g_loss:2.1858
# epoch:349  d_loss:0.2540  g_loss:2.3484
# epoch:350  d_loss:0.2954  g_loss:2.6998
# epoch:351  d_loss:0.2074  g_loss:3.2158
# epoch:352  d_loss:0.2854  g_loss:3.1494
# epoch:353  d_loss:0.3788  g_loss:2.3892
# epoch:354  d_loss:0.2732  g_loss:2.0713
# epoch:355  d_loss:0.3679  g_loss:2.2983
# epoch:356  d_loss:0.3106  g_loss:2.2198
# epoch:357  d_loss:0.3746  g_loss:2.0841
# epoch:358  d_loss:0.3591  g_loss:2.3430
# epoch:359  d_loss:0.3243  g_loss:3.5621
# epoch:360  d_loss:0.3977  g_loss:3.3010
# epoch:361  d_loss:0.3790  g_loss:2.8333
# epoch:362  d_loss:0.4112  g_loss:2.3483
# epoch:363  d_loss:0.3548  g_loss:2.2918
# epoch:364  d_loss:0.4312  g_loss:1.7700
# epoch:365  d_loss:0.3819  g_loss:1.8892
# epoch:366  d_loss:0.3620  g_loss:2.4184
# epoch:367  d_loss:0.3696  g_loss:2.1093
# epoch:368  d_loss:0.5672  g_loss:1.5076
# epoch:369  d_loss:0.5264  g_loss:1.4596
# epoch:370  d_loss:0.4212  g_loss:1.8113
# epoch:371  d_loss:0.3482  g_loss:2.3988
# epoch:372  d_loss:0.4273  g_loss:1.9555
# epoch:373  d_loss:0.3760  g_loss:1.8572
# epoch:374  d_loss:0.3043  g_loss:1.6845
# epoch:375  d_loss:0.3626  g_loss:1.8974
# epoch:376  d_loss:0.3796  g_loss:1.8369
# epoch:377  d_loss:0.3264  g_loss:1.9670
# epoch:378  d_loss:0.3000  g_loss:2.4891
# epoch:379  d_loss:0.3253  g_loss:2.2230
# epoch:380  d_loss:0.2565  g_loss:2.2930
# epoch:381  d_loss:0.3982  g_loss:1.7730
# epoch:382  d_loss:0.3179  g_loss:1.6554
# epoch:383  d_loss:0.3214  g_loss:2.1956
# epoch:384  d_loss:0.3150  g_loss:2.5694
# epoch:385  d_loss:0.3194  g_loss:3.0745
# epoch:386  d_loss:0.2176  g_loss:2.8613
# epoch:387  d_loss:0.4378  g_loss:2.5435
# epoch:388  d_loss:0.4088  g_loss:1.7462
# epoch:389  d_loss:0.5196  g_loss:1.4755
# epoch:390  d_loss:0.4798  g_loss:1.7303
# epoch:391  d_loss:0.3514  g_loss:2.4106
# epoch:392  d_loss:0.3586  g_loss:2.4198
# epoch:393  d_loss:0.3908  g_loss:2.9104
# epoch:394  d_loss:0.4781  g_loss:2.1406
# epoch:395  d_loss:0.3821  g_loss:2.1550
# epoch:396  d_loss:0.3773  g_loss:2.2905
# epoch:397  d_loss:0.3620  g_loss:2.1706
# epoch:398  d_loss:0.3614  g_loss:2.1617
# epoch:399  d_loss:0.3559  g_loss:2.3684
# epoch:400  d_loss:0.2594  g_loss:2.2761
# epoch:401  d_loss:0.3155  g_loss:2.2674
# epoch:402  d_loss:0.3358  g_loss:2.0414
# epoch:403  d_loss:0.2315  g_loss:2.6607
# epoch:404  d_loss:0.2834  g_loss:2.4797
# epoch:405  d_loss:0.2804  g_loss:2.9337
# epoch:406  d_loss:0.2452  g_loss:3.2727
# epoch:407  d_loss:0.1735  g_loss:3.1541
# epoch:408  d_loss:0.2980  g_loss:2.6286
# epoch:409  d_loss:0.2198  g_loss:2.8007
# epoch:410  d_loss:0.2388  g_loss:2.7560
# epoch:411  d_loss:0.2850  g_loss:3.1148
# epoch:412  d_loss:0.2514  g_loss:2.8194
# epoch:413  d_loss:0.2646  g_loss:2.4638
# epoch:414  d_loss:0.3110  g_loss:2.6862
# epoch:415  d_loss:0.3416  g_loss:2.9359
# epoch:416  d_loss:0.4563  g_loss:2.6682
# epoch:417  d_loss:0.3145  g_loss:2.0390
# epoch:418  d_loss:0.2674  g_loss:2.1698
# epoch:419  d_loss:0.3526  g_loss:2.2658
# epoch:420  d_loss:0.3329  g_loss:2.4735
# epoch:421  d_loss:0.3060  g_loss:2.5122
# epoch:422  d_loss:0.3997  g_loss:2.1452
# epoch:423  d_loss:0.5099  g_loss:1.7068
# epoch:424  d_loss:0.5247  g_loss:1.7324
# epoch:425  d_loss:0.3291  g_loss:2.3722
# epoch:426  d_loss:0.2670  g_loss:2.9007
# epoch:427  d_loss:0.3978  g_loss:3.3652
# epoch:428  d_loss:0.3278  g_loss:3.0184
# epoch:429  d_loss:0.3204  g_loss:2.3349
# epoch:430  d_loss:0.4005  g_loss:2.2150
# epoch:431  d_loss:0.3612  g_loss:2.6220
# epoch:432  d_loss:0.1936  g_loss:3.5013
# epoch:433  d_loss:0.2380  g_loss:4.0639
# epoch:434  d_loss:0.2206  g_loss:3.7216
# epoch:435  d_loss:0.1502  g_loss:2.4694
# epoch:436  d_loss:0.2401  g_loss:2.1482
# epoch:437  d_loss:0.2299  g_loss:2.0645
# epoch:438  d_loss:0.2625  g_loss:2.7374
# epoch:439  d_loss:0.1932  g_loss:3.5234
# epoch:440  d_loss:0.2046  g_loss:3.5078
# epoch:441  d_loss:0.2831  g_loss:2.9344
# epoch:442  d_loss:0.2571  g_loss:2.6929
# epoch:443  d_loss:0.2541  g_loss:1.9159
# epoch:444  d_loss:0.2280  g_loss:2.1698
# epoch:445  d_loss:0.2308  g_loss:2.3637
# epoch:446  d_loss:0.1425  g_loss:2.9119
# epoch:447  d_loss:0.1751  g_loss:3.1335
# epoch:448  d_loss:0.1860  g_loss:2.9427
# epoch:449  d_loss:0.2635  g_loss:2.8177
# epoch:450  d_loss:0.2777  g_loss:2.2745
# epoch:451  d_loss:0.1615  g_loss:2.6488
# epoch:452  d_loss:0.1928  g_loss:2.2576
# epoch:453  d_loss:0.1902  g_loss:2.6952
# epoch:454  d_loss:0.1613  g_loss:3.3848
# epoch:455  d_loss:0.1945  g_loss:3.5522
# epoch:456  d_loss:0.3242  g_loss:3.5069
# epoch:457  d_loss:0.2224  g_loss:3.1977
# epoch:458  d_loss:0.1656  g_loss:3.3250
# epoch:459  d_loss:0.1475  g_loss:3.2313
# epoch:460  d_loss:0.1710  g_loss:3.3892
# epoch:461  d_loss:0.2139  g_loss:2.9368
# epoch:462  d_loss:0.3015  g_loss:2.7951
# epoch:463  d_loss:0.2343  g_loss:3.1303
# epoch:464  d_loss:0.1474  g_loss:3.7906
# epoch:465  d_loss:0.3021  g_loss:3.0602
# epoch:466  d_loss:0.1890  g_loss:2.6268
# epoch:467  d_loss:0.2009  g_loss:2.8752
# epoch:468  d_loss:0.1333  g_loss:3.6764
# epoch:469  d_loss:0.2549  g_loss:3.5620
# epoch:470  d_loss:0.2187  g_loss:3.6502
# epoch:471  d_loss:0.3073  g_loss:3.2085
# epoch:472  d_loss:0.2120  g_loss:4.0531
# epoch:473  d_loss:0.3875  g_loss:2.7384
# epoch:474  d_loss:0.2394  g_loss:3.2038
# epoch:475  d_loss:0.1613  g_loss:3.1121
# epoch:476  d_loss:0.1488  g_loss:3.3568
# epoch:477  d_loss:0.1752  g_loss:3.3315
# epoch:478  d_loss:0.1388  g_loss:3.1076
# epoch:479  d_loss:0.1963  g_loss:2.8623
# epoch:480  d_loss:0.2231  g_loss:2.9025
# epoch:481  d_loss:0.2524  g_loss:2.7052
# epoch:482  d_loss:0.2172  g_loss:3.1170
# epoch:483  d_loss:0.1383  g_loss:3.2252
# epoch:484  d_loss:0.0890  g_loss:3.7458
# epoch:485  d_loss:0.3093  g_loss:2.4379
# epoch:486  d_loss:0.3494  g_loss:1.6727
# epoch:487  d_loss:0.2940  g_loss:2.1285
# epoch:488  d_loss:0.2691  g_loss:3.3594
# epoch:489  d_loss:0.2446  g_loss:3.9814
# epoch:490  d_loss:0.3855  g_loss:3.1555
# epoch:491  d_loss:0.3195  g_loss:2.1509
# epoch:492  d_loss:0.2762  g_loss:1.8525
# epoch:493  d_loss:0.3774  g_loss:2.2950
# epoch:494  d_loss:0.1357  g_loss:3.6517
# epoch:495  d_loss:0.2431  g_loss:3.9424
# epoch:496  d_loss:0.2761  g_loss:3.4561
# epoch:497  d_loss:0.2404  g_loss:2.5790
# epoch:498  d_loss:0.2431  g_loss:1.8799
# epoch:499  d_loss:0.3757  g_loss:1.9982
# epoch:500  d_loss:0.2045  g_loss:3.1500
# epoch:501  d_loss:0.2089  g_loss:3.7912
# epoch:502  d_loss:0.1630  g_loss:3.9007
# epoch:503  d_loss:0.1678  g_loss:3.3205
# epoch:504  d_loss:0.2017  g_loss:2.8327
# epoch:505  d_loss:0.1457  g_loss:3.1110
# epoch:506  d_loss:0.3048  g_loss:2.5128
# epoch:507  d_loss:0.1657  g_loss:3.2157
# epoch:508  d_loss:0.0682  g_loss:3.4373
# epoch:509  d_loss:0.1143  g_loss:3.7178
# epoch:510  d_loss:0.1505  g_loss:3.1866
# epoch:511  d_loss:0.1746  g_loss:3.1853
# epoch:512  d_loss:0.2172  g_loss:2.8178
# epoch:513  d_loss:0.1186  g_loss:3.0249
# epoch:514  d_loss:0.1238  g_loss:2.8244
# epoch:515  d_loss:0.0749  g_loss:3.5017
# epoch:516  d_loss:0.1209  g_loss:3.1826
# epoch:517  d_loss:0.1665  g_loss:4.0173
# epoch:518  d_loss:0.1670  g_loss:3.3642
# epoch:519  d_loss:0.2026  g_loss:2.9797
# epoch:520  d_loss:0.1385  g_loss:3.0984
# epoch:521  d_loss:0.1886  g_loss:3.6391
# epoch:522  d_loss:0.1572  g_loss:3.1570
# epoch:523  d_loss:0.1445  g_loss:3.6085
# epoch:524  d_loss:0.2634  g_loss:3.9002
# epoch:525  d_loss:0.1340  g_loss:3.2104
# epoch:526  d_loss:0.0969  g_loss:3.0454
# epoch:527  d_loss:0.1173  g_loss:3.3506
# epoch:528  d_loss:0.3425  g_loss:2.4231
# epoch:529  d_loss:0.1504  g_loss:2.8793
# epoch:530  d_loss:0.1166  g_loss:3.8814
# epoch:531  d_loss:0.2062  g_loss:4.2620
# epoch:532  d_loss:0.2157  g_loss:3.1164
# epoch:533  d_loss:0.2163  g_loss:3.3339
# epoch:534  d_loss:0.1081  g_loss:3.5136
# epoch:535  d_loss:0.2453  g_loss:2.6192
# epoch:536  d_loss:0.2999  g_loss:2.5923
# epoch:537  d_loss:0.2110  g_loss:3.1111
# epoch:538  d_loss:0.2898  g_loss:3.4348
# epoch:539  d_loss:0.4063  g_loss:2.3780
# epoch:540  d_loss:0.2494  g_loss:2.1533
# epoch:541  d_loss:0.2567  g_loss:2.7908
# epoch:542  d_loss:0.2489  g_loss:2.6168
# epoch:543  d_loss:0.3102  g_loss:2.7104
# epoch:544  d_loss:0.2114  g_loss:2.7218
# epoch:545  d_loss:0.2250  g_loss:2.3671
# epoch:546  d_loss:0.2035  g_loss:2.5093
# epoch:547  d_loss:0.2165  g_loss:2.6773
# epoch:548  d_loss:0.1577  g_loss:2.9461
# epoch:549  d_loss:0.1983  g_loss:3.3655
# epoch:550  d_loss:0.1881  g_loss:2.7166
# epoch:551  d_loss:0.1715  g_loss:2.6662
# epoch:552  d_loss:0.2527  g_loss:2.3355
# epoch:553  d_loss:0.2174  g_loss:2.0615
# epoch:554  d_loss:0.1459  g_loss:3.0466
# epoch:555  d_loss:0.1211  g_loss:2.6846
# epoch:556  d_loss:0.1255  g_loss:2.9133
# epoch:557  d_loss:0.1255  g_loss:2.9807
# epoch:558  d_loss:0.1295  g_loss:3.4824
# epoch:559  d_loss:0.1655  g_loss:2.5847
# epoch:560  d_loss:0.1786  g_loss:2.2495
# epoch:561  d_loss:0.1900  g_loss:2.8795
# epoch:562  d_loss:0.0994  g_loss:3.0328
# epoch:563  d_loss:0.1422  g_loss:2.7727
# epoch:564  d_loss:0.2273  g_loss:2.6722
# epoch:565  d_loss:0.1817  g_loss:2.4530
# epoch:566  d_loss:0.3052  g_loss:1.9505
# epoch:567  d_loss:0.2721  g_loss:2.4632
# epoch:568  d_loss:0.1758  g_loss:2.3879
# epoch:569  d_loss:0.1865  g_loss:2.8272
# epoch:570  d_loss:0.2568  g_loss:2.3856
# epoch:571  d_loss:0.1526  g_loss:2.0548
# epoch:572  d_loss:0.1963  g_loss:2.5714
# epoch:573  d_loss:0.3202  g_loss:2.9101
# epoch:574  d_loss:0.1733  g_loss:2.5517
# epoch:575  d_loss:0.2794  g_loss:2.4428
# epoch:576  d_loss:0.3047  g_loss:2.2663
# epoch:577  d_loss:0.2049  g_loss:2.7931
# epoch:578  d_loss:0.3396  g_loss:2.7471
# epoch:579  d_loss:0.2348  g_loss:3.5256
# epoch:580  d_loss:0.3466  g_loss:3.1014
# epoch:581  d_loss:0.3459  g_loss:3.2283
# epoch:582  d_loss:0.2545  g_loss:3.7202
# epoch:583  d_loss:0.3067  g_loss:2.9886
# epoch:584  d_loss:0.4041  g_loss:1.8892
# epoch:585  d_loss:0.4127  g_loss:1.0180
# epoch:586  d_loss:0.3277  g_loss:2.0999
# epoch:587  d_loss:0.2621  g_loss:2.7240
# epoch:588  d_loss:0.4310  g_loss:2.4491
# epoch:589  d_loss:0.6137  g_loss:1.4452
# epoch:590  d_loss:0.3643  g_loss:1.4858
# epoch:591  d_loss:0.5328  g_loss:1.2404
# epoch:592  d_loss:0.3101  g_loss:2.1191
# epoch:593  d_loss:0.3101  g_loss:2.4952
# epoch:594  d_loss:0.3175  g_loss:2.1451
# epoch:595  d_loss:0.5497  g_loss:1.9018
# epoch:596  d_loss:0.7488  g_loss:1.2596
# epoch:597  d_loss:0.2416  g_loss:2.0697
# epoch:598  d_loss:0.2146  g_loss:2.6122
# epoch:599  d_loss:0.3709  g_loss:2.5799
# epoch:600  d_loss:0.5326  g_loss:1.6942
# epoch:601  d_loss:0.3787  g_loss:1.5936
# epoch:602  d_loss:0.5771  g_loss:1.5647
# epoch:603  d_loss:0.4395  g_loss:1.8949
# epoch:604  d_loss:0.5430  g_loss:1.7416
# epoch:605  d_loss:0.6365  g_loss:1.6129
# epoch:606  d_loss:0.5608  g_loss:1.2358
# epoch:607  d_loss:0.6202  g_loss:0.9410
# epoch:608  d_loss:0.4572  g_loss:1.9882
# epoch:609  d_loss:0.5532  g_loss:3.0177
# epoch:610  d_loss:0.5031  g_loss:3.3108
# epoch:611  d_loss:0.5778  g_loss:2.1258
# epoch:612  d_loss:0.5169  g_loss:3.0042
# epoch:613  d_loss:0.4006  g_loss:2.4591
# epoch:614  d_loss:0.6697  g_loss:1.9683
# epoch:615  d_loss:0.4908  g_loss:1.9747
# epoch:616  d_loss:0.4199  g_loss:1.9894
# epoch:617  d_loss:0.6685  g_loss:2.1737
# epoch:618  d_loss:0.6322  g_loss:2.0678
# epoch:619  d_loss:0.6258  g_loss:1.7227
# epoch:620  d_loss:0.9591  g_loss:1.9792
# epoch:621  d_loss:0.8006  g_loss:1.7014
# epoch:622  d_loss:0.9348  g_loss:1.4785
# epoch:623  d_loss:0.6958  g_loss:1.3426
# epoch:624  d_loss:0.6054  g_loss:1.9227
# epoch:625  d_loss:0.4180  g_loss:1.7200
# epoch:626  d_loss:0.3474  g_loss:1.8675
# epoch:627  d_loss:0.2157  g_loss:1.5948
# epoch:628  d_loss:0.3301  g_loss:1.4320
# epoch:629  d_loss:0.3271  g_loss:1.9305
# epoch:630  d_loss:0.5275  g_loss:1.9572
# epoch:631  d_loss:0.3139  g_loss:1.8174
# epoch:632  d_loss:0.4790  g_loss:2.1662
# epoch:633  d_loss:0.7055  g_loss:2.4750
# epoch:634  d_loss:0.5068  g_loss:2.2676
# epoch:635  d_loss:0.5727  g_loss:2.0512
# epoch:636  d_loss:0.3607  g_loss:2.1526
# epoch:637  d_loss:0.6355  g_loss:2.7995
# epoch:638  d_loss:0.7887  g_loss:3.3008
# epoch:639  d_loss:1.1236  g_loss:3.0033
# epoch:640  d_loss:1.0598  g_loss:2.1900
# epoch:641  d_loss:1.3148  g_loss:1.4934
# epoch:642  d_loss:0.3249  g_loss:2.1246
# epoch:643  d_loss:0.1788  g_loss:3.7398
# epoch:644  d_loss:0.4021  g_loss:3.9157
# epoch:645  d_loss:0.4427  g_loss:2.8072
# epoch:646  d_loss:0.4617  g_loss:2.4522
# epoch:647  d_loss:1.2000  g_loss:1.7418
# epoch:648  d_loss:1.1991  g_loss:0.8033
# epoch:649  d_loss:1.2809  g_loss:1.1656
# epoch:650  d_loss:0.8235  g_loss:1.6763
# epoch:651  d_loss:1.1853  g_loss:2.3769
# epoch:652  d_loss:0.7256  g_loss:2.7346
# epoch:653  d_loss:0.6541  g_loss:2.3887
# epoch:654  d_loss:0.3962  g_loss:2.0971
# epoch:655  d_loss:0.1674  g_loss:2.3465
# epoch:656  d_loss:0.4037  g_loss:2.5961
# epoch:657  d_loss:0.4514  g_loss:2.8728
# epoch:658  d_loss:0.3360  g_loss:3.0336
# epoch:659  d_loss:0.3326  g_loss:2.6968
# epoch:660  d_loss:0.7401  g_loss:2.7343
# epoch:661  d_loss:0.4893  g_loss:2.7683
# epoch:662  d_loss:0.6774  g_loss:2.7117
# epoch:663  d_loss:0.8476  g_loss:3.2157
# epoch:664  d_loss:0.3870  g_loss:3.7409
# epoch:665  d_loss:0.4071  g_loss:4.5860
# epoch:666  d_loss:0.2941  g_loss:4.4775
# epoch:667  d_loss:0.4292  g_loss:5.3034
# epoch:668  d_loss:0.2370  g_loss:4.5809
# epoch:669  d_loss:0.3716  g_loss:4.4733
# epoch:670  d_loss:0.2801  g_loss:3.9805
# epoch:671  d_loss:0.3509  g_loss:2.9508
# epoch:672  d_loss:0.4129  g_loss:2.5588
# epoch:673  d_loss:0.2881  g_loss:3.1366
# epoch:674  d_loss:0.4106  g_loss:2.8100
# epoch:675  d_loss:0.5472  g_loss:3.1699
# epoch:676  d_loss:0.6473  g_loss:2.6397
# epoch:677  d_loss:0.5155  g_loss:1.7477
# epoch:678  d_loss:0.3667  g_loss:1.8554
# epoch:679  d_loss:0.6743  g_loss:1.4829
# epoch:680  d_loss:0.4720  g_loss:1.2164
# epoch:681  d_loss:0.4407  g_loss:1.7707
# epoch:682  d_loss:0.5243  g_loss:1.6926
# epoch:683  d_loss:0.3991  g_loss:1.8116
# epoch:684  d_loss:0.2643  g_loss:2.0348
# epoch:685  d_loss:0.3565  g_loss:1.7857
# epoch:686  d_loss:0.4250  g_loss:1.8452
# epoch:687  d_loss:0.1997  g_loss:2.2997
# epoch:688  d_loss:0.2418  g_loss:2.8926
# epoch:689  d_loss:0.1312  g_loss:3.2638
# epoch:690  d_loss:0.0933  g_loss:4.2057
# epoch:691  d_loss:0.1683  g_loss:4.2287
# epoch:692  d_loss:0.1994  g_loss:5.0380
# epoch:693  d_loss:0.1692  g_loss:4.0196
# epoch:694  d_loss:0.3494  g_loss:3.9972
# epoch:695  d_loss:0.1964  g_loss:3.3168
# epoch:696  d_loss:0.5110  g_loss:2.4136
# epoch:697  d_loss:0.6330  g_loss:2.6959
# epoch:698  d_loss:0.3532  g_loss:3.0643
# epoch:699  d_loss:0.6703  g_loss:2.6761
# epoch:700  d_loss:0.8089  g_loss:3.1738
# epoch:701  d_loss:0.9075  g_loss:2.7777
# epoch:702  d_loss:0.5057  g_loss:2.6378
# epoch:703  d_loss:0.5008  g_loss:2.6110
# epoch:704  d_loss:0.4127  g_loss:2.3879
# epoch:705  d_loss:0.4577  g_loss:2.8583
# epoch:706  d_loss:0.2709  g_loss:2.7956
# epoch:707  d_loss:0.4414  g_loss:3.2946
# epoch:708  d_loss:0.3318  g_loss:3.4472
# epoch:709  d_loss:0.2986  g_loss:3.2382
# epoch:710  d_loss:0.3957  g_loss:2.2141
# epoch:711  d_loss:0.2478  g_loss:2.2526
# epoch:712  d_loss:0.2779  g_loss:2.4186
# epoch:713  d_loss:0.2453  g_loss:2.0131
# epoch:714  d_loss:0.1912  g_loss:2.6944
# epoch:715  d_loss:0.2617  g_loss:2.1585
# epoch:716  d_loss:0.2929  g_loss:2.5397
# epoch:717  d_loss:0.4987  g_loss:2.4079
# epoch:718  d_loss:0.3586  g_loss:1.6717
# epoch:719  d_loss:0.4056  g_loss:1.6332
# epoch:720  d_loss:0.3140  g_loss:1.8632
# epoch:721  d_loss:0.5127  g_loss:1.7167
# epoch:722  d_loss:0.6470  g_loss:1.6787
# epoch:723  d_loss:0.2824  g_loss:1.5448
# epoch:724  d_loss:0.5407  g_loss:1.6523
# epoch:725  d_loss:0.3344  g_loss:1.8796
# epoch:726  d_loss:0.2747  g_loss:2.3578
# epoch:727  d_loss:0.3972  g_loss:2.3471
# epoch:728  d_loss:0.2346  g_loss:2.3030
# epoch:729  d_loss:0.2519  g_loss:2.2299
# epoch:730  d_loss:0.1979  g_loss:2.5935
# epoch:731  d_loss:0.1316  g_loss:2.8725
# epoch:732  d_loss:0.1940  g_loss:3.2578
# epoch:733  d_loss:0.1536  g_loss:3.3236
# epoch:734  d_loss:0.0855  g_loss:3.8650
# epoch:735  d_loss:0.1241  g_loss:3.8898
# epoch:736  d_loss:0.1319  g_loss:3.9180
# epoch:737  d_loss:0.1308  g_loss:3.7959
# epoch:738  d_loss:0.1586  g_loss:3.5535
# epoch:739  d_loss:0.1576  g_loss:3.4865
# epoch:740  d_loss:0.3472  g_loss:2.8220
# epoch:741  d_loss:0.4418  g_loss:2.7188
# epoch:742  d_loss:0.4165  g_loss:2.5244
# epoch:743  d_loss:0.3948  g_loss:2.5866
# epoch:744  d_loss:0.3655  g_loss:3.0096
# epoch:745  d_loss:0.3233  g_loss:2.6615
# epoch:746  d_loss:0.3893  g_loss:2.7963
# epoch:747  d_loss:0.4546  g_loss:2.9478
# epoch:748  d_loss:0.2984  g_loss:2.8986
# epoch:749  d_loss:0.4955  g_loss:2.1674
# epoch:750  d_loss:0.4687  g_loss:1.8553
# epoch:751  d_loss:0.5592  g_loss:1.6817
# epoch:752  d_loss:0.5100  g_loss:1.6596
# epoch:753  d_loss:0.3768  g_loss:1.6771
# epoch:754  d_loss:0.2607  g_loss:2.0818
# epoch:755  d_loss:0.4953  g_loss:1.8587
# epoch:756  d_loss:0.4419  g_loss:1.8433
# epoch:757  d_loss:0.4557  g_loss:1.8754
# epoch:758  d_loss:0.3487  g_loss:1.8843
# epoch:759  d_loss:0.3675  g_loss:1.6570
# epoch:760  d_loss:0.5337  g_loss:1.7609
# epoch:761  d_loss:0.5314  g_loss:1.7324
# epoch:762  d_loss:0.5013  g_loss:1.5732
# epoch:763  d_loss:0.5453  g_loss:1.5369
# epoch:764  d_loss:0.5142  g_loss:1.5503
# epoch:765  d_loss:0.7624  g_loss:1.5770
# epoch:766  d_loss:0.5167  g_loss:1.3721
# epoch:767  d_loss:0.4091  g_loss:1.4651
# epoch:768  d_loss:0.4855  g_loss:1.6201
# epoch:769  d_loss:0.3985  g_loss:1.8880
# epoch:770  d_loss:0.4671  g_loss:1.6208
# epoch:771  d_loss:0.4677  g_loss:1.5916
# epoch:772  d_loss:0.3799  g_loss:1.2624
# epoch:773  d_loss:0.3229  g_loss:1.9316
# epoch:774  d_loss:0.3054  g_loss:1.9482
# epoch:775  d_loss:0.3886  g_loss:1.9996
# epoch:776  d_loss:0.3564  g_loss:1.9662
# epoch:777  d_loss:0.2611  g_loss:2.2370
# epoch:778  d_loss:0.3240  g_loss:2.2470
# epoch:779  d_loss:0.3142  g_loss:1.9757
# epoch:780  d_loss:0.3057  g_loss:1.7388
# epoch:781  d_loss:0.2398  g_loss:1.8046
# epoch:782  d_loss:0.2711  g_loss:2.2057
# epoch:783  d_loss:0.2394  g_loss:1.9548
# epoch:784  d_loss:0.3275  g_loss:2.0359
# epoch:785  d_loss:0.2965  g_loss:2.1118
# epoch:786  d_loss:0.4694  g_loss:2.2221
# epoch:787  d_loss:0.3390  g_loss:2.1468
# epoch:788  d_loss:0.3674  g_loss:2.1059
# epoch:789  d_loss:0.3533  g_loss:2.2475
# epoch:790  d_loss:0.4882  g_loss:1.8468
# epoch:791  d_loss:0.3629  g_loss:1.9037
# epoch:792  d_loss:0.5705  g_loss:1.9628
# epoch:793  d_loss:0.5028  g_loss:1.9262
# epoch:794  d_loss:0.5080  g_loss:1.7635
# epoch:795  d_loss:0.5442  g_loss:1.6217
# epoch:796  d_loss:0.5139  g_loss:1.5754
# epoch:797  d_loss:0.4627  g_loss:1.7778
# epoch:798  d_loss:0.6217  g_loss:1.5492
# epoch:799  d_loss:0.6630  g_loss:1.4940
# epoch:800  d_loss:0.5118  g_loss:1.7024
# epoch:801  d_loss:0.5404  g_loss:1.4252
# epoch:802  d_loss:0.5519  g_loss:1.1198
# epoch:803  d_loss:0.6218  g_loss:0.7792
# epoch:804  d_loss:0.5180  g_loss:1.0646
# epoch:805  d_loss:0.5771  g_loss:1.0570
# epoch:806  d_loss:0.7852  g_loss:1.2505
# epoch:807  d_loss:0.6813  g_loss:1.4587
# epoch:808  d_loss:0.6094  g_loss:1.4200
# epoch:809  d_loss:0.5980  g_loss:1.5295
# epoch:810  d_loss:0.5105  g_loss:1.4764
# epoch:811  d_loss:0.4933  g_loss:1.4176
# epoch:812  d_loss:0.5021  g_loss:1.3364
# epoch:813  d_loss:0.5530  g_loss:1.4085
# epoch:814  d_loss:0.4095  g_loss:1.3707
# epoch:815  d_loss:0.3427  g_loss:1.6235
# epoch:816  d_loss:0.4258  g_loss:1.6471
# epoch:817  d_loss:0.3983  g_loss:1.4333
# epoch:818  d_loss:0.3047  g_loss:1.8484
# epoch:819  d_loss:0.4109  g_loss:1.9732
# epoch:820  d_loss:0.3592  g_loss:1.8932
# epoch:821  d_loss:0.2916  g_loss:2.0126
# epoch:822  d_loss:0.3041  g_loss:1.8530
# epoch:823  d_loss:0.3080  g_loss:1.8827
# epoch:824  d_loss:0.3760  g_loss:1.7360
# epoch:825  d_loss:0.3362  g_loss:2.0420
# epoch:826  d_loss:0.3327  g_loss:1.9398
# epoch:827  d_loss:0.2376  g_loss:2.6033
# epoch:828  d_loss:0.1681  g_loss:2.6790
# epoch:829  d_loss:0.3043  g_loss:2.6967
# epoch:830  d_loss:0.4039  g_loss:2.9983
# epoch:831  d_loss:0.3494  g_loss:2.6815
# epoch:832  d_loss:0.2837  g_loss:2.3083
# epoch:833  d_loss:0.3162  g_loss:1.7760
# epoch:834  d_loss:0.3676  g_loss:1.6965
# epoch:835  d_loss:0.3982  g_loss:1.8395
# epoch:836  d_loss:0.4405  g_loss:1.9296
# epoch:837  d_loss:0.4390  g_loss:1.9483
# epoch:838  d_loss:0.3917  g_loss:2.2701
# epoch:839  d_loss:0.5306  g_loss:1.6952
# epoch:840  d_loss:0.4050  g_loss:1.8886
# epoch:841  d_loss:0.7374  g_loss:1.4549
# epoch:842  d_loss:0.5262  g_loss:1.3044
# epoch:843  d_loss:0.4885  g_loss:1.3081
# epoch:844  d_loss:0.4674  g_loss:1.6138
# epoch:845  d_loss:0.4150  g_loss:1.9506
# epoch:846  d_loss:0.3906  g_loss:2.1675
# epoch:847  d_loss:0.7040  g_loss:1.9115
# epoch:848  d_loss:0.6116  g_loss:1.4782
# epoch:849  d_loss:0.3861  g_loss:1.5196
# epoch:850  d_loss:0.3648  g_loss:1.6926
# epoch:851  d_loss:0.3530  g_loss:1.6511
# epoch:852  d_loss:0.3815  g_loss:1.8801
# epoch:853  d_loss:0.4157  g_loss:2.2425
# epoch:854  d_loss:0.4295  g_loss:2.1858
# epoch:855  d_loss:0.2894  g_loss:2.5674
# epoch:856  d_loss:0.2190  g_loss:2.5468
# epoch:857  d_loss:0.3258  g_loss:2.1532
# epoch:858  d_loss:0.3667  g_loss:1.9279
# epoch:859  d_loss:0.2905  g_loss:1.8294
# epoch:860  d_loss:0.2654  g_loss:2.0300
# epoch:861  d_loss:0.3253  g_loss:2.2904
# epoch:862  d_loss:0.3039  g_loss:2.9802
# epoch:863  d_loss:0.2153  g_loss:3.1115
# epoch:864  d_loss:0.3581  g_loss:2.6208
# epoch:865  d_loss:0.2821  g_loss:2.4993
# epoch:866  d_loss:0.2578  g_loss:2.2024
# epoch:867  d_loss:0.2815  g_loss:2.5590
# epoch:868  d_loss:0.3655  g_loss:2.4068
# epoch:869  d_loss:0.3297  g_loss:2.5335
# epoch:870  d_loss:0.5148  g_loss:2.5810
# epoch:871  d_loss:0.4908  g_loss:1.7779
# epoch:872  d_loss:0.5481  g_loss:1.9093
# epoch:873  d_loss:0.3470  g_loss:1.8743
# epoch:874  d_loss:0.3688  g_loss:1.9972
# epoch:875  d_loss:0.3420  g_loss:2.4048
# epoch:876  d_loss:0.4364  g_loss:1.7800
# epoch:877  d_loss:0.5024  g_loss:1.9705
# epoch:878  d_loss:0.3013  g_loss:2.1868
# epoch:879  d_loss:0.3796  g_loss:1.9984
# epoch:880  d_loss:0.4439  g_loss:2.2666
# epoch:881  d_loss:0.2367  g_loss:2.7390
# epoch:882  d_loss:0.2863  g_loss:2.9476
# epoch:883  d_loss:0.3889  g_loss:2.4150
# epoch:884  d_loss:0.2996  g_loss:3.1349
# epoch:885  d_loss:0.4221  g_loss:2.6036
# epoch:886  d_loss:0.3647  g_loss:2.8583
# epoch:887  d_loss:0.4006  g_loss:2.8256
# epoch:888  d_loss:0.5068  g_loss:2.3890
# epoch:889  d_loss:0.3710  g_loss:2.2427
# epoch:890  d_loss:0.3554  g_loss:1.8470
# epoch:891  d_loss:0.4799  g_loss:1.7721
# epoch:892  d_loss:0.4377  g_loss:2.4238
# epoch:893  d_loss:0.3698  g_loss:2.6926
# epoch:894  d_loss:0.4081  g_loss:2.3608
# epoch:895  d_loss:0.6381  g_loss:1.6209
# epoch:896  d_loss:0.6303  g_loss:1.7226
# epoch:897  d_loss:0.3316  g_loss:2.0270
# epoch:898  d_loss:0.4313  g_loss:2.1826
# epoch:899  d_loss:0.4472  g_loss:2.2486
# epoch:900  d_loss:0.5407  g_loss:2.0423
# epoch:901  d_loss:0.4265  g_loss:1.9382
# epoch:902  d_loss:0.4091  g_loss:2.1609
# epoch:903  d_loss:0.6935  g_loss:1.7177
# epoch:904  d_loss:0.3662  g_loss:2.0457
# epoch:905  d_loss:0.4730  g_loss:1.9447
# epoch:906  d_loss:0.3907  g_loss:2.3725
# epoch:907  d_loss:0.5554  g_loss:1.6880
# epoch:908  d_loss:0.3936  g_loss:1.4113
# epoch:909  d_loss:0.3851  g_loss:1.8702
# epoch:910  d_loss:0.3943  g_loss:1.9779
# epoch:911  d_loss:0.3307  g_loss:2.2545
# epoch:912  d_loss:0.3721  g_loss:1.9042
# epoch:913  d_loss:0.3938  g_loss:2.1391
# epoch:914  d_loss:0.3986  g_loss:1.9269
# epoch:915  d_loss:0.2384  g_loss:2.0019
# epoch:916  d_loss:0.3308  g_loss:2.1773
# epoch:917  d_loss:0.3167  g_loss:2.0644
# epoch:918  d_loss:0.2751  g_loss:2.5388
# epoch:919  d_loss:0.2404  g_loss:2.2612
# epoch:920  d_loss:0.3055  g_loss:2.6894
# epoch:921  d_loss:0.3468  g_loss:2.5095
# epoch:922  d_loss:0.2492  g_loss:2.6005
# epoch:923  d_loss:0.3843  g_loss:2.1165
# epoch:924  d_loss:0.3324  g_loss:1.8875
# epoch:925  d_loss:0.4097  g_loss:2.0730
# epoch:926  d_loss:0.2810  g_loss:2.4040
# epoch:927  d_loss:0.3459  g_loss:2.1058
# epoch:928  d_loss:0.3606  g_loss:2.6224
# epoch:929  d_loss:0.2789  g_loss:2.3479
# epoch:930  d_loss:0.4197  g_loss:2.0922
# epoch:931  d_loss:0.3286  g_loss:2.3275
# epoch:932  d_loss:0.2527  g_loss:2.6279
# epoch:933  d_loss:0.3610  g_loss:2.0563
# epoch:934  d_loss:0.4968  g_loss:1.9443
# epoch:935  d_loss:0.3610  g_loss:2.1275
# epoch:936  d_loss:0.5081  g_loss:2.1503
# epoch:937  d_loss:0.6042  g_loss:1.8219
# epoch:938  d_loss:0.5427  g_loss:1.8116
# epoch:939  d_loss:0.4341  g_loss:1.7302
# epoch:940  d_loss:0.4039  g_loss:1.9100
# epoch:941  d_loss:0.4226  g_loss:1.7694
# epoch:942  d_loss:0.3425  g_loss:2.5456
# epoch:943  d_loss:0.3574  g_loss:2.2386
# epoch:944  d_loss:0.3999  g_loss:2.2537
# epoch:945  d_loss:0.3963  g_loss:2.4146
# epoch:946  d_loss:0.5199  g_loss:1.6804
# epoch:947  d_loss:0.5025  g_loss:2.0472
# epoch:948  d_loss:0.2533  g_loss:2.6474
# epoch:949  d_loss:0.4401  g_loss:2.5929
# epoch:950  d_loss:0.3534  g_loss:1.8842
# epoch:951  d_loss:0.2851  g_loss:2.5082
# epoch:952  d_loss:0.3391  g_loss:2.3017
# epoch:953  d_loss:0.2171  g_loss:2.3459
# epoch:954  d_loss:0.2405  g_loss:2.6642
# epoch:955  d_loss:0.2399  g_loss:2.8520
# epoch:956  d_loss:0.3929  g_loss:2.2862
# epoch:957  d_loss:0.2171  g_loss:2.4481
# epoch:958  d_loss:0.4350  g_loss:1.5633
# epoch:959  d_loss:0.2131  g_loss:3.0148
# epoch:960  d_loss:0.2628  g_loss:3.6921
# epoch:961  d_loss:0.2178  g_loss:2.9208
# epoch:962  d_loss:0.2914  g_loss:3.0916
# epoch:963  d_loss:0.2597  g_loss:2.7598
# epoch:964  d_loss:0.2545  g_loss:2.5625
# epoch:965  d_loss:0.3019  g_loss:2.9232
# epoch:966  d_loss:0.3913  g_loss:2.4210
# epoch:967  d_loss:0.4125  g_loss:2.2213
# epoch:968  d_loss:0.4583  g_loss:2.5178
# epoch:969  d_loss:0.4318  g_loss:2.2109
# epoch:970  d_loss:0.5665  g_loss:1.8524
# epoch:971  d_loss:0.4876  g_loss:1.8859
# epoch:972  d_loss:0.4510  g_loss:1.6372
# epoch:973  d_loss:0.3410  g_loss:2.0929
# epoch:974  d_loss:0.3804  g_loss:2.2180
# epoch:975  d_loss:0.4255  g_loss:2.4462
# epoch:976  d_loss:0.6210  g_loss:2.1537
# epoch:977  d_loss:0.4279  g_loss:1.7012
# epoch:978  d_loss:0.4364  g_loss:2.1554
# epoch:979  d_loss:0.3249  g_loss:1.6949
# epoch:980  d_loss:0.3599  g_loss:2.1739
# epoch:981  d_loss:0.2462  g_loss:2.4614
# epoch:982  d_loss:0.3914  g_loss:2.0528
# epoch:983  d_loss:0.3144  g_loss:2.1850
# epoch:984  d_loss:0.4162  g_loss:2.1013
# epoch:985  d_loss:0.4459  g_loss:1.5628
# epoch:986  d_loss:0.3227  g_loss:2.1341
# epoch:987  d_loss:0.2788  g_loss:2.2136
# epoch:988  d_loss:0.2951  g_loss:2.8225
# epoch:989  d_loss:0.3047  g_loss:2.5953
# epoch:990  d_loss:0.2816  g_loss:2.8987
# epoch:991  d_loss:0.1903  g_loss:2.3030
# epoch:992  d_loss:0.3538  g_loss:2.1690
# epoch:993  d_loss:0.2430  g_loss:2.5648
# epoch:994  d_loss:0.3355  g_loss:2.4754
# epoch:995  d_loss:0.2862  g_loss:2.8930
# epoch:996  d_loss:0.3248  g_loss:2.4229
# epoch:997  d_loss:0.3215  g_loss:2.5387
# epoch:998  d_loss:0.3599  g_loss:2.1776
# epoch:999  d_loss:0.2470  g_loss:2.1606
# epoch:1000  d_loss:0.3946  g_loss:2.1893
# epoch:1001  d_loss:0.4419  g_loss:2.3796
# epoch:1002  d_loss:0.4139  g_loss:1.9280
# epoch:1003  d_loss:0.3373  g_loss:2.0607
# epoch:1004  d_loss:0.3665  g_loss:1.7557
# epoch:1005  d_loss:0.3633  g_loss:2.2459
# epoch:1006  d_loss:0.5012  g_loss:2.4595
# epoch:1007  d_loss:0.4461  g_loss:2.3094
# epoch:1008  d_loss:0.4163  g_loss:2.5857
# epoch:1009  d_loss:0.5319  g_loss:2.1581
# epoch:1010  d_loss:0.3228  g_loss:2.3895
# epoch:1011  d_loss:0.4172  g_loss:2.2842
# epoch:1012  d_loss:0.6879  g_loss:1.6018
# epoch:1013  d_loss:0.4066  g_loss:2.0156
# epoch:1014  d_loss:0.4603  g_loss:1.9053
# epoch:1015  d_loss:0.4120  g_loss:2.2962
# epoch:1016  d_loss:0.4218  g_loss:2.1644
# epoch:1017  d_loss:0.3915  g_loss:2.4932
# epoch:1018  d_loss:0.5072  g_loss:2.1168
# epoch:1019  d_loss:0.4064  g_loss:1.9170
# epoch:1020  d_loss:0.3233  g_loss:1.7124
# epoch:1021  d_loss:0.2646  g_loss:2.1782
# epoch:1022  d_loss:0.4622  g_loss:2.2196
# epoch:1023  d_loss:0.3512  g_loss:2.0000
# epoch:1024  d_loss:0.3855  g_loss:2.6972
# epoch:1025  d_loss:0.4772  g_loss:2.2823
# epoch:1026  d_loss:0.4485  g_loss:2.3384
# epoch:1027  d_loss:0.2227  g_loss:2.0488
# epoch:1028  d_loss:0.3254  g_loss:1.7316
# epoch:1029  d_loss:0.3767  g_loss:2.4388
# epoch:1030  d_loss:0.2276  g_loss:2.5289
# epoch:1031  d_loss:0.2104  g_loss:2.7789
# epoch:1032  d_loss:0.3108  g_loss:2.8817
# epoch:1033  d_loss:0.2966  g_loss:2.6841
# epoch:1034  d_loss:0.2726  g_loss:2.3110
# epoch:1035  d_loss:0.2954  g_loss:2.2568
# epoch:1036  d_loss:0.2789  g_loss:2.7893
# epoch:1037  d_loss:0.2341  g_loss:3.0272
# epoch:1038  d_loss:0.2104  g_loss:2.3876
# epoch:1039  d_loss:0.3314  g_loss:2.4020
# epoch:1040  d_loss:0.3261  g_loss:2.2355
# epoch:1041  d_loss:0.3177  g_loss:2.7077
# epoch:1042  d_loss:0.3880  g_loss:2.1986
# epoch:1043  d_loss:0.4644  g_loss:1.7961
# epoch:1044  d_loss:0.2416  g_loss:2.1719
# epoch:1045  d_loss:0.3819  g_loss:1.9024
# epoch:1046  d_loss:0.3551  g_loss:2.2374
# epoch:1047  d_loss:0.4415  g_loss:2.2646
# epoch:1048  d_loss:0.4294  g_loss:2.0171
# epoch:1049  d_loss:0.3877  g_loss:2.1071
# epoch:1050  d_loss:0.5653  g_loss:1.8440
# epoch:1051  d_loss:0.5916  g_loss:1.6359
# epoch:1052  d_loss:0.5419  g_loss:2.0791
# epoch:1053  d_loss:0.4094  g_loss:1.9910
# epoch:1054  d_loss:0.3854  g_loss:2.0542
# epoch:1055  d_loss:0.5870  g_loss:1.9594
# epoch:1056  d_loss:0.3257  g_loss:2.3351
# epoch:1057  d_loss:0.5057  g_loss:1.6621
# epoch:1058  d_loss:0.2542  g_loss:2.4074
# epoch:1059  d_loss:0.3450  g_loss:2.7001
# epoch:1060  d_loss:0.3834  g_loss:2.8929
# epoch:1061  d_loss:0.3251  g_loss:2.6121
# epoch:1062  d_loss:0.3321  g_loss:2.4065
# epoch:1063  d_loss:0.5074  g_loss:2.2336
# epoch:1064  d_loss:0.4362  g_loss:2.0613
# epoch:1065  d_loss:0.4255  g_loss:1.9601
# epoch:1066  d_loss:0.3736  g_loss:2.5831
# epoch:1067  d_loss:0.4136  g_loss:2.3483
# epoch:1068  d_loss:0.3686  g_loss:2.6758
# epoch:1069  d_loss:0.4293  g_loss:2.1862
# epoch:1070  d_loss:0.4257  g_loss:2.2894
# epoch:1071  d_loss:0.4836  g_loss:1.9523
# epoch:1072  d_loss:0.7077  g_loss:1.5919
# epoch:1073  d_loss:0.3941  g_loss:1.8428
# epoch:1074  d_loss:0.3474  g_loss:2.4744
# epoch:1075  d_loss:0.3204  g_loss:2.9538
# epoch:1076  d_loss:0.5448  g_loss:2.5746
# epoch:1077  d_loss:0.3698  g_loss:2.1384
# epoch:1078  d_loss:0.4043  g_loss:1.7654
# epoch:1079  d_loss:0.4824  g_loss:1.9705
# epoch:1080  d_loss:0.5707  g_loss:1.7719
# epoch:1081  d_loss:0.3915  g_loss:1.7661
# epoch:1082  d_loss:0.6878  g_loss:1.4652
# epoch:1083  d_loss:0.6285  g_loss:1.5599
# epoch:1084  d_loss:0.4044  g_loss:2.0148
# epoch:1085  d_loss:0.4371  g_loss:1.9213
# epoch:1086  d_loss:0.6313  g_loss:1.7161
# epoch:1087  d_loss:0.3496  g_loss:1.7855
# epoch:1088  d_loss:0.4729  g_loss:1.6438
# epoch:1089  d_loss:0.4307  g_loss:1.7200
# epoch:1090  d_loss:0.4948  g_loss:1.8147
# epoch:1091  d_loss:0.4446  g_loss:1.9036
# epoch:1092  d_loss:0.3516  g_loss:2.0531
# epoch:1093  d_loss:0.2443  g_loss:2.0286
# epoch:1094  d_loss:0.4788  g_loss:1.8398
# epoch:1095  d_loss:0.2256  g_loss:2.5907
# epoch:1096  d_loss:0.3472  g_loss:2.5015
# epoch:1097  d_loss:0.3663  g_loss:2.2362
# epoch:1098  d_loss:0.3559  g_loss:2.0663
# epoch:1099  d_loss:0.3366  g_loss:2.2750
# epoch:1100  d_loss:0.2592  g_loss:2.4831
# epoch:1101  d_loss:0.2779  g_loss:2.7334
# epoch:1102  d_loss:0.3193  g_loss:2.9369
# epoch:1103  d_loss:0.3271  g_loss:2.5378
# epoch:1104  d_loss:0.2594  g_loss:2.4220
# epoch:1105  d_loss:0.3316  g_loss:2.1659
# epoch:1106  d_loss:0.4614  g_loss:1.9386
# epoch:1107  d_loss:0.3836  g_loss:2.0861
# epoch:1108  d_loss:0.3986  g_loss:2.2066
# epoch:1109  d_loss:0.4032  g_loss:2.7570
# epoch:1110  d_loss:0.4925  g_loss:3.2111
# epoch:1111  d_loss:0.3253  g_loss:2.6334
# epoch:1112  d_loss:0.3454  g_loss:2.5592
# epoch:1113  d_loss:0.6865  g_loss:1.9794
# epoch:1114  d_loss:0.6134  g_loss:1.8157
# epoch:1115  d_loss:0.3622  g_loss:2.0353
# epoch:1116  d_loss:0.3779  g_loss:2.0645
# epoch:1117  d_loss:0.3787  g_loss:2.5858
# epoch:1118  d_loss:0.5212  g_loss:2.3806
# epoch:1119  d_loss:0.4784  g_loss:2.2801
# epoch:1120  d_loss:0.4322  g_loss:2.3325
# epoch:1121  d_loss:0.4046  g_loss:2.3532
# epoch:1122  d_loss:0.4812  g_loss:2.2685
# epoch:1123  d_loss:0.3812  g_loss:2.5137
# epoch:1124  d_loss:0.5128  g_loss:1.8598
# epoch:1125  d_loss:0.4754  g_loss:1.9322
# epoch:1126  d_loss:0.5164  g_loss:1.9412
# epoch:1127  d_loss:0.3986  g_loss:1.7808
# epoch:1128  d_loss:0.4900  g_loss:2.3527
# epoch:1129  d_loss:0.3261  g_loss:2.7379
# epoch:1130  d_loss:0.4506  g_loss:2.1116
# epoch:1131  d_loss:0.4340  g_loss:2.1673
# epoch:1132  d_loss:0.4272  g_loss:1.3185
# epoch:1133  d_loss:0.5028  g_loss:1.5501
# epoch:1134  d_loss:0.2697  g_loss:2.4842
# epoch:1135  d_loss:0.4128  g_loss:2.2970
# epoch:1136  d_loss:0.3014  g_loss:3.1068
# epoch:1137  d_loss:0.3109  g_loss:2.5372
# epoch:1138  d_loss:0.3067  g_loss:1.9776
# epoch:1139  d_loss:0.3524  g_loss:1.9851
# epoch:1140  d_loss:0.2987  g_loss:1.7583
# epoch:1141  d_loss:0.3089  g_loss:2.1165
# epoch:1142  d_loss:0.3880  g_loss:2.6727
# epoch:1143  d_loss:0.3108  g_loss:2.4544
# epoch:1144  d_loss:0.3970  g_loss:2.4754
# epoch:1145  d_loss:0.3684  g_loss:2.4758
# epoch:1146  d_loss:0.5116  g_loss:2.2950
# epoch:1147  d_loss:0.3721  g_loss:2.3468
# epoch:1148  d_loss:0.6288  g_loss:1.6846
# epoch:1149  d_loss:0.4748  g_loss:1.6355
# epoch:1150  d_loss:0.3751  g_loss:2.1337
# epoch:1151  d_loss:0.4214  g_loss:2.2367
# epoch:1152  d_loss:0.3763  g_loss:2.5315
# epoch:1153  d_loss:0.3482  g_loss:2.5876
# epoch:1154  d_loss:0.5009  g_loss:1.8155
# epoch:1155  d_loss:0.5249  g_loss:1.9871
# epoch:1156  d_loss:0.6277  g_loss:1.7234
# epoch:1157  d_loss:0.5155  g_loss:1.5146
# epoch:1158  d_loss:0.4427  g_loss:2.2172
# epoch:1159  d_loss:0.4435  g_loss:2.6199
# epoch:1160  d_loss:0.3323  g_loss:2.9286
# epoch:1161  d_loss:0.3806  g_loss:2.3384
# epoch:1162  d_loss:0.6213  g_loss:1.9548
# epoch:1163  d_loss:0.3587  g_loss:1.9408
# epoch:1164  d_loss:0.4633  g_loss:1.5708
# epoch:1165  d_loss:0.2793  g_loss:2.2333
# epoch:1166  d_loss:0.3609  g_loss:2.4761
# epoch:1167  d_loss:0.3342  g_loss:2.3072
# epoch:1168  d_loss:0.3249  g_loss:2.2341
# epoch:1169  d_loss:0.2755  g_loss:2.5969
# epoch:1170  d_loss:0.3584  g_loss:2.3120
# epoch:1171  d_loss:0.4149  g_loss:2.4633
# epoch:1172  d_loss:0.4122  g_loss:2.3126
# epoch:1173  d_loss:0.3463  g_loss:2.1872
# epoch:1174  d_loss:0.2865  g_loss:2.6091
# epoch:1175  d_loss:0.3465  g_loss:2.6212
# epoch:1176  d_loss:0.2525  g_loss:3.7001
# epoch:1177  d_loss:0.3207  g_loss:2.7876
# epoch:1178  d_loss:0.5037  g_loss:2.3147
# ...
# epoch:3610  d_loss:0.5586  g_loss:1.6152
# epoch:3611  d_loss:0.5023  g_loss:1.8156
# epoch:3612  d_loss:0.4862  g_loss:1.7677
# epoch:3613  d_loss:0.3847  g_loss:1.8569
# epoch:3614  d_loss:0.4688  g_loss:2.0860
# epoch:3615  d_loss:0.5218  g_loss:1.7405
# epoch:3616  d_loss:0.5181  g_loss:1.9385
# epoch:3617  d_loss:0.6053  g_loss:1.8528
# epoch:3618  d_loss:0.4957  g_loss:1.7229
# epoch:3619  d_loss:0.4180  g_loss:2.0789
# epoch:3620  d_loss:0.3734  g_loss:2.3528
# epoch:3621  d_loss:0.4583  g_loss:1.7397
# epoch:3622  d_loss:0.4470  g_loss:1.6624
# epoch:3623  d_loss:0.4111  g_loss:2.1414
# epoch:3624  d_loss:0.4180  g_loss:1.9189
# epoch:3625  d_loss:0.4035  g_loss:1.7916
# epoch:3626  d_loss:0.3446  g_loss:2.2054
# epoch:3627  d_loss:0.3553  g_loss:2.0612
# epoch:3628  d_loss:0.5276  g_loss:1.5056
# epoch:3629  d_loss:0.5737  g_loss:1.3883
# epoch:3630  d_loss:0.5535  g_loss:1.4168
# epoch:3631  d_loss:0.4458  g_loss:1.9548
# epoch:3632  d_loss:0.3844  g_loss:1.7017
# epoch:3633  d_loss:0.4198  g_loss:1.9427
# epoch:3634  d_loss:0.5139  g_loss:2.0076
# epoch:3635  d_loss:0.5802  g_loss:1.8386
# epoch:3636  d_loss:0.3998  g_loss:2.0642
# epoch:3637  d_loss:0.4091  g_loss:1.7306
# epoch:3638  d_loss:0.3279  g_loss:2.0112
# epoch:3639  d_loss:0.4918  g_loss:2.1577
# epoch:3640  d_loss:0.5115  g_loss:1.7736
# epoch:3641  d_loss:0.4898  g_loss:1.4382
# epoch:3642  d_loss:0.5172  g_loss:1.4131
# epoch:3643  d_loss:0.4910  g_loss:1.4745
# epoch:3644  d_loss:0.4363  g_loss:2.1751
# epoch:3645  d_loss:0.4041  g_loss:2.6265
# epoch:3646  d_loss:0.5165  g_loss:2.4955
# epoch:3647  d_loss:0.3446  g_loss:2.4685
# epoch:3648  d_loss:0.4259  g_loss:1.7681
# epoch:3649  d_loss:0.5621  g_loss:1.5297
# epoch:3650  d_loss:0.3946  g_loss:1.5887
# epoch:3651  d_loss:0.5248  g_loss:1.9514
# epoch:3652  d_loss:0.5596  g_loss:2.0213
# epoch:3653  d_loss:0.4045  g_loss:2.2667
# epoch:3654  d_loss:0.5407  g_loss:2.4324
# epoch:3655  d_loss:0.5252  g_loss:1.8342
# epoch:3656  d_loss:0.6502  g_loss:1.6980
# epoch:3657  d_loss:0.5530  g_loss:1.8435
# epoch:3658  d_loss:0.4959  g_loss:2.3510
# epoch:3659  d_loss:0.5566  g_loss:2.0171
# epoch:3660  d_loss:0.5096  g_loss:2.3954
# epoch:3661  d_loss:0.4178  g_loss:2.2579
# epoch:3662  d_loss:0.4792  g_loss:1.9742
# epoch:3663  d_loss:0.5282  g_loss:2.0558
# epoch:3664  d_loss:0.6703  g_loss:1.4834
# epoch:3665  d_loss:0.6311  g_loss:1.3480
# epoch:3666  d_loss:0.3886  g_loss:1.8475
# epoch:3667  d_loss:0.5908  g_loss:1.8562
# epoch:3668  d_loss:0.4414  g_loss:2.1949
# epoch:3669  d_loss:0.4243  g_loss:2.8131
# epoch:3670  d_loss:0.4026  g_loss:2.1729
# epoch:3671  d_loss:0.5313  g_loss:1.7370
# epoch:3672  d_loss:0.4633  g_loss:1.5827
# epoch:3673  d_loss:0.3850  g_loss:1.7895
# epoch:3674  d_loss:0.4242  g_loss:1.6578
# epoch:3675  d_loss:0.3110  g_loss:2.0573
# epoch:3676  d_loss:0.5927  g_loss:2.1580
# epoch:3677  d_loss:0.4041  g_loss:2.1541
# epoch:3678  d_loss:0.5000  g_loss:1.5738
# epoch:3679  d_loss:0.4482  g_loss:1.6628
# epoch:3680  d_loss:0.4725  g_loss:1.2711
# epoch:3681  d_loss:0.4607  g_loss:1.3661
# epoch:3682  d_loss:0.4750  g_loss:2.0713
# epoch:3683  d_loss:0.4279  g_loss:1.9446
# epoch:3684  d_loss:0.4695  g_loss:2.3858
# epoch:3685  d_loss:0.3315  g_loss:1.7800
# epoch:3686  d_loss:0.3412  g_loss:2.3291
# epoch:3687  d_loss:0.4378  g_loss:1.7769
# epoch:3688  d_loss:0.4583  g_loss:1.9493
# epoch:3689  d_loss:0.5730  g_loss:1.5965
# epoch:3690  d_loss:0.4206  g_loss:1.3854
# epoch:3691  d_loss:0.4282  g_loss:1.4747
# epoch:3692  d_loss:0.3342  g_loss:1.7755
# epoch:3693  d_loss:0.4555  g_loss:1.6698
# epoch:3694  d_loss:0.3898  g_loss:2.1451
# epoch:3695  d_loss:0.4801  g_loss:2.0350
# epoch:3696  d_loss:0.4225  g_loss:1.7942
# epoch:3697  d_loss:0.5103  g_loss:1.6887
# epoch:3698  d_loss:0.4225  g_loss:1.9758
# epoch:3699  d_loss:0.4762  g_loss:1.6062
# epoch:3700  d_loss:0.6073  g_loss:1.5575
# epoch:3701  d_loss:0.3296  g_loss:1.9281
# epoch:3702  d_loss:0.5186  g_loss:2.2414
# epoch:3703  d_loss:0.6394  g_loss:1.6239
# epoch:3704  d_loss:0.5622  g_loss:1.6211
# epoch:3705  d_loss:0.6711  g_loss:1.4522
# epoch:3706  d_loss:0.4855  g_loss:1.2249
# epoch:3707  d_loss:0.4943  g_loss:1.7591
# epoch:3708  d_loss:0.3195  g_loss:2.0316
# epoch:3709  d_loss:0.3306  g_loss:2.0918
# epoch:3710  d_loss:0.5545  g_loss:1.8579
# epoch:3711  d_loss:0.4210  g_loss:2.1913
# epoch:3712  d_loss:0.4387  g_loss:1.6510
# epoch:3713  d_loss:0.4205  g_loss:1.4807
# epoch:3714  d_loss:0.5818  g_loss:1.8427
# epoch:3715  d_loss:0.3174  g_loss:1.7426
# epoch:3716  d_loss:0.4964  g_loss:1.8368
# epoch:3717  d_loss:0.4374  g_loss:1.8269
# epoch:3718  d_loss:0.4090  g_loss:1.5041
# epoch:3719  d_loss:0.4314  g_loss:1.6962
# epoch:3720  d_loss:0.4626  g_loss:1.9083
# epoch:3721  d_loss:0.5408  g_loss:1.5160
# epoch:3722  d_loss:0.3849  g_loss:1.2843
# epoch:3723  d_loss:0.4079  g_loss:1.8726
# epoch:3724  d_loss:0.5748  g_loss:2.0311
# epoch:3725  d_loss:0.4831  g_loss:2.0754
# epoch:3726  d_loss:0.4080  g_loss:2.0944
# epoch:3727  d_loss:0.5408  g_loss:1.7371
# epoch:3728  d_loss:0.6145  g_loss:1.4513
# epoch:3729  d_loss:0.5241  g_loss:1.6035
# epoch:3730  d_loss:0.5522  g_loss:1.5272
# epoch:3731  d_loss:0.4921  g_loss:1.7838
# epoch:3732  d_loss:0.5278  g_loss:1.5546
# epoch:3733  d_loss:0.4533  g_loss:1.5103
# epoch:3734  d_loss:0.4059  g_loss:1.7574
# epoch:3735  d_loss:0.3622  g_loss:1.8997
# epoch:3736  d_loss:0.4579  g_loss:1.8418
# epoch:3737  d_loss:0.3563  g_loss:1.9116
# epoch:3738  d_loss:0.5084  g_loss:1.4975
# epoch:3739  d_loss:0.4840  g_loss:1.4992
# epoch:3740  d_loss:0.4790  g_loss:1.6253
# epoch:3741  d_loss:0.3113  g_loss:2.0315
# epoch:3742  d_loss:0.4951  g_loss:1.6828
# epoch:3743  d_loss:0.4696  g_loss:1.8536
# epoch:3744  d_loss:0.4411  g_loss:1.9292
# epoch:3745  d_loss:0.4592  g_loss:2.0420
# epoch:3746  d_loss:0.4598  g_loss:1.9608
# epoch:3747  d_loss:0.4429  g_loss:2.0534
# epoch:3748  d_loss:0.2955  g_loss:1.9594
# epoch:3749  d_loss:0.5293  g_loss:1.7841
# epoch:3750  d_loss:0.5953  g_loss:1.4955
# epoch:3751  d_loss:0.4184  g_loss:1.3685
# epoch:3752  d_loss:0.4895  g_loss:1.4674
# epoch:3753  d_loss:0.5074  g_loss:1.4089
# epoch:3754  d_loss:0.4395  g_loss:1.3662
# epoch:3755  d_loss:0.4796  g_loss:1.7387
# epoch:3756  d_loss:0.5316  g_loss:1.6359
# epoch:3757  d_loss:0.3735  g_loss:1.9407
# epoch:3758  d_loss:0.4870  g_loss:1.9280
# epoch:3759  d_loss:0.3570  g_loss:2.2739
# epoch:3760  d_loss:0.4370  g_loss:1.8880
# epoch:3761  d_loss:0.5115  g_loss:1.5733
# epoch:3762  d_loss:0.4614  g_loss:1.6957
# epoch:3763  d_loss:0.7011  g_loss:1.8571
# epoch:3764  d_loss:0.4510  g_loss:1.7105
# epoch:3765  d_loss:0.3735  g_loss:2.0352
# epoch:3766  d_loss:0.4107  g_loss:1.9837
# epoch:3767  d_loss:0.4880  g_loss:1.8096
# epoch:3768  d_loss:0.5058  g_loss:2.0535
# epoch:3769  d_loss:0.4366  g_loss:1.8231
# epoch:3770  d_loss:0.5150  g_loss:1.5547
# epoch:3771  d_loss:0.4369  g_loss:1.3955
# epoch:3772  d_loss:0.5559  g_loss:1.2940
# epoch:3773  d_loss:0.5078  g_loss:1.5344
# epoch:3774  d_loss:0.4478  g_loss:1.8186
# epoch:3775  d_loss:0.5831  g_loss:1.6718
# epoch:3776  d_loss:0.5620  g_loss:1.7131
# epoch:3777  d_loss:0.6816  g_loss:1.4535
# epoch:3778  d_loss:0.5103  g_loss:1.1818
# epoch:3779  d_loss:0.6429  g_loss:1.1184
# epoch:3780  d_loss:0.4144  g_loss:1.5895
# epoch:3781  d_loss:0.5103  g_loss:1.7747
# epoch:3782  d_loss:0.4530  g_loss:2.0620
# epoch:3783  d_loss:0.5610  g_loss:1.6890
# epoch:3784  d_loss:0.5710  g_loss:1.5374
# epoch:3785  d_loss:0.5204  g_loss:1.3292
# epoch:3786  d_loss:0.5584  g_loss:1.8627
# epoch:3787  d_loss:0.3677  g_loss:2.1907
# epoch:3788  d_loss:0.4986  g_loss:1.6887
# epoch:3789  d_loss:0.4495  g_loss:1.9914
# epoch:3790  d_loss:0.5420  g_loss:1.4808
# epoch:3791  d_loss:0.5519  g_loss:1.3505
# epoch:3792  d_loss:0.4244  g_loss:1.6207
# epoch:3793  d_loss:0.3515  g_loss:2.2025
# epoch:3794  d_loss:0.3164  g_loss:1.9950
# epoch:3795  d_loss:0.5682  g_loss:2.0539
# epoch:3796  d_loss:0.6392  g_loss:1.7459
# epoch:3797  d_loss:0.4552  g_loss:1.5150
# epoch:3798  d_loss:0.5072  g_loss:2.0415
# epoch:3799  d_loss:0.5364  g_loss:1.7734
# epoch:3800  d_loss:0.5345  g_loss:1.3884
# epoch:3801  d_loss:0.5401  g_loss:1.4085
# epoch:3802  d_loss:0.4252  g_loss:1.4496
# epoch:3803  d_loss:0.5197  g_loss:1.4628
# epoch:3804  d_loss:0.5047  g_loss:2.0048
# epoch:3805  d_loss:0.5497  g_loss:1.9022
# epoch:3806  d_loss:0.6292  g_loss:1.6781
# epoch:3807  d_loss:0.5600  g_loss:1.3310
# epoch:3808  d_loss:0.5082  g_loss:1.3683
# epoch:3809  d_loss:0.4103  g_loss:1.5352
# epoch:3810  d_loss:0.4437  g_loss:1.8960
# epoch:3811  d_loss:0.5577  g_loss:1.8752
# epoch:3812  d_loss:0.4216  g_loss:2.2042
# epoch:3813  d_loss:0.4698  g_loss:1.7118
# epoch:3814  d_loss:0.4485  g_loss:1.6667
# epoch:3815  d_loss:0.5676  g_loss:2.0647
# epoch:3816  d_loss:0.4292  g_loss:1.7404
# epoch:3817  d_loss:0.4634  g_loss:1.5434
# epoch:3818  d_loss:0.5600  g_loss:1.5929
# epoch:3819  d_loss:0.3390  g_loss:2.0536
# epoch:3820  d_loss:0.6372  g_loss:1.7935
# epoch:3821  d_loss:0.4981  g_loss:1.7596
# epoch:3822  d_loss:0.5095  g_loss:1.6794
# epoch:3823  d_loss:0.5604  g_loss:1.3983
# epoch:3824  d_loss:0.4057  g_loss:1.6365
# epoch:3825  d_loss:0.4614  g_loss:1.7733
# epoch:3826  d_loss:0.6450  g_loss:1.6020
# epoch:3827  d_loss:0.5951  g_loss:1.5306
# epoch:3828  d_loss:0.3939  g_loss:1.9454
# epoch:3829  d_loss:0.4888  g_loss:1.3865
# epoch:3830  d_loss:0.4684  g_loss:1.6607
# epoch:3831  d_loss:0.3789  g_loss:1.6135
# epoch:3832  d_loss:0.6738  g_loss:1.2825
# epoch:3833  d_loss:0.4167  g_loss:1.8524
# epoch:3834  d_loss:0.4850  g_loss:1.8220
# epoch:3835  d_loss:0.5332  g_loss:1.6371
# epoch:3836  d_loss:0.5028  g_loss:1.8516
# epoch:3837  d_loss:0.5496  g_loss:1.3980
# epoch:3838  d_loss:0.4866  g_loss:1.1890
# epoch:3839  d_loss:0.5868  g_loss:1.3221
# epoch:3840  d_loss:0.4766  g_loss:1.3843
# epoch:3841  d_loss:0.3279  g_loss:1.8914
# epoch:3842  d_loss:0.4023  g_loss:2.2240
# epoch:3843  d_loss:0.6016  g_loss:2.0106
# epoch:3844  d_loss:0.5519  g_loss:1.4574
# epoch:3845  d_loss:0.5260  g_loss:1.3009
# epoch:3846  d_loss:0.4954  g_loss:1.2709
# epoch:3847  d_loss:0.5148  g_loss:1.5821
# epoch:3848  d_loss:0.4416  g_loss:1.6739
# epoch:3849  d_loss:0.3818  g_loss:1.6493
# epoch:3850  d_loss:0.4834  g_loss:1.9507
# epoch:3851  d_loss:0.4388  g_loss:2.0941
# epoch:3852  d_loss:0.5458  g_loss:1.5978
# epoch:3853  d_loss:0.3599  g_loss:1.8591
# epoch:3854  d_loss:0.3842  g_loss:1.5646
# epoch:3855  d_loss:0.4195  g_loss:1.6793
# epoch:3856  d_loss:0.4570  g_loss:1.5198
# epoch:3857  d_loss:0.5559  g_loss:1.7042
# epoch:3858  d_loss:0.5452  g_loss:1.9386
# epoch:3859  d_loss:0.4494  g_loss:1.0965
# epoch:3860  d_loss:0.4748  g_loss:1.3250
# epoch:3861  d_loss:0.3311  g_loss:1.6189
# epoch:3862  d_loss:0.4132  g_loss:1.8649
# epoch:3863  d_loss:0.4863  g_loss:1.8265
# epoch:3864  d_loss:0.4912  g_loss:1.7458
# epoch:3865  d_loss:0.4992  g_loss:1.5953
# epoch:3866  d_loss:0.5587  g_loss:1.1967
# epoch:3867  d_loss:0.4867  g_loss:1.6237
# epoch:3868  d_loss:0.5143  g_loss:1.6583
# epoch:3869  d_loss:0.3790  g_loss:2.0110
# epoch:3870  d_loss:0.4162  g_loss:1.6482
# epoch:3871  d_loss:0.5577  g_loss:1.6658
# epoch:3872  d_loss:0.4351  g_loss:1.4444
# epoch:3873  d_loss:0.5935  g_loss:1.6648
# epoch:3874  d_loss:0.4750  g_loss:1.6659
# epoch:3875  d_loss:0.5497  g_loss:1.6646
# epoch:3876  d_loss:0.5232  g_loss:1.5150
# epoch:3877  d_loss:0.5888  g_loss:1.2379
# epoch:3878  d_loss:0.5341  g_loss:1.6766
# epoch:3879  d_loss:0.5451  g_loss:1.3997
# epoch:3880  d_loss:0.4549  g_loss:1.3864
# epoch:3881  d_loss:0.5707  g_loss:1.5485
# epoch:3882  d_loss:0.5126  g_loss:1.6414
# epoch:3883  d_loss:0.4799  g_loss:1.5393
# epoch:3884  d_loss:0.5100  g_loss:1.7265
# epoch:3885  d_loss:0.5213  g_loss:1.6634
# epoch:3886  d_loss:0.4815  g_loss:1.4797
# epoch:3887  d_loss:0.4979  g_loss:1.8835
# epoch:3888  d_loss:0.4728  g_loss:1.6366
# epoch:3889  d_loss:0.3283  g_loss:2.0530
# epoch:3890  d_loss:0.5008  g_loss:1.2850
# epoch:3891  d_loss:0.3649  g_loss:1.5493
# epoch:3892  d_loss:0.5143  g_loss:1.9598
# epoch:3893  d_loss:0.4185  g_loss:1.7412
# epoch:3894  d_loss:0.4937  g_loss:1.8068
# epoch:3895  d_loss:0.4416  g_loss:1.7113
# epoch:3896  d_loss:0.5956  g_loss:1.9148
# epoch:3897  d_loss:0.3629  g_loss:1.7735
# epoch:3898  d_loss:0.4218  g_loss:1.9317
# epoch:3899  d_loss:0.5195  g_loss:1.6809
# epoch:3900  d_loss:0.5308  g_loss:1.9075
# epoch:3901  d_loss:0.4334  g_loss:1.8218
# epoch:3902  d_loss:0.5345  g_loss:1.7282
# epoch:3903  d_loss:0.5697  g_loss:1.2616
# epoch:3904  d_loss:0.4786  g_loss:1.9699
# epoch:3905  d_loss:0.4541  g_loss:1.7909
# epoch:3906  d_loss:0.6673  g_loss:1.7720
# epoch:3907  d_loss:0.4913  g_loss:2.1127
# epoch:3908  d_loss:0.5450  g_loss:1.7023
# epoch:3909  d_loss:0.5317  g_loss:1.4897
# epoch:3910  d_loss:0.5304  g_loss:1.4451
# epoch:3911  d_loss:0.5565  g_loss:1.4658
# epoch:3912  d_loss:0.5239  g_loss:1.6441
# epoch:3913  d_loss:0.4717  g_loss:1.5090
# epoch:3914  d_loss:0.5401  g_loss:1.6241
# epoch:3915  d_loss:0.5779  g_loss:1.7388
# epoch:3916  d_loss:0.5591  g_loss:1.5933
# epoch:3917  d_loss:0.4190  g_loss:1.7616
# epoch:3918  d_loss:0.5938  g_loss:1.2346
# epoch:3919  d_loss:0.5923  g_loss:1.6060
# epoch:3920  d_loss:0.5187  g_loss:1.6439
# epoch:3921  d_loss:0.4661  g_loss:1.7874
# epoch:3922  d_loss:0.2969  g_loss:1.9439
# epoch:3923  d_loss:0.4163  g_loss:2.0158
# epoch:3924  d_loss:0.5473  g_loss:1.6371
# epoch:3925  d_loss:0.4957  g_loss:1.3456
# epoch:3926  d_loss:0.5013  g_loss:1.0907
# epoch:3927  d_loss:0.4138  g_loss:1.6312
# epoch:3928  d_loss:0.4371  g_loss:1.4475
# epoch:3929  d_loss:0.4964  g_loss:1.8645
# epoch:3930  d_loss:0.4600  g_loss:1.8710
# epoch:3931  d_loss:0.5000  g_loss:1.9954
# epoch:3932  d_loss:0.4391  g_loss:1.7109
# epoch:3933  d_loss:0.4616  g_loss:1.8743
# epoch:3934  d_loss:0.5709  g_loss:1.6106
# epoch:3935  d_loss:0.3525  g_loss:1.7629
# epoch:3936  d_loss:0.3770  g_loss:1.8621
# epoch:3937  d_loss:0.4372  g_loss:1.5302
# epoch:3938  d_loss:0.3914  g_loss:1.9158
# epoch:3939  d_loss:0.5127  g_loss:1.6565
# epoch:3940  d_loss:0.4342  g_loss:1.6236
# epoch:3941  d_loss:0.4235  g_loss:1.6834
# epoch:3942  d_loss:0.4295  g_loss:2.4028
# epoch:3943  d_loss:0.3535  g_loss:1.8663
# epoch:3944  d_loss:0.4584  g_loss:1.7897
# epoch:3945  d_loss:0.4073  g_loss:1.5076
# epoch:3946  d_loss:0.5607  g_loss:1.3678
# epoch:3947  d_loss:0.3482  g_loss:1.2913
# epoch:3948  d_loss:0.4216  g_loss:1.9476
# epoch:3949  d_loss:0.3548  g_loss:2.1951
# epoch:3950  d_loss:0.3664  g_loss:1.9337
# epoch:3951  d_loss:0.5020  g_loss:2.1542
# epoch:3952  d_loss:0.4076  g_loss:1.9096
# epoch:3953  d_loss:0.4368  g_loss:1.7811
# epoch:3954  d_loss:0.4489  g_loss:1.4739
# epoch:3955  d_loss:0.5482  g_loss:1.2160
# epoch:3956  d_loss:0.4938  g_loss:1.7775
# epoch:3957  d_loss:0.5430  g_loss:1.7613
# epoch:3958  d_loss:0.6057  g_loss:1.4688
# epoch:3959  d_loss:0.6804  g_loss:1.4087
# epoch:3960  d_loss:0.4197  g_loss:1.6893
# epoch:3961  d_loss:0.4035  g_loss:2.1076
# epoch:3962  d_loss:0.5585  g_loss:1.7648
# epoch:3963  d_loss:0.6377  g_loss:1.6495
# epoch:3964  d_loss:0.6536  g_loss:1.2969
# epoch:3965  d_loss:0.5382  g_loss:1.2809
# epoch:3966  d_loss:0.4351  g_loss:1.7284
# epoch:3967  d_loss:0.6409  g_loss:1.9102
# epoch:3968  d_loss:0.5409  g_loss:1.7660
# epoch:3969  d_loss:0.6775  g_loss:1.5040
# epoch:3970  d_loss:0.3646  g_loss:2.0947
# epoch:3971  d_loss:0.5328  g_loss:1.6800
# epoch:3972  d_loss:0.5828  g_loss:1.6680
# epoch:3973  d_loss:0.4797  g_loss:1.6084
# epoch:3974  d_loss:0.4584  g_loss:1.7456
# epoch:3975  d_loss:0.4937  g_loss:1.6484
# epoch:3976  d_loss:0.4744  g_loss:1.9568
# epoch:3977  d_loss:0.3328  g_loss:2.2340
# epoch:3978  d_loss:0.5811  g_loss:1.7567
# epoch:3979  d_loss:0.4504  g_loss:2.3379
# epoch:3980  d_loss:0.4787  g_loss:1.7670
# epoch:3981  d_loss:0.4380  g_loss:2.0609
# epoch:3982  d_loss:0.3939  g_loss:1.8606
# epoch:3983  d_loss:0.5981  g_loss:1.6594
# epoch:3984  d_loss:0.5475  g_loss:1.4183
# epoch:3985  d_loss:0.4199  g_loss:1.9433
# epoch:3986  d_loss:0.5747  g_loss:1.4691
# epoch:3987  d_loss:0.4722  g_loss:1.5556
# epoch:3988  d_loss:0.4241  g_loss:1.7036
# epoch:3989  d_loss:0.5111  g_loss:1.9257
# epoch:3990  d_loss:0.4973  g_loss:1.8286
# epoch:3991  d_loss:0.5056  g_loss:1.8499
# epoch:3992  d_loss:0.4866  g_loss:1.6461
# epoch:3993  d_loss:0.4799  g_loss:1.6691
# epoch:3994  d_loss:0.5138  g_loss:1.4287
# epoch:3995  d_loss:0.4787  g_loss:1.7374
# epoch:3996  d_loss:0.5797  g_loss:1.6413
# epoch:3997  d_loss:0.5166  g_loss:1.7845
# epoch:3998  d_loss:0.5655  g_loss:1.7557
# epoch:3999  d_loss:0.5025  g_loss:1.3740
